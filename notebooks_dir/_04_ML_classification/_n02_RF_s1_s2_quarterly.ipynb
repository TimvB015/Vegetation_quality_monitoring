# %% [markdown]
# _This notebook trains the Quarterly Random Forest based on the Sentinel-1 and -2 data._

# %% [markdown]
# # General

# %% [markdown]
# ## Importing functions

# %%
from notebooks_dir._04_ML_classification._support._n01_full_workflow import (
    RF_trainer_workflow,
)

# %% [markdown]
# ## Setting Directory

# %%
from paths.OG_paths import (
    #######################################
    #  03_training_validation_data_split  #
    #######################################
    # |   n03_training_validation_split   |
    # +===================================+
    # --- training validation GPKGs UTM32631 --- #
    # WD1
    training_pixels__WD1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__WD1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # WD2
    training_pixels__WD2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__WD2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # WD3
    training_pixels__WD3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__WD3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # WD4
    training_pixels__WD4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__WD4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # WD5
    training_pixels__WD5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__WD5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # WD6
    training_pixels__WD6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__WD6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # s1
    training_pixels__s1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__s1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # s2
    training_pixels__s2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__s2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # s3
    training_pixels__s3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__s3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # WDNF1
    training_pixels__WDNF1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__WDNF1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # WDNF2
    training_pixels__WDNF2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__WDNF2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # WDNF3
    training_pixels__WDNF3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__WDNF3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # WDNF4
    training_pixels__WDNF4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__WDNF4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # WDNF5
    training_pixels__WDNF5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__WDNF5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    # WDNF6
    training_pixels__WDNF6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    validation_pixels__WDNF6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,


    #######################################
    #        04_ML_classification         #
    #######################################ac
    # |  n01_random_forest_s2_quarterly   |
    # +===================================+
    # DIRs
    s2_stack_b2348s1__dir,
    s2_stack_b28ndvwis1__dir,

    # --- RF model output --- #
    RF_out__UTM32631__rstrs_dir,
)

# %% [markdown]
# ## raster stacks

# %%
b2348s1_stack_full = [
    "B02", "B03", "B04", "B08", "VH_Q_mean_dB", 
    "VV_Q_mean_dB", "VH_Q_std_dB_std", "VV_Q_std_dB_std",
    "VV_VH_ratio_Q_opt1_dB", "VALID_MASK",
]

b2348s1_stack_features = [
    "B02", "B03", "B04", "B08", "VH_Q_mean_dB", 
    "VV_Q_mean_dB", "VH_Q_std_dB_std", "VV_Q_std_dB_std",
    "VV_VH_ratio_Q_opt1_dB",
]

# %%
b28ndvwis1_stack_full = [
    "B02", "B08", "S2_ndvi", "S2_ndwi",
    "VH_Q_mean_dB", "VV_Q_mean_dB",
    "VH_Q_std_dB_std", "VV_Q_std_dB_std",
    "VV_VH_ratio_Q_opt1_dB", "VALID_MASK",
]

b28ndvwis1_stack_features = [
    "B02", "B08", "S2_ndvi", "S2_ndwi", 
    "VH_Q_mean_dB", "VV_Q_mean_dB", 
    "VH_Q_std_dB_std", "VV_Q_std_dB_std",
    "VV_VH_ratio_Q_opt1_dB",
]

# %% [markdown]
# # WD-division

# %% [markdown]
# ## WD1 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_WD1_mdl1_b2348s1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WD1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WD1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WD1",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WD1_mdl1_b2348s1_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_WD1_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WD1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WD1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WD1",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WD1_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# ## WD2 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_WD2_mdl1_b2348_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WD2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WD2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WD2",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WD2_mdl1_b2348_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_WD2_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WD2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WD2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WD2",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WD2_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# ## WD3 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_WD3_mdl1_b2348s1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WD3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WD3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WD3",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WD3_mdl1_b2348s1_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_WD3_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WD3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WD3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WD3",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WD3_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# ## WD4 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_WD4_mdl1_b2348s1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WD4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WD4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WD4",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WD4_mdl1_b2348s1_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_WD4_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WD4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WD4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WD4",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WD4_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# ## WD5 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_WD5_mdl1_b2348s1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WD5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WD5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WD5",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WD5_mdl1_b2348s1_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_WD5_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WD5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WD5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WD5",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WD5_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# ## WD6 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_WD6_mdl1_b2348s1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WD6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WD6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WD6",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WD6_mdl1_b2348s1_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_WD6_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WD6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WD6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WD6",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WD6_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# # S-division

# %% [markdown]
# ## S1 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_s1_mdl1_b2348_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__s1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__s1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="s1",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_s1_mdl1_b2348_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_s1_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__s1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__s1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="s1",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_s1_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# ## S2 mdl2

# %% [markdown]
# ### b2348s1 - stack

# %%
result_s2_mdl1_b2348_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__s2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__s2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="s2",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_s2_mdl1_b2348_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_s2_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__s2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__s2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="s2",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_s2_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# ## S3 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_s3_mdl1_b2348_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__s3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__s3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="s3",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_s3_mdl1_b2348_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_s3_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__s3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__s3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="s3",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_s3_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# # WDNF-division

# %% [markdown]
# ## WDNF1 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_WDNF1_mdl1_b2348_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WDNF1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WDNF1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WDNF1",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WDNF1_mdl1_b2348_at1_df

# %%
result_WDNF1_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WDNF1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WDNF1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WDNF1",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WDNF1_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# ## WDNF2 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_WDNF2_mdl1_b2348_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WDNF2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WDNF2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WDNF2",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WDNF2_mdl1_b2348_at1_df

# %%
result_WDNF2_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WDNF2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WDNF2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WDNF2",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WDNF2_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# ## WDNF3 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_WDNF3_mdl1_b2348_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WDNF3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WDNF3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WDNF3",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WDNF3_mdl1_b2348_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_WDNF3_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WDNF3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WDNF3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WDNF3",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WDNF3_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# ## WDNF4 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_WDNF4_mdl1_b2348_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WDNF4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WDNF4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WDNF4",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WDNF4_mdl1_b2348_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_WDNF4_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WDNF4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WDNF4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WDNF4",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WDNF4_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# ## WDNF5 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_WDNF5_mdl1_b2348_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WDNF5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WDNF5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WDNF5",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WDNF5_mdl1_b2348_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_WDNF5_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WDNF5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WDNF5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WDNF5",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WDNF5_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# ## WDNF6 mdl1

# %% [markdown]
# ### b2348s1 - stack

# %%
result_WDNF6_mdl1_b2348_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b2348s1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b2348s1_stack.tif",
    all_raster_band_names=b2348s1_stack_full,
    feature_band_names=b2348s1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WDNF6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WDNF6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WDNF6",
    stack_description="b2348s1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WDNF6_mdl1_b2348_at1_df

# %% [markdown]
# ### b28ndvwis1 - stack

# %%
result_WDNF6_mdl1_b28ndvwis1_at1_df = RF_trainer_workflow(
    stacked_raster_dir=s2_stack_b28ndvwis1__dir,
    stacked_raster_crs="UTM32631",
    stacked_raster_filename="S2_b28ndvwis1_stack.tif",
    all_raster_band_names=b28ndvwis1_stack_full,
    feature_band_names=b28ndvwis1_stack_features,
    years=['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
    timeframes=['q1', 'q2', 'q3', 'q4'],
    valid_band_available=True,
    valid_band_name="VALID_MASK",
    valid_value=1,
    train_gpkg_path=training_pixels__WDNF6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    val_gpkg_path=validation_pixels__WDNF6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg_path,
    gpkg_label_col="type",
    gpkg_year_col="years",
    rf_model_selection="mdl1",
    hab_selection="WDNF6",
    stack_description="b28ndvwis1",
    train_split_attempt="at1",
    classified_rasters_dir=RF_out__UTM32631__rstrs_dir,
    nodata_out=255,
    overwrite=False,
)

result_WDNF6_mdl1_b28ndvwis1_at1_df

# %% [markdown]
# End of the Notebook
