# %% [markdown]
# _This notebook uses the Folium package to visualize the habitat polygon maps_

# %% [markdown]
# ## Importing Functions

# %%
from pathlib import Path
import sys

sys.path.insert(0, str(Path.cwd().resolve()))
from functions._00_common_funcs import (
    batch_func,
    check_directories_func,
    path_func,
    check_gpkg_layers_func,
    import_gpkg_func,
    import_xlsx_func,
    print_raster_info,
    import_raster_func,
    quick_rstr_plot_func,
    check_processing,
    show_nameconvention_func,
)

from functions._04_visualizing_habitat_map_funcs import (
    add_recenter_button,
    create_collapsible_legend,
    rstr_to_folium_layer,
    idx_df_to_folium_layers
)

# %% [markdown]
# ## Setting directory

# %%
notebook_dir = Path.cwd()

check_directories_func(notebook_dir)
# Out:
# 'Functions, Dependencies, and Output directories found'

# %%
# years definition
years_2018_2024 = [2018, 2019, 2020, 2021, 2022, 2023, 2024]
tmp_1_year = ['2010-2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
from functions._00_file_paths import (
    # --- Habitat kart Processed GPKGs (WGS84) ---
    habitat_kart__processed__gelderland__WGS84__gpkg_path,
    habitat_kart__processed__gelderland_minHR__WGS84__gpkg_path,
    habitat_kart__processed__website__WGS84__gpkg_path,
    habitat_kart__processed__website_plusHR__WGS84__gpkg_path,


    # --- Folium Maps ---
    # Basiskaart
	map__basis__html_path,
	# LGN
	map__lgn__html_path,
	# gelderland
	map__AO__gelderland__tmp1__html_path,
	map__FC__gelderland__tmp1__html_path,
	map__WD__gelderland__tmp1__html_path,
	map__s1__gelderland__tmp1__html_path,
	# gelderland min HR
	map__AO__gelderland_minHR__tmp1__html_path,
	map__FC__gelderland_minHR__tmp1__html_path,
	map__WD__gelderland_minHR__tmp1__html_path,
	map__s1__gelderland_minHR__tmp1__html_path,
	# website
	map__AO__website__tmp1__html_path,
	map__FC__website__tmp1__html_path,
	map__WD__website__tmp1__html_path,
	map__s1__website__tmp1__html_path,
	# website plus HR
	map__AO__website_plusHR__tmp1__html_path,
	map__FC__website_plusHR__tmp1__html_path,
	map__WD__website_plusHR__tmp1__html_path,
	map__s1__website_plusHR__tmp1__html_path,


    # --- IDX dfs ---
    # AO tmp0
    idx__AO__division__gelderland__tmp0__df_path,
    idx__AO__division__gelderland_minHR__tmp0__df_path,
    idx__AO__division__website__tmp0__df_path,
    idx__AO__division__website_plusHR__tmp0__df_path,
    # AO tmp1
    idx__AO__division__gelderland__tmp1__df_path,
    idx__AO__division__gelderland_minHR__tmp1__df_path,
    idx__AO__division__website__tmp1__df_path,
    idx__AO__division__website_plusHR__tmp1__df_path,
    # HB tmp1
    idx__HB__division__gelderland__tmp1__df_path,
    idx__HB__division__gelderland_minHR__tmp1__df_path,
    idx__HB__division__website__tmp1__df_path,
    idx__HB__division__website_plusHR__tmp1__df_path,
    # FC tmp1
    idx__FC__division__gelderland__tmp1__df_path,
    idx__FC__division__gelderland_minHR__tmp1__df_path,
    idx__FC__division__website__tmp1__df_path,
    idx__FC__division__website_plusHR__tmp1__df_path,
    # WD tmp1
    idx__WD__division__gelderland__tmp1__df_path,
    idx__WD__division__gelderland_minHR__tmp1__df_path,
    idx__WD__division__website__tmp1__df_path,
    idx__WD__division__website_plusHR__tmp1__df_path,
    # s1 tmp1
    idx__s1__division__gelderland__tmp1__df_path,
    idx__s1__division__gelderland_minHR__tmp1__df_path,
    idx__s1__division__website__tmp1__df_path,
    idx__s1__division__website_plusHR__tmp1__df_path,


    # --- Veluwe Polygons ---
    veluwe_polygon__n2000__WGS84__gpkg_path,
    veluwe_polygon__ruim__WGS84__gpkg_path,
    veluwe_polygon__aoi__WGS84__gpkg_path,


    # --- LGN Veluwe clip ruim Maps ---    
    lgn2018__ruim__clip__WGS84__rstr_path,
    lgn2019__ruim__clip__WGS84__rstr_path,
    lgn2020__ruim__clip__WGS84__rstr_path,
    lgn2021__ruim__clip__WGS84__rstr_path,
    lgn2022__ruim__clip__WGS84__rstr_path,
    lgn2023__ruim__clip__WGS84__rstr_path,
    lgn2024__ruim__clip__WGS84__rstr_path,


    # --- LGN reference dfs ---
    lgn2018_reference__df_path,
    lgn2019_reference__df_path,
    lgn2020_reference__df_path,
    lgn2021_reference__df_path,
    lgn2022_reference__df_path,
    lgn2023_reference__df_path,
    lgn2024_reference__df_path,


    # --- Selection reference dfs ---
    habitat_reference__HB__df_path,
    habitat_reference__s__df_path,
)

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import folium

# %% [markdown]
# ## Importing files

# %%
# --- Habitat kart Processed GPKGs ---
habitat_kart_cols_to_keep = ['habitatnaam_1_disp', 'geometry']

# Gelderland 
habitat_kart__processed__gelderland__WGS84__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__gelderland__WGS84__gpkg_path,
    layer='habitat_kart__processed__gelderland__WGS84__layer',
    index_col='index',
    cols_to_keep=habitat_kart_cols_to_keep,
)

# Gelderland min hr 
habitat_kart__processed__gelderland_minHR__WGS84__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__gelderland_minHR__WGS84__gpkg_path,
    layer='habitat_kart__processed__gelderland_minHR__WGS84__layer',
    index_col='index',
    cols_to_keep=habitat_kart_cols_to_keep,
)

# Website 
habitat_kart__processed__website__WGS84__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__website__WGS84__gpkg_path,
    layer='habitat_kart__processed__website__WGS84__layer',
    index_col='index',
    cols_to_keep=habitat_kart_cols_to_keep,
)

# Website plus hr 
habitat_kart__processed__website_plusHR__WGS84__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__website_plusHR__WGS84__gpkg_path,
    layer='habitat_kart__processed__website_plusHR__WGS84__layer',
    index_col='index',
    cols_to_keep=habitat_kart_cols_to_keep,
)

# %%
# --- IDX dfs ---
# AO tmp0 IDX
idx__AO__division__gelderland__tmp0__df = pd.read_pickle(idx__AO__division__gelderland__tmp0__df_path)
idx__AO__division__gelderland_minHR__tmp0__df = pd.read_pickle(idx__AO__division__gelderland_minHR__tmp0__df_path)
idx__AO__division__website__tmp0__df = pd.read_pickle(idx__AO__division__website__tmp0__df_path)
idx__AO__division__website_plusHR__tmp0__df = pd.read_pickle(idx__AO__division__website_plusHR__tmp0__df_path)

# AO tmp1 IDX
idx__AO__division__gelderland__tmp1__df = pd.read_pickle(idx__AO__division__gelderland__tmp1__df_path)
idx__AO__division__gelderland_minHR__tmp1__df = pd.read_pickle(idx__AO__division__gelderland_minHR__tmp1__df_path)
idx__AO__division__website__tmp1__df = pd.read_pickle(idx__AO__division__website__tmp1__df_path)
idx__AO__division__website_plusHR__tmp1__df = pd.read_pickle(idx__AO__division__website_plusHR__tmp1__df_path)

# HB tmp1 IDX
idx__HB__division__gelderland__tmp1__df = pd.read_pickle(idx__HB__division__gelderland__tmp1__df_path)
idx__HB__division__gelderland_minHR__tmp1__df = pd.read_pickle(idx__HB__division__gelderland_minHR__tmp1__df_path)
idx__HB__division__website__tmp1__df = pd.read_pickle(idx__HB__division__website__tmp1__df_path)
idx__HB__division__website_plusHR__tmp1__df = pd.read_pickle(idx__HB__division__website_plusHR__tmp1__df_path)

# FC tmp1 IDX
idx__FC__division__gelderland__tmp1__df = pd.read_pickle(idx__FC__division__gelderland__tmp1__df_path)
idx__FC__division__gelderland_minHR__tmp1__df = pd.read_pickle(idx__FC__division__gelderland_minHR__tmp1__df_path)
idx__FC__division__website__tmp1__df = pd.read_pickle(idx__FC__division__website__tmp1__df_path)
idx__FC__division__website_plusHR__tmp1__df = pd.read_pickle(idx__FC__division__website_plusHR__tmp1__df_path)

# WD tmp1 IDX
idx__WD__division__gelderland__tmp1__df = pd.read_pickle(idx__WD__division__gelderland__tmp1__df_path)
idx__WD__division__gelderland_minHR__tmp1__df = pd.read_pickle(idx__WD__division__gelderland_minHR__tmp1__df_path)
idx__WD__division__website__tmp1__df = pd.read_pickle(idx__WD__division__website__tmp1__df_path)
idx__WD__division__website_plusHR__tmp1__df = pd.read_pickle(idx__WD__division__website_plusHR__tmp1__df_path)

# s1 tmp1 IDX
idx__s1__division__gelderland__tmp1__df = pd.read_pickle(idx__s1__division__gelderland__tmp1__df_path)
idx__s1__division__gelderland_minHR__tmp1__df = pd.read_pickle(idx__s1__division__gelderland_minHR__tmp1__df_path)
idx__s1__division__website__tmp1__df = pd.read_pickle(idx__s1__division__website__tmp1__df_path)
idx__s1__division__website_plusHR__tmp1__df = pd.read_pickle(idx__s1__division__website_plusHR__tmp1__df_path)

# %%
# --- Veluwe Polygons ---
veluwe_polygon__n2000__WGS84__gdf = import_gpkg_func(
    gdf_path=veluwe_polygon__n2000__WGS84__gpkg_path,
    layer='natura2000',
)

veluwe_polygon__ruim__WGS84__gdf = import_gpkg_func(
    gdf_path=veluwe_polygon__ruim__WGS84__gpkg_path,
    layer='ruime_veluwe_cut_WGS84',
)

veluwe_polygon__aoi__WGS84__gdf = import_gpkg_func(
    gdf_path=veluwe_polygon__aoi__WGS84__gpkg_path,
    layer='vennen_interesse_WSG84',
    cols_to_keep=['Naam', 'geometry'],
)

# %%
# --- LGN files ---
lgn__ruim__clip__WGS84__rstr_template = """
lgn{year}__ruim__clip__WGS84__rstr = import_raster_func(
    path=lgn{year}__ruim__clip__WGS84__rstr_path,
    band=None, 
    masked=True, 
    return_meta=True
)
"""

batch_func(years_2018_2024, lgn__ruim__clip__WGS84__rstr_template, globals())

# %%
# --- LGN classes dfs ---
lgn_reference__df_template = """
lgn{year}_reference__df = pd.read_pickle(lgn{year}_reference__df_path)
"""

batch_func(years_2018_2024, lgn_reference__df_template, globals())

# %%
# --- Selection reference dfs ---
habitat_reference__HB__df = pd.read_pickle(habitat_reference__HB__df_path)
habitat_reference__s1__df = pd.read_pickle(habitat_reference__s1__df_path)

# %% [markdown]
# ## Achtergrond polygonen

# %%
## PDOK WMS background layer
map_background__pdok_wms__layer = folium.raster_layers.WmsTileLayer(
    url="https://service.pdok.nl/hwh/luchtfotorgb/wms/v1_0",
    layers="Actueel_ortho25",
    name="PDOK Luchtfoto RGB",
    fmt="image/png",
    transparent=True,
    attr="PDOK",
    overlay=True,           
    control=True,
    show=True                
)

# %%
# Groene Veluwe Polygon
map_polygon__veluwe_n2000_boundary__layer = folium.GeoJson(
    veluwe_polygon__n2000__WGS84__gdf,
    name="Veluwe",
    style_function=lambda x: {
        'fillColor': 'transparent',
        'color': '#14c231',
        'weight': 2,
        'fillOpacity': 0
    }
)

# %%
# Zwarte Veluwe Polygon
map_polygon__veluwe_n2000_black__layer = folium.GeoJson(
    veluwe_polygon__n2000__WGS84__gdf,
    name="Veluwe",
    style_function=lambda x: {
        'fillColor': 'transparent',
        'color': "#000000",
        'weight': 2,
        'fillOpacity': 0
    }
)

# %%
# Witte Veluwe
map_polygon__veluwe_n2000_white__layer = folium.GeoJson(
    veluwe_polygon__n2000__WGS84__gdf,
    name="Veluwe Neutral",
    style_function=lambda x: {
        'fillColor': "#ffffff",
        'color': "#ffffff",
        'weight': 2,
        'fillOpacity': 1
    }
)

# %%
# Vennnen van interesse
map_polygon__veluwe_aoi_boundary__layer = folium.GeoJson(
    veluwe_polygon__aoi__WGS84__gdf,
    name="Interessegebieden",
    style_function=lambda x: {
        'fillColor': 'transparent',
        'color': "#ff0000",
        'weight': 2,
        'fillOpacity': 0
    },
    tooltip=folium.GeoJsonTooltip(fields=["Naam"])
)

# %% [markdown]
# ## Legends

# %%
legend__basis_map__html = create_collapsible_legend(legend_id="legend__basis_map", show_veluwe='True',
                                             show_areas_of_interest='True')

# %%
legend__lgn_map__html = create_collapsible_legend(lgn2018_reference__df, item_col='class', color_col='hexa',
                                           legend_id="lengend__lgn_map", show_veluwe='True',
                                           show_veluwe_neutral='True', show_areas_of_interest='True')

# %%
legend__HB__html = create_collapsible_legend(habitat_reference__HB__df, item_col='habitatnaam_disp', 
                                            color_col='habitat_color', legend_id="legend__HB", 
                                            show_veluwe_neutral='True', show_areas_of_interest='True')

# %%
legend__WD__html = create_collapsible_legend(habitat_reference__HB__df, item_col='WD_division', color_col='WD_color',
                                             legend_id="legend__WD", show_veluwe_neutral='True',
                                             show_areas_of_interest='True')

# %%
legend__s1__html = create_collapsible_legend(habitat_reference__s1__df, item_col='habitatnaam_disp',
                                            color_col='habitat_color', legend_id="S1_legend",
                                            show_veluwe_neutral='True', show_areas_of_interest='True')

# %% [markdown]
# ## Basiskaart

# %%
veluwe_coordinates = [52.2, 5.8]

map__basis__html = folium.Map(location=veluwe_coordinates, zoom_start=10)
map_background__pdok_wms__layer.add_to(map__basis__html)
map_polygon__veluwe_n2000_boundary__layer.add_to(map__basis__html)
map_polygon__veluwe_aoi_boundary__layer.add_to(map__basis__html)
map__basis__html.get_root().add_child(legend__basis_map__html);

# %%
folium.LayerControl(position='topright').add_to(map__basis__html)
add_recenter_button(map__basis__html, center=veluwe_coordinates, zoom=10)

map__basis__html.save(map__basis__html_path)

# %% [markdown]
# ## LGN kaart

# %%
map__lgn__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__lgn__html)
map_polygon__veluwe_n2000_boundary__layer.add_to(map__lgn__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__lgn__html)
map_polygon__veluwe_aoi_boundary__layer.add_to(map__lgn__html)
map__lgn__html.get_root().add_child(legend__lgn_map__html);

# %%
lgn__ruim__clip__WGS84__layer_template = """
lgn{year}__ruim__clip__WGS84__layer = rstr_to_folium_layer(
    lgn{year}__ruim__clip__WGS84__rstr,
    lgn{year}_reference__df,
    name="LGN {year}",
    downsample=1,
    nodata=0,
    default_alpha=180,
    show=False,
    control=True,
    validate_bounds=True
)

lgn{year}__ruim__clip__WGS84__layer.add_to(map__lgn__html);
"""

batch_func(years_2018_2024, lgn__ruim__clip__WGS84__layer_template, globals())

# %%
folium.LayerControl(position='topright').add_to(map__lgn__html)
add_recenter_button(map__lgn__html, center=veluwe_coordinates, zoom=10)
map__lgn__html.save(map__lgn__html_path)

# %% [markdown]
# ## Gelderland Maps

# %% [markdown]
# ### -> Gel AO TMP 1

# %%
# Creating map AO tmp1 Gelderland
map__AO__gelderland__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__AO__gelderland__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__AO__gelderland__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__AO__gelderland__tmp1__html,
    layer_index_df=idx__AO__division__gelderland__tmp1__df,
    geometries_gdf=habitat_kart__processed__gelderland__WGS84__gdf,
    legend_df=habitat_reference__HB__df,
    label_scheme="Habitat",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__AO__gelderland__tmp1__html)
map__AO__gelderland__tmp1__html.get_root().add_child(legend__HB__html);

# %%
folium.LayerControl(position='topright').add_to(map__AO__gelderland__tmp1__html)
add_recenter_button(map__AO__gelderland__tmp1__html, center=veluwe_coordinates, zoom=10)
map__AO__gelderland__tmp1__html.save(map__AO__gelderland__tmp1__html_path)

# %%
# Creating map AO tmp1 Gelderland minHR
map__AO__gelderland_minHR__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__AO__gelderland_minHR__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__AO__gelderland_minHR__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__AO__gelderland_minHR__tmp1__html,
    layer_index_df=idx__AO__division__gelderland_minHR__tmp1__df,
    geometries_gdf=habitat_kart__processed__gelderland_minHR__WGS84__gdf,
    legend_df=habitat_reference__HB__df,
    label_scheme="Habitat",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__AO__gelderland_minHR__tmp1__html)
map__AO__gelderland_minHR__tmp1__html.get_root().add_child(legend__HB__html);

# %%
folium.LayerControl(position='topright').add_to(map__AO__gelderland_minHR__tmp1__html)
add_recenter_button(map__AO__gelderland_minHR__tmp1__html, center=veluwe_coordinates, zoom=10)
map__AO__gelderland_minHR__tmp1__html.save(map__AO__gelderland_minHR__tmp1__html_path)

# %% [markdown]
# ### -> Gel FC TMP 1

# %%
# Creating map FC tmp1 Gelderland
map__FC__gelderland__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__FC__gelderland__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__FC__gelderland__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__FC__gelderland__tmp1__html,
    layer_index_df=idx__FC__division__gelderland__tmp1__df,
    geometries_gdf=habitat_kart__processed__gelderland__WGS84__gdf,
    legend_df=habitat_reference__HB__df,
    label_scheme="Habitat",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__FC__gelderland__tmp1__html)
map__FC__gelderland__tmp1__html.get_root().add_child(legend__HB__html);

# %%
folium.LayerControl(position='topright').add_to(map__FC__gelderland__tmp1__html)
add_recenter_button(map__FC__gelderland__tmp1__html, center=veluwe_coordinates, zoom=10)
map__FC__gelderland__tmp1__html.save(map__FC__gelderland__tmp1__html_path)

# %%
# Creating map FC tmp1 Gelderland minHR
map__FC__gelderland_minHR__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__FC__gelderland_minHR__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__FC__gelderland_minHR__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__FC__gelderland_minHR__tmp1__html,
    layer_index_df=idx__FC__division__gelderland_minHR__tmp1__df,
    geometries_gdf=habitat_kart__processed__gelderland_minHR__WGS84__gdf,
    legend_df=habitat_reference__HB__df,
    label_scheme="Habitat",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__FC__gelderland_minHR__tmp1__html)
map__FC__gelderland_minHR__tmp1__html.get_root().add_child(legend__HB__html);

# %%
folium.LayerControl(position='topright').add_to(map__FC__gelderland_minHR__tmp1__html)
add_recenter_button(map__FC__gelderland_minHR__tmp1__html, center=veluwe_coordinates, zoom=10)
map__FC__gelderland_minHR__tmp1__html.save(map__FC__gelderland_minHR__tmp1__html_path)

# %% [markdown]
# ### -> Gel WD TMP 1

# %%
# Creating map WD tmp1 Gelderland
map__WD__gelderland__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__WD__gelderland__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__WD__gelderland__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__WD__gelderland__tmp1__html,
    layer_index_df=idx__WD__division__gelderland__tmp1__df,
    geometries_gdf=habitat_kart__processed__gelderland__WGS84__gdf,
    legend_df=habitat_reference__HB__df,
    label_scheme="WD-div",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__WD__gelderland__tmp1__html)
map__WD__gelderland__tmp1__html.get_root().add_child(legend__WD__html);

# %%
folium.LayerControl(position='topright').add_to(map__WD__gelderland__tmp1__html)
add_recenter_button(map__WD__gelderland__tmp1__html, center=veluwe_coordinates, zoom=10)
map__WD__gelderland__tmp1__html.save(map__WD__gelderland__tmp1__html_path)

# %%
# Creating map WD tmp1 Gelderland minHR
map__WD__gelderland_minHR__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__WD__gelderland_minHR__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__WD__gelderland_minHR__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__WD__gelderland_minHR__tmp1__html,
    layer_index_df=idx__WD__division__gelderland_minHR__tmp1__df,
    geometries_gdf=habitat_kart__processed__gelderland_minHR__WGS84__gdf,
    legend_df=habitat_reference__HB__df,
    label_scheme="WD-div",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__WD__gelderland_minHR__tmp1__html)
map__WD__gelderland_minHR__tmp1__html.get_root().add_child(legend__WD__html);

# %%
folium.LayerControl(position='topright').add_to(map__WD__gelderland_minHR__tmp1__html)
add_recenter_button(map__WD__gelderland_minHR__tmp1__html, center=veluwe_coordinates, zoom=10)
map__WD__gelderland_minHR__tmp1__html.save(map__WD__gelderland_minHR__tmp1__html_path)

# %% [markdown]
# ### Gel S1 TMP 1

# %%
# Creating map FC tmp1 Gelderland
map__s1__gelderland__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__s1__gelderland__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__s1__gelderland__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__s1__gelderland__tmp1__html,
    layer_index_df=idx__s1__division__gelderland__tmp1__df,
    geometries_gdf=habitat_kart__processed__gelderland__WGS84__gdf,
    legend_df=habitat_reference__s1__df,
    label_scheme="Habitat",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__s1__gelderland__tmp1__html)
map__s1__gelderland__tmp1__html.get_root().add_child(legend__s1__html);

# %%
folium.LayerControl(position='topright').add_to(map__s1__gelderland__tmp1__html)
add_recenter_button(map__s1__gelderland__tmp1__html, center=veluwe_coordinates, zoom=10)
map__s1__gelderland__tmp1__html.save(map__s1__gelderland__tmp1__html_path)

# %%
# Creating map FC tmp1 Gelderland
map__s1__gelderland_minHR__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__s1__gelderland_minHR__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__s1__gelderland_minHR__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__s1__gelderland_minHR__tmp1__html,
    layer_index_df=idx__s1__division__gelderland_minHR__tmp1__df,
    geometries_gdf=habitat_kart__processed__gelderland_minHR__WGS84__gdf,
    legend_df=habitat_reference__s1__df,
    label_scheme="Habitat",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__s1__gelderland_minHR__tmp1__html)
map__s1__gelderland_minHR__tmp1__html.get_root().add_child(legend__s1__html);

# %%
folium.LayerControl(position='topright').add_to(map__s1__gelderland_minHR__tmp1__html)
add_recenter_button(map__s1__gelderland_minHR__tmp1__html, center=veluwe_coordinates, zoom=10)
map__s1__gelderland_minHR__tmp1__html.save(map__s1__gelderland_minHR__tmp1__html_path)

# %% [markdown]
# ## Website

# %% [markdown]
# ### -> Webs AO TMP 1

# %%
# Creating map AO tmp1 Website
map__AO__website__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__AO__website__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__AO__website__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__AO__website__tmp1__html,
    layer_index_df=idx__AO__division__website__tmp1__df,
    geometries_gdf=habitat_kart__processed__website__WGS84__gdf,
    legend_df=habitat_reference__HB__df,
    label_scheme="Habitat",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__AO__website__tmp1__html)
map__AO__website__tmp1__html.get_root().add_child(legend__HB__html);

# %%
folium.LayerControl(position='topright').add_to(map__AO__website__tmp1__html)
add_recenter_button(map__AO__website__tmp1__html, center=veluwe_coordinates, zoom=10)
map__AO__website__tmp1__html.save(map__AO__website__tmp1__html_path)

# %%
# Creating map AO tmp1 Website_plusHR
map__AO__website_plusHR__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__AO__website_plusHR__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__AO__website_plusHR__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__AO__website_plusHR__tmp1__html,
    layer_index_df=idx__AO__division__website_plusHR__tmp1__df,
    geometries_gdf=habitat_kart__processed__website_plusHR__WGS84__gdf,
    legend_df=habitat_reference__HB__df,
    label_scheme="Habitat",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__AO__website_plusHR__tmp1__html)
map__AO__website_plusHR__tmp1__html.get_root().add_child(legend__HB__html);

# %%
folium.LayerControl(position='topright').add_to(map__AO__website_plusHR__tmp1__html)
add_recenter_button(map__AO__website_plusHR__tmp1__html, center=veluwe_coordinates, zoom=10)
map__AO__website_plusHR__tmp1__html.save(map__AO__website_plusHR__tmp1__html_path)

# %% [markdown]
# ### -> Webs FC TMP 1

# %%
# Creating map FC tmp1 Website
map__FC__website__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__FC__website__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__FC__website__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__FC__website__tmp1__html,
    layer_index_df=idx__FC__division__website__tmp1__df,
    geometries_gdf=habitat_kart__processed__website__WGS84__gdf,
    legend_df=habitat_reference__HB__df,
    label_scheme="Habitat",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__FC__website__tmp1__html)
map__FC__website__tmp1__html.get_root().add_child(legend__HB__html);

# %%
folium.LayerControl(position='topright').add_to(map__FC__website__tmp1__html)
add_recenter_button(map__FC__website__tmp1__html, center=veluwe_coordinates, zoom=10)
map__FC__website__tmp1__html.save(map__FC__website__tmp1__html_path)

# %%
# Creating map FC tmp1 Website_plusHR
map__FC__website_plusHR__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__FC__website_plusHR__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__FC__website_plusHR__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__FC__website_plusHR__tmp1__html,
    layer_index_df=idx__FC__division__website_plusHR__tmp1__df,
    geometries_gdf=habitat_kart__processed__website_plusHR__WGS84__gdf,
    legend_df=habitat_reference__HB__df,
    label_scheme="Habitat",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__FC__website_plusHR__tmp1__html)
map__FC__website_plusHR__tmp1__html.get_root().add_child(legend__HB__html);

# %%
folium.LayerControl(position='topright').add_to(map__FC__website_plusHR__tmp1__html)
add_recenter_button(map__FC__website_plusHR__tmp1__html, center=veluwe_coordinates, zoom=10)
map__FC__website_plusHR__tmp1__html.save(map__FC__website_plusHR__tmp1__html_path)

# %% [markdown]
# ### -> Webs WD TMP 1

# %%
# Creating map WD tmp1 Website
map__WD__website__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__WD__website__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__WD__website__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__WD__website__tmp1__html,
    layer_index_df=idx__WD__division__website__tmp1__df,
    geometries_gdf=habitat_kart__processed__website__WGS84__gdf,
    legend_df=habitat_reference__HB__df,
    label_scheme="WD-div",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__WD__website__tmp1__html)
map__WD__website__tmp1__html.get_root().add_child(legend__WD__html);

# %%
folium.LayerControl(position='topright').add_to(map__WD__website__tmp1__html)
add_recenter_button(map__WD__website__tmp1__html, center=veluwe_coordinates, zoom=10)
map__WD__website__tmp1__html.save(map__WD__website__tmp1__html_path)

# %%
# Creating map WD tmp1 website_plusHR
map__WD__website_plusHR__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__WD__website_plusHR__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__WD__website_plusHR__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__WD__website_plusHR__tmp1__html,
    layer_index_df=idx__WD__division__website_plusHR__tmp1__df,
    geometries_gdf=habitat_kart__processed__website_plusHR__WGS84__gdf,
    legend_df=habitat_reference__HB__df,
    label_scheme="WD-div",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__WD__website_plusHR__tmp1__html)
map__WD__website_plusHR__tmp1__html.get_root().add_child(legend__WD__html);

# %%
folium.LayerControl(position='topright').add_to(map__WD__website_plusHR__tmp1__html)
add_recenter_button(map__WD__website_plusHR__tmp1__html, center=veluwe_coordinates, zoom=10)
map__WD__website_plusHR__tmp1__html.save(map__WD__website_plusHR__tmp1__html_path)

# %% [markdown]
# ### -> Webs S1 TMP 1

# %%
# Creating map FC tmp1 website
map__s1__website__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__s1__website__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__s1__website__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__s1__website__tmp1__html,
    layer_index_df=idx__s1__division__website__tmp1__df,
    geometries_gdf=habitat_kart__processed__website__WGS84__gdf,
    legend_df=habitat_reference__s1__df,
    label_scheme="Habitat",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__s1__website__tmp1__html)
map__s1__website__tmp1__html.get_root().add_child(legend__s1__html);

# %%
folium.LayerControl(position='topright').add_to(map__s1__website__tmp1__html)
add_recenter_button(map__s1__website__tmp1__html, center=veluwe_coordinates, zoom=10)
map__s1__website__tmp1__html.save(map__s1__website__tmp1__html_path)

# %%
# Creating map FC tmp1 website_plusHR
map__s1__website_plusHR__tmp1__html = folium.Map(location=veluwe_coordinates, zoom_start=10)

map_background__pdok_wms__layer.add_to(map__s1__website_plusHR__tmp1__html)
map_polygon__veluwe_n2000_white__layer.add_to(map__s1__website_plusHR__tmp1__html)
idx_df_to_folium_layers(
    folium_map=map__s1__website_plusHR__tmp1__html,
    layer_index_df=idx__s1__division__website_plusHR__tmp1__df,
    geometries_gdf=habitat_kart__processed__website_plusHR__WGS84__gdf,
    legend_df=habitat_reference__s1__df,
    label_scheme="Habitat",
)

map_polygon__veluwe_aoi_boundary__layer.add_to(map__s1__website_plusHR__tmp1__html)
map__s1__website_plusHR__tmp1__html.get_root().add_child(legend__s1__html);

# %%
folium.LayerControl(position='topright').add_to(map__s1__website_plusHR__tmp1__html)
add_recenter_button(map__s1__website_plusHR__tmp1__html, center=veluwe_coordinates, zoom=10)
map__s1__website_plusHR__tmp1__html.save(map__s1__website_plusHR__tmp1__html_path)

# %% [markdown]
# End of the Notebook
