# %% [markdown]
# _This notebook builds the Heatmap visualizations on the accuracy and the F1 scores for the habitat classifications._

# %% [markdown]
# # General

# %% [markdown]
# ## Importing functions

# %%
from notebooks_dir._05_output_validation._support._n02_full_workflow import (
    make_and_save_carto_performance_heatmap,
    make_and_save_RF_year_avg_performance_heatmap,
    make_and_save_RF_timeframe_performance_heatmap,
)

# %% [markdown]
# ## Setting Directory

# %%
from paths.OG_paths import(
    #######################################
    #            00_common_dfs            #
    #######################################
    # |    n01_habitat_reference_dfs      |
    # +===================================+ 
    habitat_reference__WD__df_path,
    habitat_reference__s__df_path,
    habitat_reference__UC__df_path,
    habitat_reference__WDNF__df_path,
    
    #######################################
    #        04_ML_classification         #
    #######################################
    # |  n01_random_forest_s2_quarterly   |
    # +===================================+
    # --- RF model output --- #
    RF_out__UTM32631__rstrs_dir,
    
    #########################################
    #          05_output_validation         #
    #########################################
    # |    n02_carto_RF_results_comp_df     |
    # +=====================================+
    # DIRs
    carto_output_result_dfs__dir,
    carto_heatmaps__dir,
    RF_heatmaps__dir,
)

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing files

# %%
habitat_reference__WD__df = pd.read_pickle(habitat_reference__WD__df_path)
habitat_reference__s__df = pd.read_pickle(habitat_reference__s__df_path)
habitat_reference__UC__df = pd.read_pickle(habitat_reference__UC__df_path)
habitat_reference__WDNF__df = pd.read_pickle(habitat_reference__WDNF__df_path)

# %%
years_list = ['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %% [markdown]
# # Classification performance visualisation

# %% [markdown]
# ## WD1

# %% [markdown]
# ### WD1 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="WD1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ### WD1 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WD1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WD1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WD1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### WD1 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WD1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WD1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WD1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## WD2

# %% [markdown]
# ### WD2 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="WD2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
)
plt.show()

# %% [markdown]
# ### WD2 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WD2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WD2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WD2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### WD2 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WD2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WD2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WD2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## WD3

# %% [markdown]
# ### WD3 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="WD3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
)
plt.show()

# %% [markdown]
# ### WD3 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WD3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WD3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WD3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### WD3 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WD3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WD3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WD3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## WD4

# %% [markdown]
# ### WD4 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="WD4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ### WD4 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WD4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WD4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WD4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### WD4 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WD4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WD4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WD4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## WD5

# %% [markdown]
# ### WD5 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="WD5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ### WD5 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WD5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WD5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WD5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### WD5 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WD5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WD5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WD5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## WD6

# %% [markdown]
# ### WD6 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="WD6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ### WD6 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WD6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WD6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WD6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### WD6 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WD6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WD6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WD6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WD6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WD__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## S1

# %% [markdown]
# ### S1 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="s1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ### S1 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="s1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="s1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="s1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="s1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### S1 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="s1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="s1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="s1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="s1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## S2

# %% [markdown]
# ### S2 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="s2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ### S2 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="s2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="s2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="s2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="s2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### S2 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="s2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="s2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="s2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="s2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## S3

# %% [markdown]
# ### S3 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="s3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ### S3 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="s3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="s3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="s3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="s3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### S3 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="s3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="s3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="s3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="s3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__s__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## UC1 at1 (2+1 clustering)

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="UC1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__UC__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ## UC3 at2 (3+1 clustering)

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="UC3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__UC__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ## UC5 at1 (2+1 clustering)

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="UC5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__UC__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ## WDNF1

# %% [markdown]
# ### WDNF1 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="WDNF1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ### WDNF1 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WDNF1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WDNF1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WDNF1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WDNF1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### WDNF1 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WDNF1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WDNF1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WDNF1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WDNF1",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## WDNF2

# %% [markdown]
# ### WDNF2 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="WDNF2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
)
plt.show()

# %% [markdown]
# ### WDNF2 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WDNF2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WDNF2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WDNF2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WDNF2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### WDNF2 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WDNF2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WDNF2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WDNF2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WDNF2",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## WDNF3

# %% [markdown]
# ### WDNF3 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="WDNF3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
)
plt.show()

# %% [markdown]
# ### WDNF3 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WDNF3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WDNF3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WDNF3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WDNF3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### WD3 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WDNF3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WDNF3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WDNF3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WDNF3",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## WDNF4

# %% [markdown]
# ### WDNF4 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="WDNF4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ### WDNF4 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WDNF4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WDNF4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WDNF4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WDNF4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### WDNF4 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WDNF4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WDNF4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WDNF4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WDNF4",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## WDNF5

# %% [markdown]
# ### WDNF5 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="WDNF5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ### WDNF5 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WDNF5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WDNF5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WDNF5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WDNF5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### WDNF5 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WDNF5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WDNF5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WDNF5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WDNF5",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ## WDNF6

# %% [markdown]
# ### WDNF6 - Carto

# %%
fig = make_and_save_carto_performance_heatmap(
    carto_results_dfs_dir=carto_output_result_dfs__dir,
    carto_heatmaps_dir=carto_heatmaps__dir,
    hab_selection="WDNF6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)
plt.show()

# %% [markdown]
# ### WDNF6 - RF year average

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WDNF6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WDNF6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WDNF6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
fig = make_and_save_RF_year_avg_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WDNF6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# ### WDNF6 - RF quartal results

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348",
    hab_selection="WDNF6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwi",
    hab_selection="WDNF6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b2348s1",
    hab_selection="WDNF6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %%
figs = make_and_save_RF_timeframe_performance_heatmap(
    RF_results__dir=RF_out__UTM32631__rstrs_dir,
    RF_heatmaps_dir=RF_heatmaps__dir,
    train_year="2017-2024",
    model_selection="mdl1",
    band_selection="b28ndvwis1",
    hab_selection="WDNF6",
    train_split_attempt="at1",
    habitat_reference_df=habitat_reference__WDNF__df,
    years=years_list,
    overwrite=False,
    dpi=300,
)

# %% [markdown]
# End of the Notebook
