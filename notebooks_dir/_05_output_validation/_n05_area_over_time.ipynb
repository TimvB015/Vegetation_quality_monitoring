# %% [markdown]
# _This Notebook generates the area barplots over time_

# %% [markdown]
# # General

# %%
from paths.OG_paths import(
    #######################################
    #            00_common_dfs            #
    #######################################
    # |    n01_habitat_reference_dfs      |
    # +===================================+
    habitat_reference__WD__df_path,
    habitat_reference__s__df_path,
    habitat_reference__WDNF__df_path,
    veluwe_polygon__subaoi__UTM32631__gpkg_path,
    area_over_time__dir,
    RF_out__UTM32631__rstrs_dir,
)

# %%
from notebooks_dir._05_output_validation._support._n05_funcs import (
    carto_area_plot_over_time_workflow,
    RF_area_plot_quarterly_workflow,
)

# %%
from matplotlib import pyplot as plt
import pandas as pd
import geopandas as gpd

# %%
veluwe_polygon__subaoi__UTM32631__gpkg_path

# %%
habitat_reference__WD__df = pd.read_pickle(habitat_reference__WD__df_path)
habitat_reference__s__df = pd.read_pickle(habitat_reference__s__df_path)
habitat_reference__WDNF__df = pd.read_pickle(habitat_reference__WDNF__df_path)
veluwe_plot_windows__gdf = gpd.read_file(veluwe_polygon__subaoi__UTM32631__gpkg_path)

# %%
veluwe_plot_windows__gdf

# %%
all_years = [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
sub_years = [2021, 2022, 2023, 2024]

# %% [markdown]
# # Carto

# %%
hab_div = {
    0: ['s1', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\s1_at1_gelderland_stacked_rstrs.tif", habitat_reference__s__df[['s1_division','s1_color']]],
    1: ['s2', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\s2_at1_gelderland_stacked_rstrs.tif", habitat_reference__s__df[['s2_division','s2_color']]],
    2: ['s3', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\s3_at1_gelderland_stacked_rstrs.tif", habitat_reference__s__df[['s3_division','s3_color']]],
    3: ['WD1', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\WD1_at1_gelderland_stacked_rstrs.tif", habitat_reference__WD__df[['WD1_division','WD1_color']]],
    4: ['WD2', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\WD2_at1_gelderland_stacked_rstrs.tif", habitat_reference__WD__df[['WD2_division','WD2_color']]],
    5: ['WD3', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\WD3_at1_gelderland_stacked_rstrs.tif", habitat_reference__WD__df[['WD3_division','WD3_color']]],
    6: ['WD4', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\WD4_at1_gelderland_stacked_rstrs.tif", habitat_reference__WD__df[['WD4_division','WD4_color']]],
    7: ['WD5', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\WD5_at1_gelderland_stacked_rstrs.tif", habitat_reference__WD__df[['WD5_division','WD5_color']]],
    8: ['WD6', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\WD6_at1_gelderland_stacked_rstrs.tif", habitat_reference__WD__df[['WD6_division','WD6_color']]],
    9: ['WDNF1', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\WDNF1_at1_gelderland_stacked_rstrs.tif", habitat_reference__WDNF__df[['WDNF1_division','WDNF1_color']]],
    10: ['WDNF2', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\WDNF2_at1_gelderland_stacked_rstrs.tif", habitat_reference__WDNF__df[['WDNF2_division','WDNF2_color']]],
    11: ['WDNF3', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\WDNF3_at1_gelderland_stacked_rstrs.tif", habitat_reference__WDNF__df[['WDNF3_division','WDNF3_color']]],
    12: ['WDNF4', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\WDNF4_at1_gelderland_stacked_rstrs.tif", habitat_reference__WDNF__df[['WDNF4_division','WDNF4_color']]],
    13: ['WDNF5', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\WDNF5_at1_gelderland_stacked_rstrs.tif", habitat_reference__WDNF__df[['WDNF5_division','WDNF5_color']]],
    14: ['WDNF6', r"D:\Thesis\10.Thesis_Data\04_carto_output\02_stacked_rstrs\WDNF6_at1_gelderland_stacked_rstrs.tif", habitat_reference__WDNF__df[['WDNF6_division','WDNF6_color']]],
}

# %%
for i in hab_div.keys():
    carto_area_plot_over_time_workflow(
        hab_div=hab_div,
        hab_selection=i,
        all_years=all_years,
        veluwe_plot_windows__gdf=veluwe_plot_windows__gdf,
        save_dir=area_over_time__dir,
        overwrite=False,
    )

# %% [markdown]
# # RF

# %%
timeframes = ['Q1', 'Q2', 'Q3', 'Q4']

habitat_reference_dfs = {
    's': habitat_reference__s__df,
    'WD': habitat_reference__WD__df,
    'WDNF': habitat_reference__WDNF__df,
}

band_selections = ['b2348', 'b2ndvwi', 'b2348s1', 'b2ndvwis1']

for band_sel in band_selections:
    print(f"\n{'='*50}\nProcessing: {band_sel}\n{'='*50}")
    all_figures = RF_area_plot_quarterly_workflow(
        base_dir=RF_out__UTM32631__rstrs_dir,
        band_selection=band_sel,
        timeframes=timeframes,
        habitat_reference_dfs=habitat_reference_dfs,
        all_years=all_years,
        veluwe_plot_windows__gdf=veluwe_plot_windows__gdf,
        save_dir=area_over_time__dir,
        overwrite=False,
    )

# %% [markdown]
# End of the Notebook
