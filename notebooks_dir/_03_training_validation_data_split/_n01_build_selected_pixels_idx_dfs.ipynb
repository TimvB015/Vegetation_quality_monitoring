# %% [markdown]
# _In the last Notebook (n05_pixelize_hab_kart), the FC p80 tmp2 was pixelized. Using QGIS all pixels were visually checked. This notebook imports the manually selected pixeled GPKG and builds new IDX dfs for the training/validation split._ <br>
#
# _As the Gelderland Habitat kart has been the most reliable so far, this is the only GPKG that I'll work with. The OW file is already added. This notebook wil thus only work with the file *habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gpkg*_

# %% [markdown]
# # General

# %% [markdown]
# ## Importing functions

# %%
from functions.gpkg_funcs import (
    import_gpkg_func,
)

from functions.idx_builder_funcs import (
    tmp_0_idx_df_func,
    HT_idx_df_func,
    group_idx_df_func,

)

from notebooks_dir._03_training_validation_data_split._support._n01_funcs import (
    clean_and_update_inspected_GPKG,
)

# %% [markdown]
# ## Setting Directory

# %%
from paths.OG_paths import(
    #######################################
    #            00_common_dfs            #
    #######################################
    # |    n01_habitat_reference_dfs      |
    # +===================================+ 
    habitat_reference__WD__df_path,
    habitat_reference__s__df_path,
    habitat_reference__WDNF__df_path,

    
    #######################################
    #  03_training_validation_data_split  #
    #######################################
    # | n01_build_selected_pixels_idx_dfs |
    # +===================================+
    # --- manual inspected pixeled gpkg --- #    
    habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gpkg_path,

    # --- selected pixels IDX dfs --- #
    idx__FC_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD1_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD2_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD3_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD4_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD5_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD6_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__s1_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__s2_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__s3_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__FC_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WDNF1_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WDNF2_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WDNF3_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WDNF4_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WDNF5_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WDNF6_plusOW_p80__selected__gelderland__tmp2__df_path,
)

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd

# %% [markdown]
# ## Importing files

# %%
habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gpkg_path, 
    layer='habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__layer', 
    index_col='index',
)

# %%
# --- Selection reference dfs ---
habitat_reference__WD__df = pd.read_pickle(habitat_reference__WD__df_path)
habitat_reference__s__df = pd.read_pickle(habitat_reference__s__df_path)
habitat_reference__WDNF__df = pd.read_pickle(habitat_reference__WDNF__df_path)

# %% [markdown]
# ## Update the columns of the gpkg

# %% [markdown]
# Update the area col

# %%
# habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf = clean_and_update_inspected_GPKG(
#     habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf
# )

# %%
# habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf.to_file(
#     filename=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gpkg_path,
#     layer="habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__layer",
#     driver="GPKG",
# )

# %% [markdown]
# ## IDX FC plusOW p80 selected df

# %%
idx__FC_plusOW_p80__selected__gelderland__tmp2__df, idx__FC_plusOW_p80__selected__gelderland__tmp2__count = tmp_0_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
)

# %%
idx__FC_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__FC_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# # WD-division

# %% [markdown]
# ## IDX WD1 plusOW p80 selected df

# %%
# WD
idx__WD1_plusOW_p80__selected__gelderland__tmp2__df, idx__WD1_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD1_division'
)

# %%
idx__WD1_plusOW_p80__selected__gelderland__tmp2__df
# Out:
# _year_str                                                2017  \
# Remaining   [GI_11616_1, GI_11616_10, GI_11616_11, GI_1161...
# Wet Nature  [GI_41299_1, GI_41299_2, GI_41299_3, GI_41299_...
# Open water                                                 []
#
# _year_str                                                2018  \
# Remaining   [GI_14424_1, GI_14424_10, GI_14424_100, GI_144...
# Wet Nature  [GI_18556_1, GI_18556_10, GI_18556_11, GI_1855...
# Open water  [lgn_plusOW_110_11, lgn_plusOW_110_12, lgn_plu...
#
# _year_str                                                2019  \
# Remaining   [GI_10058_1, GI_10058_2, GI_10058_3, GI_10058_...
# Wet Nature                                                 []
# Open water  [lgn_plusOW_110_11, lgn_plusOW_110_12, lgn_plu...
#
# _year_str                                                2020  \
# Remaining   [GI_10052_4, GI_10052_5, GI_10087_1, GI_10087_...
# Wet Nature  [GI_12951_1, GI_12951_2, GI_12951_3, GI_12951_...
# ...

# %%
idx__WD1_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__WD1_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## IDX WD2 plusOW p80 selected df

# %%
# WD2
idx__WD2_plusOW_p80__selected__gelderland__tmp2__df, idx__WD2_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD2_division'
)

# %%
idx__WD2_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__WD2_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## IDX WD3 plusOW p80 selected df

# %%
# WD3
idx__WD3_plusOW_p80__selected__gelderland__tmp2__df, idx__WD3_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD3_division'
)

# %%
idx__WD3_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__WD3_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## IDX WD4 plusOW p80 selected df

# %%
# WD4
idx__WD4_plusOW_p80__selected__gelderland__tmp2__df, idx__WD4_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD4_division'
)

# %%
idx__WD4_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__WD4_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## IDX WD5 plusOW p80 selected df

# %%
# WD5
idx__WD5_plusOW_p80__selected__gelderland__tmp2__df, idx__WD5_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD5_division'
)

# %%
idx__WD5_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__WD5_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## IDX WD6 plusOW p80 selected df

# %%
# WD6
idx__WD6_plusOW_p80__selected__gelderland__tmp2__df, idx__WD5_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD6_division'
)

# %%
idx__WD6_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__WD6_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# # s-division

# %% [markdown]
# ## IDX s1 plusOW p80 selected df

# %%
# s1
idx__s1_plusOW_p80__selected__gelderland__tmp2__df, idx__s1_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__s__df,
    habitat_col='habitatType1',
    group_col='s1_division'
)

# %%
idx__s1_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__s1_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## IDX s2 plusOW p80 selected df

# %%
# s2
idx__s2_plusOW_p80__selected__gelderland__tmp2__df, idx__s2_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__s__df,
    habitat_col='habitatType1',
    group_col='s2_division'
)

# %%
idx__s2_plusOW_p80__selected__gelderland__tmp2__df
# Out:
# _year_str                                                     2017  \
# Remaining        [GI_11616_1, GI_11616_10, GI_11616_11, GI_1161...
# Ven              [GI_41966_1, GI_41966_10, GI_41966_11, GI_4196...
# Vochtige heiden  [GI_41299_1, GI_41299_2, GI_41299_3, GI_41299_...
# Open water                                                      []
#
# _year_str                                                     2018  \
# Remaining        [GI_14426_1, GI_14426_2, GI_14426_3, GI_14426_...
# Ven              [GI_18556_1, GI_18556_10, GI_18556_11, GI_1855...
# Vochtige heiden  [GI_18984_1, GI_18984_10, GI_18984_11, GI_1898...
# Open water       [lgn_plusOW_110_11, lgn_plusOW_110_12, lgn_plu...
#
# _year_str                                                     2019  \
# Remaining        [GI_10067_10, GI_10067_11, GI_10067_12, GI_100...
# Ven                                                             []
# Vochtige heiden                                                 []
# ...

# %%
idx__s2_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__s2_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## IDX s3 plusOW p80 selected df

# %%
# s3
idx__s3_plusOW_p80__selected__gelderland__tmp2__df, idx__s3_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__s__df,
    habitat_col='habitatType1',
    group_col='s3_division'
)

# %%
idx__s3_plusOW_p80__selected__gelderland__tmp2__df
# Out:
# _year_str                                                     2017  \
# Remaining        [GI_11616_1, GI_11616_10, GI_11616_11, GI_1161...
# Vochtige heiden  [GI_41299_1, GI_41299_2, GI_41299_3, GI_41299_...
# Ven                                                             []
# Open water                                                      []
#
# _year_str                                                     2018  \
# Remaining        [GI_14426_1, GI_14426_2, GI_14426_3, GI_14426_...
# Vochtige heiden  [GI_18984_1, GI_18984_10, GI_18984_11, GI_1898...
# Ven              [GI_18556_1, GI_18556_10, GI_18556_11, GI_1855...
# Open water       [lgn_plusOW_110_11, lgn_plusOW_110_12, lgn_plu...
#
# _year_str                                                     2019  \
# Remaining        [GI_10067_10, GI_10067_11, GI_10067_12, GI_100...
# Vochtige heiden                                                 []
# Ven                                                             []
# ...

# %%
idx__s3_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__s3_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# # WDNF

# %% [markdown]
# ## IDX WDNF1 plusOW p80 selected df

# %%
# WDNF
idx__WDNF1_plusOW_p80__selected__gelderland__tmp2__df, idx__WDNF1_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WDNF__df,
    habitat_col='habitatType1',
    group_col='WDNF1_division'
)

# %%
idx__WDNF1_plusOW_p80__selected__gelderland__tmp2__df
# Out:
# _year_str                                                2017  \
# Remaining   [GI_11616_1, GI_11616_10, GI_11616_11, GI_1161...
# Wet Nature  [GI_41299_1, GI_41299_2, GI_41299_3, GI_41299_...
# Open water                                                 []
#
# _year_str                                                2018  \
# Remaining   [GI_14424_1, GI_14424_10, GI_14424_100, GI_144...
# Wet Nature  [GI_18556_1, GI_18556_10, GI_18556_11, GI_1855...
# Open water  [lgn_plusOW_110_11, lgn_plusOW_110_12, lgn_plu...
#
# _year_str                                                2019  \
# Remaining   [GI_10058_1, GI_10058_2, GI_10058_3, GI_10058_...
# Wet Nature                                                 []
# Open water  [lgn_plusOW_110_11, lgn_plusOW_110_12, lgn_plu...
#
# _year_str                                                2020  \
# Remaining   [GI_10052_4, GI_10052_5, GI_10087_1, GI_10087_...
# Wet Nature  [GI_12951_1, GI_12951_2, GI_12951_3, GI_12951_...
# ...

# %%
idx__WDNF1_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__WDNF1_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## IDX WDNF2 plusOW p80 selected df

# %%
# WDNF2
idx__WDNF2_plusOW_p80__selected__gelderland__tmp2__df, idx__WDNF2_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WDNF__df,
    habitat_col='habitatType1',
    group_col='WDNF2_division'
)

# %%
idx__WDNF2_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__WDNF2_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## IDX WDNF3 plusOW p80 selected df

# %%
# WD3
idx__WDNF3_plusOW_p80__selected__gelderland__tmp2__df, idx__WDNF3_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WDNF__df,
    habitat_col='habitatType1',
    group_col='WDNF3_division'
)

# %%
idx__WDNF3_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__WDNF3_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## IDX WDNF4 plusOW p80 selected df

# %%
# WDNF4
idx__WDNF4_plusOW_p80__selected__gelderland__tmp2__df, idx__WDNF4_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WDNF__df,
    habitat_col='habitatType1',
    group_col='WDNF4_division'
)

# %%
idx__WDNF4_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__WDNF4_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## IDX WDNF5 plusOW p80 selected df

# %%
# WDNF5
idx__WDNF5_plusOW_p80__selected__gelderland__tmp2__df, idx__WDNF5_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WDNF__df,
    habitat_col='habitatType1',
    group_col='WDNF5_division'
)

# %%
idx__WDNF5_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__WDNF5_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## IDX WDNF6 plusOW p80 selected df

# %%
# WDNF6
idx__WDNF6_plusOW_p80__selected__gelderland__tmp2__df, idx__WDNF5_plusOW_p80__selected__gelderland__tmp2__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WDNF__df,
    habitat_col='habitatType1',
    group_col='WDNF6_division'
)

# %%
idx__WDNF6_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__WDNF6_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# End of the Notebook
