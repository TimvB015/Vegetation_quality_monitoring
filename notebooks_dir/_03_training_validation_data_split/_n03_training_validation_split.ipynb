# %% [markdown]
# _This notebook splits the habitat data into a training and a validation dataset for each division strategy separately._

# %% [markdown]
# ## Importing functions

# %%
from functions.gpkg_funcs import (
    import_gpkg_func,
)

from functions.idx_pixel_count_funcs import (
    unique_idx_area_func,
)

from notebooks_dir._03_training_validation_data_split._support._n03_funcs import (
    train_val_split_automation,
)

# %% [markdown]
# ## Setting Directory

# %%
from paths.OG_paths import(
    #######################################
    #  03_training_validation_data_split  #
    #######################################
    # | n01_build_selected_pixels_idx_dfs |
    # +===================================+
    # --- manual inspected pixeled gpkg --- #    
    habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gpkg_path,
    
    # --- selected pixels IDX dfs --- #
    idx__FC_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD1_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD2_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD3_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD4_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD5_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD6_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__s1_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__s2_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__s3_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WDNF1_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WDNF2_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WDNF3_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WDNF4_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WDNF5_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WDNF6_plusOW_p80__selected__gelderland__tmp2__df_path,


    # +=====================================+
    # | n03_training_validation_split_carto |
    # +=====================================+
    # --- idx training validation dfs --- #
    # DIR
    training_validation__dir,
)

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd

# %% [markdown]
# ## Importing files

# %%
habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gpkg_path, 
    layer='habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__layer', 
    index_col='index',
)

# %%
idx__FC_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__FC_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WD1_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__WD1_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WD2_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__WD2_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WD3_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__WD3_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WD4_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__WD4_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WD5_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__WD5_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WD6_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__WD6_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__s1_plusOW_p80_selected_gelderland_tmp2_df = pd.read_pickle(idx__s1_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__s2_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__s2_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__s3_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__s3_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__FC_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__FC_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WDNF1_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__WDNF1_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WDNF2_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__WDNF2_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WDNF3_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__WDNF3_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WDNF4_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__WDNF4_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WDNF5_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__WDNF5_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WDNF6_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__WDNF6_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# ## Calculating the unique area of each pixel

# %% [markdown]
# _This step calculates the total area of the unique ID's. If a ID is present in multiple columns, then it is only taken into account once. Based on this a list is build that determines the amount of area that should be included in the training/validation set_

# %% [markdown]
# ### WD1 - area_selection

# %%
WD1_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD1_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WD1 areas per row:\n" + WD1_area_text)
# Out:
# WD1 areas per row:
# Remaining: 311622.00 pixels
# Wet Nature: 2207.00 pixels
# Open water: 1279.00 pixels

# %%
WD1_at1_dict = {
    "Remaining": 3000,
    "Wet Nature": 1200,
    "Open water": 450,
}

# %% [markdown]
# ### WD2 - area_selection

# %%
WD2_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD2_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WD2 areas per row:\n" + WD2_area_text)
# Out:
# WD2 areas per row:
# Remaining: 129211.00 pixels
# Wet Nature: 2207.00 pixels
# Open water: 1279.00 pixels

# %%
WD2_at1_dict = {
    "Remaining": 3000,
    "Wet Nature": 1200,
    "Open water": 450,
}

# %% [markdown]
# ### WD3 - area_selection

# %%
WD3_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD3_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WD3 areas per row:\n" + WD3_area_text)
# Out:
# WD3 areas per row:
# Remaining: 311622.00 pixels
# Semi-Wet Nature: 2063.00 pixels
# Wet Nature: 144.00 pixels
# Open water: 1279.00 pixels

# %%
WD3_at1_dict = {
    "Remaining": 3000,
    "Wet Nature": 150,
    "Semi-Wet Nature": 750,
    "Open water": 450,
}

# %% [markdown]
# ### WD4 - area_selection

# %%
WD4_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD4_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WD4 areas per row:\n" + WD4_area_text)
# Out:
# WD4 areas per row:
# Remaining: 129211.00 pixels
# Semi-Wet Nature: 2063.00 pixels
# Wet Nature: 144.00 pixels
# Open water: 1279.00 pixels

# %%
WD4_at1_dict = {
    "Remaining": 3000,
    "Wet Nature": 150,
    "Semi-Wet Nature": 750,
    "Open water": 450,
}

# %% [markdown]
# ### WD5 - area_selection

# %%
WD5_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD5_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WD5 areas per row:\n" + WD5_area_text)
# Out:
# WD5 areas per row:
# Remaining: 311622.00 pixels
# Semi-Wet Nature: 2063.00 pixels
# Open water: 1423.00 pixels

# %%
WD5_at1_dict = {
    "Remaining": 3000,
    "Semi-Wet Nature": 1200,
    "Open water": 600,
}

# %% [markdown]
# ### WD6 - area_selection

# %%
WD6_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD6_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WD5 areas per row:\n" + WD6_area_text)
# Out:
# WD5 areas per row:
# Remaining: 129211.00 pixels
# Semi-Wet Nature: 2063.00 pixels
# Open water: 1423.00 pixels

# %%
WD6_at1_dict = {
    "Remaining": 3000,
    "Semi-Wet Nature": 1200,
    "Open water": 600,
}

# %% [markdown]
# ### S1 - area_selection

# %%
s1_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__s1_plusOW_p80_selected_gelderland_tmp2_df,
    area_col="Shape_Area",
    as_text=True,
)

print("S1 areas per row:\n" + s1_area_text)
# Out:
# S1 areas per row:
# Remaining: 122724.00 pixels
# Overgangs- & trilven: 106.00 pixels
# Vochtige heiden: 1286.00 pixels
# Zwakgebufferde vennen: 79.00 pixels
# Zure vennen: 65.00 pixels
# Open water: 1279.00 pixels

# %%
s1_at1_dict = {
    "Remaining": 1500,
    "Overgangs- & trilven": 80,
    "Vochtige heiden": 800,
    "Zwakgebufferde vennen": 60,
    "Zure vennen": 45,
    "Open water": 450,
}

# %% [markdown]
# ### S2 - area_selection

# %%
s2_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__s2_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("S2 areas per row:\n" + s2_area_text)
# Out:
# S2 areas per row:
# Remaining: 129357.00 pixels
# Ven: 250.00 pixels
# Vochtige heiden: 1286.00 pixels
# Open water: 1279.00 pixels

# %%
s2_at1_dict = {
    'Remaining': 1500,
    "Ven": 175,
    "Vochtige heiden": 800,
    "Open water": 450,
}

# %% [markdown]
# ### S3 - area_selection

# %%
s3_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__s3_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("S3 areas per row:\n" + s3_area_text)
# Out:
# S3 areas per row:
# Remaining: 129463.00 pixels
# Vochtige heiden: 1286.00 pixels
# Ven: 144.00 pixels
# Open water: 1279.00 pixels

# %%
s3_at1_dict = {
    'Remaining': 1500,
    "Ven": 150,
    "Vochtige heiden": 800,
    "Open water": 450,
}

# %% [markdown]
# ### WDNF1 - area_selection

# %%
WDNF1_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF1_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WD1 areas per row:\n" + WDNF1_area_text)
# Out:
# WD1 areas per row:
# Remaining: 311622.00 pixels
# Wet Nature: 1930.00 pixels
# Open water: 1279.00 pixels

# %%
WDNF1_at1_dict = {
    "Remaining": 3000,
    "Wet Nature": 1200,
    "Open water": 450,
}

# %% [markdown]
# ### WDNF2 - area_selection

# %%
WDNF2_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF2_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WDNF2 areas per row:\n" + WD2_area_text)
# Out:
# WDNF2 areas per row:
# Remaining: 129211.00 pixels
# Wet Nature: 2207.00 pixels
# Open water: 1279.00 pixels

# %%
WDNF2_at1_dict = {
    "Remaining": 3000,
    "Wet Nature": 1200,
    "Open water": 450,
}

# %% [markdown]
# ### WDNF3 - area_selection

# %%
WDNF3_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF3_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WDNF3 areas per row:\n" + WD3_area_text)
# Out:
# WDNF3 areas per row:
# Remaining: 311622.00 pixels
# Semi-Wet Nature: 2063.00 pixels
# Wet Nature: 144.00 pixels
# Open water: 1279.00 pixels

# %%
WDNF3_at1_dict = {
    "Remaining": 3000,
    "Wet Nature": 150,
    "Semi-Wet Nature": 750,
    "Open water": 450,
}

# %% [markdown]
# ### WDNF4 - area_selection

# %%
WDNF4_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF4_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WDNF4 areas per row:\n" + WD4_area_text)
# Out:
# WDNF4 areas per row:
# Remaining: 129211.00 pixels
# Semi-Wet Nature: 2063.00 pixels
# Wet Nature: 144.00 pixels
# Open water: 1279.00 pixels

# %%
WDNF4_at1_dict = {
    "Remaining": 3000,
    "Wet Nature": 150,
    "Semi-Wet Nature": 750,
    "Open water": 450,
}

# %% [markdown]
# ### WDNF5 - area_selection

# %%
WDNF5_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF5_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WDNF5 areas per row:\n" + WD5_area_text)
# Out:
# WDNF5 areas per row:
# Remaining: 311622.00 pixels
# Semi-Wet Nature: 2063.00 pixels
# Open water: 1423.00 pixels

# %%
WDNF5_at1_dict = {
    "Remaining": 3000,
    "Semi-Wet Nature": 1200,
    "Open water": 600,
}

# %% [markdown]
# ### WDNF6 - area_selection

# %%
WDNF6_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF6_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WDNF5 areas per row:\n" + WD6_area_text)
# Out:
# WDNF5 areas per row:
# Remaining: 129211.00 pixels
# Semi-Wet Nature: 2063.00 pixels
# Open water: 1423.00 pixels

# %%
WDNF6_at1_dict = {
    "Remaining": 3000,
    "Semi-Wet Nature": 1200,
    "Open water": 600,
}

# %% [markdown]
# ## Splitting the data and saving as gpkgs

# %% [markdown]
# ### WD1 split

# %% [markdown]
# #### WD1 at1

# %%
# at1
WD1_at1_sum_df, WD1_at1_train_pixel_area_df_exp, WD1_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WD1_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD1_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD1_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=40,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Wet Nature', 'Remaining'],
);

display(WD1_at1_sum_df)
display(WD1_at1_train_pixel_area_df_exp)
display(WD1_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD1_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD1_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WD1_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WD1_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__WD1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### WD2 split

# %% [markdown]
# #### WD2 at1

# %%
# at1
WD2_at1_sum_df, WD2_at1_train_pixel_area_df_exp, WD2_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WD2_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD2_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD2_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=42,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Wet Nature', 'Remaining'],
);

display(WD2_at1_sum_df)
display(WD2_at1_train_pixel_area_df_exp)
display(WD2_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD2_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD2_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WD2_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WD2_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__WD2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### WD3 split

# %% [markdown]
# #### WD3 at1

# %%
# at1
WD3_at1_sum_df, WD3_at1_train_pixel_area_df_exp, WD3_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WD3_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD3_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD3_at1_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=3,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Wet Nature', 'Semi-Wet Nature', 'Remaining'],
);

display(WD3_at1_sum_df)
display(WD3_at1_train_pixel_area_df_exp)
display(WD3_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD3_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD3_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WD3_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WD3_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__WD3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### WD4 split

# %% [markdown]
# #### WD4 at1

# %%
# at1
WD4_at1_sum_df, WD4_at1_train_pixel_area_df_exp, WD4_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WD4_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD4_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD4_at1_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=1,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Wet Nature', 'Semi-Wet Nature', 'Remaining'],
);

display(WD4_at1_sum_df)
display(WD4_at1_train_pixel_area_df_exp)
display(WD4_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD4_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD4_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WD4_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WD4_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__WD4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### WD5 split

# %% [markdown]
# #### WD5 at1

# %%
# at1
WD5_at1_sum_df, WD5_at1_train_pixel_area_df_exp, WD5_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WD5_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD5_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD5_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=2,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Semi-Wet Nature', 'Remaining'],
);

display(WD5_at1_sum_df)
display(WD5_at1_train_pixel_area_df_exp)
display(WD5_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD5_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD5_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WD5_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WD5_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__WD5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### WD6 split

# %% [markdown]
# #### WD6 at1

# %%
# at1
WD6_at1_sum_df, WD6_at1_train_pixel_area_df_exp, WD6_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WD6_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD6_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD6_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=3,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Semi-Wet Nature', 'Remaining'],
);

display(WD6_at1_sum_df)
display(WD6_at1_train_pixel_area_df_exp)
display(WD6_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD6_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD6_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WD6_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WD6_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__WD6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### S1 - split

# %% [markdown]
# #### s1 at1

# %%
# at1
s1_at1_sum_df, s1_at1_train_pixel_area_df_exp, s1_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="s1_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__s1_plusOW_p80_selected_gelderland_tmp2_df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=s1_at1_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=42,
    seed=44,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=[
        'Open water', 'Zure vennen', 'Zwakgebufferde vennen',
        'Overgangs- & trilven', 'Vochtige heiden', 'Remaining'
    ]
);

display(s1_at1_sum_df)
display(s1_at1_train_pixel_area_df_exp)
display(s1_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__s1_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__s1_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__s1_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__s1_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__s1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### S2 - split

# %% [markdown]
# #### s2 at1

# %%
# at1
s2_at1_sum_df, s2_at1_train_pixel_area_df_exp, s2_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="s2_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__s2_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=s2_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=59,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Ven', 'Vochtige heiden', 'Remaining']
);

display(s2_at1_sum_df)
display(s2_at1_train_pixel_area_df_exp)
display(s2_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__s2_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__s2_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__s2_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__s2_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__s2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### S3 - split

# %% [markdown]
# #### s3 at1

# %%
clkjvzsldkjf
# Out:
# [train_val_split_automation] overwrite=False and no split files + no associated GPKGs -> computed split and saved:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__s3_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__s3_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__s3_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] Created/overwritten: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__s3_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] Created/overwritten: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__s3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### WDNF1 - area_selection

# %%
WDNF1_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF1_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WD1 areas per row:\n" + WDNF1_area_text)
# Out:
# WD1 areas per row:
# Remaining: 311622.00 pixels
# Wet Nature: 1930.00 pixels
# Open water: 1279.00 pixels

# %%
WDNF1_at1_dict = {
    "Remaining": 3000,
    "Wet Nature": 1200,
    "Open water": 450,
}

# %% [markdown]
# ### WDNF2 - area_selection

# %%
WDNF2_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF2_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WDNF2 areas per row:\n" + WD2_area_text)
# Out:
# WDNF2 areas per row:
# Remaining: 129211.00 pixels
# Wet Nature: 2207.00 pixels
# Open water: 1279.00 pixels

# %%
WDNF2_at1_dict = {
    "Remaining": 3000,
    "Wet Nature": 1200,
    "Open water": 450,
}

# %% [markdown]
# ### WDNF3 - area_selection

# %%
WDNF3_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF3_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WDNF3 areas per row:\n" + WD3_area_text)
# Out:
# WDNF3 areas per row:
# Remaining: 311622.00 pixels
# Semi-Wet Nature: 2063.00 pixels
# Wet Nature: 144.00 pixels
# Open water: 1279.00 pixels

# %%
WDNF3_at1_dict = {
    "Remaining": 3000,
    "Wet Nature": 150,
    "Semi-Wet Nature": 750,
    "Open water": 450,
}

# %% [markdown]
# ### WDNF4 - area_selection

# %%
WDNF4_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF4_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WDNF4 areas per row:\n" + WD4_area_text)
# Out:
# WDNF4 areas per row:
# Remaining: 129211.00 pixels
# Semi-Wet Nature: 2063.00 pixels
# Wet Nature: 144.00 pixels
# Open water: 1279.00 pixels

# %%
WDNF4_at1_dict = {
    "Remaining": 3000,
    "Wet Nature": 150,
    "Semi-Wet Nature": 750,
    "Open water": 450,
}

# %% [markdown]
# ### WDNF5 - area_selection

# %%
WDNF5_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF5_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WDNF5 areas per row:\n" + WD5_area_text)
# Out:
# WDNF5 areas per row:
# Remaining: 311622.00 pixels
# Semi-Wet Nature: 2063.00 pixels
# Open water: 1423.00 pixels

# %%
WDNF5_at1_dict = {
    "Remaining": 3000,
    "Semi-Wet Nature": 1200,
    "Open water": 600,
}

# %% [markdown]
# ### WDNF6 - area_selection

# %%
WDNF6_area_text = unique_idx_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF6_plusOW_p80__selected__gelderland__tmp2__df,
    area_col="Shape_Area",
    as_text=True,
)

print("WDNF5 areas per row:\n" + WD6_area_text)
# Out:
# WDNF5 areas per row:
# Remaining: 129211.00 pixels
# Semi-Wet Nature: 2063.00 pixels
# Open water: 1423.00 pixels

# %%
WDNF6_at1_dict = {
    "Remaining": 3000,
    "Semi-Wet Nature": 1200,
    "Open water": 600,
}

# %% [markdown]
# ## Splitting the data and saving as gpkgs

# %% [markdown]
# ### WD1 split

# %% [markdown]
# #### WD1 at1

# %%
# at1
WD1_at1_sum_df, WD1_at1_train_pixel_area_df_exp, WD1_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WD1_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD1_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD1_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=40,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Wet Nature', 'Remaining'],
);

display(WD1_at1_sum_df)
display(WD1_at1_train_pixel_area_df_exp)
display(WD1_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD1_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD1_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WD1_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WD1_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__WD1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### WD2 split

# %% [markdown]
# #### WD2 at1

# %%
# at1
WD2_at1_sum_df, WD2_at1_train_pixel_area_df_exp, WD2_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WD2_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD2_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD2_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=42,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Wet Nature', 'Remaining'],
);

display(WD2_at1_sum_df)
display(WD2_at1_train_pixel_area_df_exp)
display(WD2_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD2_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD2_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WD2_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WD2_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__WD2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### WD3 split

# %% [markdown]
# #### WD3 at1

# %%
# at1
WD3_at1_sum_df, WD3_at1_train_pixel_area_df_exp, WD3_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WD3_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD3_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD3_at1_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=3,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Wet Nature', 'Semi-Wet Nature', 'Remaining'],
);

display(WD3_at1_sum_df)
display(WD3_at1_train_pixel_area_df_exp)
display(WD3_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD3_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD3_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WD3_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WD3_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__WD3_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### WD4 split

# %% [markdown]
# #### WD4 at1

# %%
# at1
WD4_at1_sum_df, WD4_at1_train_pixel_area_df_exp, WD4_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WD4_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD4_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD4_at1_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=1,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Wet Nature', 'Semi-Wet Nature', 'Remaining'],
);

display(WD4_at1_sum_df)
display(WD4_at1_train_pixel_area_df_exp)
display(WD4_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD4_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD4_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WD4_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WD4_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__WD4_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### WD5 split

# %% [markdown]
# #### WD5 at1

# %%
# at1
WD5_at1_sum_df, WD5_at1_train_pixel_area_df_exp, WD5_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WD5_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD5_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD5_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=2,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Semi-Wet Nature', 'Remaining'],
);

display(WD5_at1_sum_df)
display(WD5_at1_train_pixel_area_df_exp)
display(WD5_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD5_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD5_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WD5_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WD5_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__WD5_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### WD6 split

# %% [markdown]
# #### WD6 at1

# %%
# at1
WD6_at1_sum_df, WD6_at1_train_pixel_area_df_exp, WD6_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WD6_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD6_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD6_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=3,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Semi-Wet Nature', 'Remaining'],
);

display(WD6_at1_sum_df)
display(WD6_at1_train_pixel_area_df_exp)
display(WD6_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD6_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WD6_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WD6_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WD6_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__WD6_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### S1 - split

# %% [markdown]
# #### s1 at1

# %%
# at1
s1_at1_sum_df, s1_at1_train_pixel_area_df_exp, s1_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="s1_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__s1_plusOW_p80_selected_gelderland_tmp2_df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=s1_at1_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=42,
    seed=44,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=[
        'Open water', 'Zure vennen', 'Zwakgebufferde vennen',
        'Overgangs- & trilven', 'Vochtige heiden', 'Remaining'
    ]
);

display(s1_at1_sum_df)
display(s1_at1_train_pixel_area_df_exp)
display(s1_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__s1_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__s1_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__s1_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__s1_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__s1_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### S2 - split

# %% [markdown]
# #### s2 at1

# %%
# at1
s2_at1_sum_df, s2_at1_train_pixel_area_df_exp, s2_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="s2_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__s2_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=s2_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=59,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Ven', 'Vochtige heiden', 'Remaining']
);

display(s2_at1_sum_df)
display(s2_at1_train_pixel_area_df_exp)
display(s2_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__s2_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__s2_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__s2_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__s2_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\ML_approach [UTM32631]\training_pixels__s2_plusOW_p80_tmp2_ML_at1__gelderland__UTM32631__gpkg.gpkg
# ...

# %% [markdown]
# ### WDNF1 split

# %% [markdown]
# #### WDNF1 at1

# %%
# at1
WDNF1_at1_sum_df, WDNF1_at1_train_pixel_area_df_exp, WDNF1_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WDNF1_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF1_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WDNF1_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=45,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Wet Nature', 'Remaining'],
);

display(WDNF1_at1_sum_df)
display(WDNF1_at1_train_pixel_area_df_exp)
display(WDNF1_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WDNF1_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WDNF1_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WDNF1_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WDNF1_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# ...

# %% [markdown]
# ### WDNF2 split

# %% [markdown]
# #### WDNF2 at1

# %%
# at1
WDNF2_at1_sum_df, WDNF2_at1_train_pixel_area_df_exp, WDNF2_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WDNF2_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF2_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WD2_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=45,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Wet Nature', 'Remaining'],
);

display(WDNF2_at1_sum_df)
display(WDNF2_at1_train_pixel_area_df_exp)
display(WDNF2_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WDNF2_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WDNF2_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WDNF2_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WDNF2_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# ...

# %% [markdown]
# ### WDNF3 split

# %% [markdown]
# #### WDNF3 at1

# %%
# at1
WDNF3_at1_sum_df, WDNF3_at1_train_pixel_area_df_exp, WDNF3_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WDNF3_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF3_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WDNF3_at1_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=3,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Wet Nature', 'Semi-Wet Nature', 'Remaining'],
);

display(WDNF3_at1_sum_df)
display(WDNF3_at1_train_pixel_area_df_exp)
display(WDNF3_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WDNF3_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WDNF3_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WDNF3_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WDNF3_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# ...

# %% [markdown]
# ### WDNF4 split

# %% [markdown]
# #### WDNF4 at1

# %%
# at1
WDNF4_at1_sum_df, WDNF4_at1_train_pixel_area_df_exp, WDNF4_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WDNF4_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF4_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WDNF4_at1_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=3,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Wet Nature', 'Semi-Wet Nature', 'Remaining'],
);

display(WDNF4_at1_sum_df)
display(WDNF4_at1_train_pixel_area_df_exp)
display(WDNF4_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WDNF4_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WDNF4_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WDNF4_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WDNF4_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# ...

# %% [markdown]
# ### WDNF5 split

# %% [markdown]
# #### WDNF5 at1

# %%
# at1
WDNF5_at1_sum_df, WDNF5_at1_train_pixel_area_df_exp, WDNF5_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WDNF5_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF5_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WDNF5_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=5,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Semi-Wet Nature', 'Remaining'],
);

display(WDNF5_at1_sum_df)
display(WDNF5_at1_train_pixel_area_df_exp)
display(WDNF5_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WDNF5_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WDNF5_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WDNF5_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WDNF5_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# ...

# %% [markdown]
# ### WDNF6 split

# %% [markdown]
# #### WDNF6 at1

# %%
# at1
WDNF6_at1_sum_df, WDNF6_at1_train_pixel_area_df_exp, WDNF6_at1_validation_pixel_area_df_exp = train_val_split_automation(
    run_id="WDNF6_plusOW_p80_tmp2_cart_at1__gelderland__RD",
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WDNF6_plusOW_p80__selected__gelderland__tmp2__df,
    output_dir=training_validation__dir,
    cap_pixels_by_class=WDNF6_at1_dict,
    train_pct=0.75,
    val_pct=0.25,
    test_pct=0.0,
    area_col="Shape_Area",
    large_polygon_threshold=36,
    seed=5,
    overwrite=False,
    ml_epsg="EPSG:32631",
    pixels_row_order=['Open water', 'Semi-Wet Nature', 'Remaining'],
);

display(WDNF6_at1_sum_df)
display(WDNF6_at1_train_pixel_area_df_exp)
display(WDNF6_at1_validation_pixel_area_df_exp)
# Out:
# [train_val_split_automation] overwrite=False and all split files exist -> loaded:
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WDNF6_plusOW_p80_tmp2_training_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_idx_dfs\idx__WDNF6_plusOW_p80_tmp2_validation_at1__gelderland__df.pkl
#   - D:\Thesis\10.Thesis_Data\03_training_validation_data\02_training_validation_split_sum_df\sum__WDNF6_plusOW_p80_tmp2_at1__gelderland__df.pkl
# [train_val_split_automation] overwrite=False and exists -> kept: D:\Thesis\10.Thesis_Data\03_training_validation_data\03_training_data_gpkgs\Carto [RD]\training_polys__WDNF6_plusOW_p80_tmp2_cart_at1__gelderland__RD__gpkg.gpkg
# ...

# %% [markdown]
# End of the Notebook
