# %% [markdown]
# _This Notebook extracted the RGB-values from PDOK imagery._

# %% [markdown]
# ## Importing functions

# %%
from functions.raster_ops_funcs import (
    stack_multiband_rasters_func,
    align_raster_to_reference,
)

# %% [markdown]
# ## Setting directory

# %%
paths_DV = [
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_deelenschev_2017_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_deelenschev_2018_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_deelenschev_2019_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_deelenschev_2020_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_deelenschev_2021_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_deelenschev_2022_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_deelenschev_2023_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_deelenschev_2024_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_deelenschev_2025_UTM32631.tif",
]

paths_gerritsfles = [
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_gerritsfles_2017_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_gerritsfles_2018_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_gerritsfles_2019_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_gerritsfles_2020_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_gerritsfles_2021_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_gerritsfles_2022_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_gerritsfles_2023_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_gerritsfles_2024_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_gerritsfles_2025_UTM32631.tif",
]

paths_kootwijkerveen = [
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_kootwijkerveen_2017_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_kootwijkerveen_2018_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_kootwijkerveen_2019_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_kootwijkerveen_2020_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_kootwijkerveen_2021_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_kootwijkerveen_2022_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_kootwijkerveen_2023_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_kootwijkerveen_2024_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_kootwijkerveen_2025_UTM32631.tif",
]

paths_mosterdveen = [
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_mosterdveen_2017_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_mosterdveen_2018_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_mosterdveen_2019_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_mosterdveen_2020_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_mosterdveen_2021_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_mosterdveen_2022_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_mosterdveen_2023_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_mosterdveen_2024_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_mosterdveen_2025_UTM32631.tif",
]

paths_speulderveld = [
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_speulderveld_2017_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_speulderveld_2018_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_speulderveld_2019_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_speulderveld_2020_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_speulderveld_2021_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_speulderveld_2022_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_speulderveld_2023_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_speulderveld_2024_UTM32631.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\pdok_speulderveld_2025_UTM32631.tif",
]

path_full_veluwe = [
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\full_veluwe_2017.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\full_veluwe_2018.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\full_veluwe_2019.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\full_veluwe_2020.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\full_veluwe_2021.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\full_veluwe_2022.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\full_veluwe_2023.tif",
    r"D:\Thesis\10.Thesis_Data\00_basismaps_raw\pdok_imgs\UTM32631\full_veluwe_2024.tif",
]

# %% [markdown]
# ## Building RGB rasters

# %%
from rasterio.enums import Resampling

# %%
stack_multiband_rasters_func(
    raster_paths=paths_DV,
    out_dir=r"D:\Thesis\10.Thesis_Data\01_basismaps_processed\pdok_imgs",
    out_name="Deelensche veld_stack.tif",
    bands_to_select=[1, 2, 3],
    raster_names=["2017", "2018", "2019", "2020", "2021", "2022", "2023", "2024", "2025"],
    band_labels=["R", "G", "B"],
    auto_align=True,  
    resampling_method=Resampling.bilinear,  
    overwrite=False,
)
# Out:
# ...
# WindowsPath('D:/Thesis/10.Thesis_Data/01_basismaps_processed/pdok_imgs/Deelensche veld_stack.tif')

# %%
stack_multiband_rasters_func(
    raster_paths=paths_gerritsfles,
    out_dir=r"D:\Thesis\10.Thesis_Data\01_basismaps_processed\pdok_imgs",
    out_name="gerritsfles_stack.tif",
    bands_to_select=[1, 2, 3],
    raster_names=["2017", "2018", "2019", "2020", "2021", "2022", "2023", "2024", "2025"],
    band_labels=["R", "G", "B"],
    auto_align=True,  
    resampling_method=Resampling.bilinear,  
    overwrite=False,
)
# Out:
# ...
# WindowsPath('D:/Thesis/10.Thesis_Data/01_basismaps_processed/pdok_imgs/gerritsfles_stack.tif')

# %%
stack_multiband_rasters_func(
    raster_paths=paths_kootwijkerveen,
    out_dir=r"D:\Thesis\10.Thesis_Data\01_basismaps_processed\pdok_imgs",
    out_name="kootwijkerveen_stack.tif",
    bands_to_select=[1, 2, 3],
    raster_names=["2017", "2018", "2019", "2020", "2021", "2022", "2023", "2024", "2025"],
    band_labels=["R", "G", "B"],
    auto_align=True,  
    resampling_method=Resampling.bilinear,  
    overwrite=False,
)
# Out:
# ...
# WindowsPath('D:/Thesis/10.Thesis_Data/01_basismaps_processed/pdok_imgs/kootwijkerveen_stack.tif')

# %%
stack_multiband_rasters_func(
    raster_paths=paths_mosterdveen,
    out_dir=r"D:\Thesis\10.Thesis_Data\01_basismaps_processed\pdok_imgs",
    out_name="mosterdveen_stack.tif",
    bands_to_select=[1, 2, 3],
    raster_names=["2017", "2018", "2019", "2020", "2021", "2022", "2023", "2024", "2025"],
    band_labels=["R", "G", "B"],
    auto_align=True,  
    resampling_method=Resampling.bilinear,  
    overwrite=False,
)
# Out:
# ...
# WindowsPath('D:/Thesis/10.Thesis_Data/01_basismaps_processed/pdok_imgs/mosterdveen_stack.tif')

# %%
stack_multiband_rasters_func(
    raster_paths=paths_speulderveld,
    out_dir=r"D:\Thesis\10.Thesis_Data\01_basismaps_processed\pdok_imgs",
    out_name="speulderveld_stack.tif",
    bands_to_select=[1, 2, 3],
    raster_names=["2017", "2018", "2019", "2020", "2021", "2022", "2023", "2024", "2025"],
    band_labels=["R", "G", "B"],
    auto_align=True,  
    resampling_method=Resampling.bilinear,  
    overwrite=False,
)
# Out:
# ...
# WindowsPath('D:/Thesis/10.Thesis_Data/01_basismaps_processed/pdok_imgs/speulderveld_stack.tif')

# %%
stack_multiband_rasters_func(
    raster_paths=path_full_veluwe,
    out_dir=r"D:\Thesis\10.Thesis_Data\01_basismaps_processed\pdok_imgs",
    out_name="full_veluwe_stack.tif",
    bands_to_select=[1, 2, 3],
    raster_names=["2017", "2018", "2019", "2020", "2021", "2022", "2023", "2024"],
    band_labels=["R", "G", "B"],
    auto_align=True,  
    resampling_method=Resampling.bilinear,  
    overwrite=True,
)
# Out:
# WindowsPath('D:/Thesis/10.Thesis_Data/01_basismaps_processed/pdok_imgs/full_veluwe_stack.tif')

# %% [markdown]
# End of the Notebook
