# %% [markdown]
# _This notebook provides a first estimation on the number of sentinel-2 pixels based on the habitat polygons_

# %% [markdown]
# ## Importing functions

# %%
from functions.gpkg_funcs import (
    import_gpkg_func,
)

from functions.custom_common_nb_funcs import (
    check_processing,
)

from functions.idx_pixel_count_funcs import (
    pixel_count_df_func,
    pixel_vis_func,
)

# %% [markdown]
# ## Setting directory

# %%
from paths.OG_paths import (
    #######################################
    #     01_pre_processing_hab_kart      #
    #######################################
    # |  n01_T0_habitat_gpkg_processing   |
    # +===================================+ 
    # --- Habitat kart Processed GPKG --- #
    habitat_kart__processed__gelderland__RD__gpkg_path,
    habitat_kart__processed__gelderland_minHR__RD__gpkg_path,
    habitat_kart__processed__website__RD__gpkg_path,
    habitat_kart__processed__website_plusHR__RD__gpkg_path,


    #######################################
    #  02_hab_kart_selection_and_division #
    #######################################
    # |      n01_first_data_division      |
    # +===================================+ 
    # AO tmp0
    idx__AO__division__gelderland__tmp0__df_path,
    idx__AO__division__gelderland_minHR__tmp0__df_path,
    idx__AO__division__website__tmp0__df_path,
    idx__AO__division__website_plusHR__tmp0__df_path,
    # AO tmp1
    idx__AO__division__gelderland__tmp1__df_path,
    idx__AO__division__gelderland_minHR__tmp1__df_path,
    idx__AO__division__website__tmp1__df_path,
    idx__AO__division__website_plusHR__tmp1__df_path,
    # HB tmp1
    idx__HB__division__gelderland__tmp1__df_path,
    idx__HB__division__gelderland_minHR__tmp1__df_path,
    idx__HB__division__website__tmp1__df_path,
    idx__HB__division__website_plusHR__tmp1__df_path,
    # FC tmp1
    idx__FC__division__gelderland__tmp1__df_path,
    idx__FC__division__gelderland_minHR__tmp1__df_path,
    idx__FC__division__website__tmp1__df_path,
    idx__FC__division__website_plusHR__tmp1__df_path,
    # WD tmp1
    idx__WD__division__gelderland__tmp1__df_path,
    idx__WD__division__gelderland_minHR__tmp1__df_path,
    idx__WD__division__website__tmp1__df_path,
    idx__WD__division__website_plusHR__tmp1__df_path,
    # s1 tmp1
    idx__s1__division__gelderland__tmp1__df_path,
    idx__s1__division__gelderland_minHR__tmp1__df_path,
    idx__s1__division__website__tmp1__df_path,
    idx__s1__division__website_plusHR__tmp1__df_path,
)

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd

# pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Import files

# %%
# Importing GPKG files
# --- Gelderland ---
habitat_kart__processed__gelderland__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__gelderland__RD__gpkg_path, 
    layer='habitat_kart__processed__gelderland__RD__layer', 
    index_col='index'
)

# --- Gelderland min hr ---
habitat_kart__processed__gelderland_minHR__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__gelderland_minHR__RD__gpkg_path, 
    layer='habitat_kart__processed__gelderland_minHR__RD__layer', 
    index_col='index'
)

# --- Website ---
habitat_kart__processed__website__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__website__RD__gpkg_path,
    layer='habitat_kart__processed__website__RD__layer',
    index_col='index'
)

# --- Website plus hr ---
habitat_kart__processed__website_plusHR__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__website_plusHR__RD__gpkg_path,
    layer='habitat_kart__processed__website_plusHR__RD__layer',
    index_col='index'
)
# Out:
# c:\Users\NL1G3K\Desktop\Vegetation_quality_monitoring\.pixi\envs\default\Lib\site-packages\pyogrio\geopandas.py:49: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   res = pd.to_datetime(ser, **datetime_kwargs)
# c:\Users\NL1G3K\Desktop\Vegetation_quality_monitoring\.pixi\envs\default\Lib\site-packages\pyogrio\geopandas.py:49: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   res = pd.to_datetime(ser, **datetime_kwargs)
# c:\Users\NL1G3K\Desktop\Vegetation_quality_monitoring\.pixi\envs\default\Lib\site-packages\pyogrio\geopandas.py:49: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   res = pd.to_datetime(ser, **datetime_kwargs)
# ...

# %%
# AO tmp0 IDX
idx__AO__division__gelderland__tmp0__df = pd.read_pickle(idx__AO__division__gelderland__tmp0__df_path)
idx__AO__division__gelderland_minHR__tmp0__df = pd.read_pickle(idx__AO__division__gelderland_minHR__tmp0__df_path)
idx__AO__division__website__tmp0__df = pd.read_pickle(idx__AO__division__website__tmp0__df_path)
idx__AO__division__website_plusHR__tmp0__df = pd.read_pickle(idx__AO__division__website_plusHR__tmp0__df_path)

# AO tmp1 IDX
idx__AO__division__gelderland__tmp1__df = pd.read_pickle(idx__AO__division__gelderland__tmp1__df_path)
idx__AO__division__gelderland_minHR__tmp1__df = pd.read_pickle(idx__AO__division__gelderland_minHR__tmp1__df_path)
idx__AO__division__website__tmp1__df = pd.read_pickle(idx__AO__division__website__tmp1__df_path)
idx__AO__division__website_plusHR__tmp1__df = pd.read_pickle(idx__AO__division__website_plusHR__tmp1__df_path)

# HB tmp1 IDX
idx__HB__division__gelderland__tmp1__df = pd.read_pickle(idx__HB__division__gelderland__tmp1__df_path)
idx__HB__division__gelderland_minHR__tmp1__df = pd.read_pickle(idx__HB__division__gelderland_minHR__tmp1__df_path)
idx__HB__division__website__tmp1__df = pd.read_pickle(idx__HB__division__website__tmp1__df_path)
idx__HB__division__website_plusHR__tmp1__df = pd.read_pickle(idx__HB__division__website_plusHR__tmp1__df_path)

# FC tmp1 IDX
idx__FC__division__gelderland__tmp1__df = pd.read_pickle(idx__FC__division__gelderland__tmp1__df_path)
idx__FC__division__gelderland_minHR__tmp1__df = pd.read_pickle(idx__FC__division__gelderland_minHR__tmp1__df_path)
idx__FC__division__website__tmp1__df = pd.read_pickle(idx__FC__division__website__tmp1__df_path)
idx__FC__division__website_plusHR__tmp1__df = pd.read_pickle(idx__FC__division__website_plusHR__tmp1__df_path)

# WD tmp1 IDX
idx__WD__division__gelderland__tmp1__df = pd.read_pickle(idx__WD__division__gelderland__tmp1__df_path)
idx__WD__division__gelderland_minHR__tmp1__df = pd.read_pickle(idx__WD__division__gelderland_minHR__tmp1__df_path)
idx__WD__division__website__tmp1__df = pd.read_pickle(idx__WD__division__website__tmp1__df_path)
idx__WD__division__website_plusHR__tmp1__df = pd.read_pickle(idx__WD__division__website_plusHR__tmp1__df_path)

# s1 tmp1 IDX
idx__s1__division__gelderland__tmp1__df = pd.read_pickle(idx__s1__division__gelderland__tmp1__df_path)
idx__s1__division__gelderland_minHR__tmp1__df = pd.read_pickle(idx__s1__division__gelderland_minHR__tmp1__df_path)
idx__s1__division__website__tmp1__df = pd.read_pickle(idx__s1__division__website__tmp1__df_path)
idx__s1__division__website_plusHR__tmp1__df = pd.read_pickle(idx__s1__division__website_plusHR__tmp1__df_path)

# %% [markdown]
# ## Counting pixels -> AO tmp 0

# %%
pixel_count__AO__division__gelderland__tmp0__df, pixel_count__AO__division__gelderland__tmp0__check = pixel_count_df_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    idx_df=idx__AO__division__gelderland__tmp0__df,
)

pixel_count__AO__division__gelderland_minHR__tmp0__df, pixel_count__AO__division__gelderland_minHR__tmp0__check = pixel_count_df_func(
    gdf=habitat_kart__processed__gelderland_minHR__RD__gdf,
    idx_df=idx__AO__division__gelderland_minHR__tmp0__df,
)

pixel_count__AO__division__website__tmp0__df, pixel_count__AO__division__website__tmp0__check = pixel_count_df_func(
    gdf=habitat_kart__processed__website__RD__gdf,
    idx_df=idx__AO__division__website__tmp0__df,
)

pixel_count__AO__division__website_plusHR__tmp0__df, pixel_count__AO__division__website_plusHR__tmp0__check = pixel_count_df_func(
    gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    idx_df=idx__AO__division__website_plusHR__tmp0__df,
)

# %%
# Check AO tmp0 pixel count processing
values = [pixel_count__AO__division__gelderland__tmp0__check, 
          pixel_count__AO__division__gelderland_minHR__tmp0__check,
          pixel_count__AO__division__website__tmp0__check, 
          pixel_count__AO__division__website_plusHR__tmp0__check
]
entities = ["gelderland", "gelderland_min_hr", "website", "website_plus_hr"]

check_processing(values, entities, typ="AO", tmp="tmp0")
# Out:
# ['The number of habitat surveys is correct']

# %%
# Years list for visualization
tmp_0_gelderland_years = pixel_count__AO__division__gelderland__tmp0__df.columns.tolist()
tmp_0_website_years = pixel_count__AO__division__website_plusHR__tmp0__df.columns.tolist()

# %%
pixel_vis_func(pixel_count__AO__division__gelderland__tmp0__df, tmp_0_gelderland_years, title="AO tmp0 Gelderland Pixels per Year")
# Out:
# <style type="text/css">
# #T_d9db6 th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_d9db6 th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_d9db6 caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# ...

# %%
# pixel_vis_func(pixel_count__AO__division__website_plusHR__tmp0__df, tmp_0_website_years, title="AO tmp0 Website Pixels per Year")

# %% [markdown]
# ## Counting Pixels -> FC tmp 1

# %%
pixel_count__FC__division__gelderland__tmp1__df, pixel_count__FC__division__gelderland__tmp1__check = pixel_count_df_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    idx_df=idx__FC__division__gelderland__tmp1__df,
)

pixel_count__FC__division__gelderland_minHR__tmp1__df, pixel_count__FC__division__gelderland_minHR__tmp1__check = pixel_count_df_func(
    gdf=habitat_kart__processed__gelderland_minHR__RD__gdf,
    idx_df=idx__FC__division__gelderland_minHR__tmp1__df,
)

pixel_count__FC__division__website__tmp1__df, pixel_count__FC__division__website__tmp1__check = pixel_count_df_func(
    gdf=habitat_kart__processed__website__RD__gdf,
    idx_df=idx__FC__division__website__tmp1__df,
)

pixel_count__FC__division__website_plusHR__tmp1__df, pixel_count__FC__division__website_plusHR__tmp1__check = pixel_count_df_func(
    gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    idx_df=idx__FC__division__website_plusHR__tmp1__df,
)

# %%
# Check FC tmp1 pixel count processing
values = [pixel_count__FC__division__gelderland__tmp1__check, 
          pixel_count__FC__division__gelderland_minHR__tmp1__check,
          pixel_count__FC__division__website__tmp1__check, 
          pixel_count__FC__division__website_plusHR__tmp1__check
]
entities = ["gelderland", "gelderland_min_hr", "website", "website_plus_hr"]

check_processing(values, entities, typ="FC", tmp="tmp1")
# Out:
# ['The number of habitat surveys is correct']

# %%
tmp_1_gelderland_years = pixel_count__FC__division__gelderland__tmp1__df.columns.tolist()
tmp_1_website_years = pixel_count__FC__division__website_plusHR__tmp1__df.columns.tolist()

# %%
# pixel_vis_func(pixel_count__FC__division__gelderland__tmp1__df, tmp_1_gelderland_years, title="FC tmp1 Gelderland Pixels per Year")

# %%
pixel_vis_func(pixel_count__FC__division__website_plusHR__tmp1__df, tmp_1_website_years, title="FC tmp1 Website Pixels per Year")
# Out:
# <style type="text/css">
# #T_a676a th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_a676a th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_a676a caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# ...

# %% [markdown]
# # Counting Pixels -> WD tmp 1

# %%
pixel_count__WD__division__gelderland__tmp1__df, pixel_count__WD__division__gelderland__tmp1__check = pixel_count_df_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    idx_df=idx__WD__division__gelderland__tmp1__df,
)

pixel_count__WD__division__gelderland_minHR__tmp1__df, pixel_count__WD__division__gelderland_minHR__tmp1__check = pixel_count_df_func(
    gdf=habitat_kart__processed__gelderland_minHR__RD__gdf,
    idx_df=idx__WD__division__gelderland_minHR__tmp1__df,
)

pixel_count__WD__division__website__tmp1__df, pixel_count__WD__division__website__tmp1__check = pixel_count_df_func(
    gdf=habitat_kart__processed__website__RD__gdf,
    idx_df=idx__WD__division__website__tmp1__df,
)

pixel_count__WD__division__website_plusHR__tmp1__df, pixel_count__WD__division__website_plusHR__tmp1__check = pixel_count_df_func(
    gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    idx_df=idx__WD__division__website_plusHR__tmp1__df,
)

# %%
# Check WD tmp1 pixel count processing
values = [
    pixel_count__WD__division__gelderland__tmp1__check,
    pixel_count__WD__division__gelderland_minHR__tmp1__check,
    pixel_count__WD__division__website__tmp1__check,
    pixel_count__WD__division__website_plusHR__tmp1__check,
]
entities = ["gelderland", "gelderland_min_hr", "website", "website_plus_hr"]

check_processing(values, entities, typ="WD", tmp="tmp1")
# Out:
# ['The number of habitat surveys is correct']

# %%
pixel_vis_func(pixel_count__WD__division__gelderland__tmp1__df, tmp_1_gelderland_years, title="WD tmp1 Gelderland Pixels per Year")
# Out:
# <style type="text/css">
# #T_a65fa th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_a65fa th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_a65fa caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# #T_a65fa_row0_col0, #T_a65fa_row0_col1, #T_a65fa_row0_col2, #T_a65fa_row0_col3, #T_a65fa_row0_col4, #T_a65fa_row0_col5, #T_a65fa_row0_col6, #T_a65fa_row0_col7, #T_a65fa_row0_col8, #T_a65fa_row2_col0, #T_a65fa_row2_col1, #T_a65fa_row2_col2, #T_a65fa_row2_col3, #T_a65fa_row2_col4, #T_a65fa_row2_col5, #T_a65fa_row2_col6, #T_a65fa_row2_col7, #T_a65fa_row2_col8, #T_a65fa_row4_col0, #T_a65fa_row4_col1, #T_a65fa_row4_col2, #T_a65fa_row4_col3, #T_a65fa_row4_col4, #T_a65fa_row4_col5, #T_a65fa_row4_col6, #T_a65fa_row4_col7, #T_a65fa_row4_col8 {
# ...

# %%
pixel_vis_func(pixel_count__WD__division__website_plusHR__tmp1__df, tmp_1_website_years, title="WD tmp1 Website Pixels per Year")
# Out:
# <style type="text/css">
# #T_d960e th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_d960e th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_d960e caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# #T_d960e_row0_col0, #T_d960e_row0_col1, #T_d960e_row0_col2, #T_d960e_row0_col3, #T_d960e_row0_col4, #T_d960e_row0_col5, #T_d960e_row0_col6, #T_d960e_row0_col7, #T_d960e_row0_col8, #T_d960e_row2_col0, #T_d960e_row2_col1, #T_d960e_row2_col2, #T_d960e_row2_col3, #T_d960e_row2_col4, #T_d960e_row2_col5, #T_d960e_row2_col6, #T_d960e_row2_col7, #T_d960e_row2_col8, #T_d960e_row4_col0, #T_d960e_row4_col1, #T_d960e_row4_col2, #T_d960e_row4_col3, #T_d960e_row4_col4, #T_d960e_row4_col5, #T_d960e_row4_col6, #T_d960e_row4_col7, #T_d960e_row4_col8 {
# ...

# %% [markdown]
# ## Counting Pixels -> S1 tmp 1

# %%
pixel_count__s1__division__gelderland__tmp1__df, pixel_count__s1__division__gelderland__tmp1__check = pixel_count_df_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    idx_df=idx__s1__division__gelderland__tmp1__df,
)

pixel_count__s1__division__gelderland_minHR__tmp1__df, pixel_count__s1__division__gelderland_minHR__tmp1__check = pixel_count_df_func(
    gdf=habitat_kart__processed__gelderland_minHR__RD__gdf,
    idx_df=idx__s1__division__gelderland_minHR__tmp1__df,
)

pixel_count__s1__division__website__tmp1__df, pixel_count__s1__division__website__tmp1__check = pixel_count_df_func(
    gdf=habitat_kart__processed__website__RD__gdf,
    idx_df=idx__s1__division__website__tmp1__df,
)

pixel_count__s1__division__website_plusHR__tmp1__df, pixel_count__s1__division__website_plusHR__tmp1__check = pixel_count_df_func(
    gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    idx_df=idx__s1__division__website_plusHR__tmp1__df,
)

# %%
# Check s1 tmp1 pixel count processing
values = [
    pixel_count__s1__division__gelderland__tmp1__check,
    pixel_count__s1__division__gelderland_minHR__tmp1__check,
    pixel_count__s1__division__website__tmp1__check,
    pixel_count__s1__division__website_plusHR__tmp1__check,
]
entities = ["gelderland", "gelderland_min_hr", "website", "website_plus_hr"]

check_processing(values, entities, typ="S1", tmp="tmp1")
# Out:
# ['The number of habitat surveys is correct']

# %%
pixel_vis_func(pixel_count__s1__division__gelderland__tmp1__df, tmp_1_gelderland_years, title="S1 tmp1 Gelderland Pixels per Year")
# Out:
# <style type="text/css">
# #T_6ccc0 th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_6ccc0 th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_6ccc0 caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# #T_6ccc0_row0_col0, #T_6ccc0_row0_col1, #T_6ccc0_row0_col2, #T_6ccc0_row0_col3, #T_6ccc0_row0_col4, #T_6ccc0_row0_col5, #T_6ccc0_row0_col6, #T_6ccc0_row0_col7, #T_6ccc0_row0_col8, #T_6ccc0_row2_col0, #T_6ccc0_row2_col1, #T_6ccc0_row2_col2, #T_6ccc0_row2_col3, #T_6ccc0_row2_col4, #T_6ccc0_row2_col5, #T_6ccc0_row2_col6, #T_6ccc0_row2_col7, #T_6ccc0_row2_col8, #T_6ccc0_row4_col0, #T_6ccc0_row4_col1, #T_6ccc0_row4_col2, #T_6ccc0_row4_col3, #T_6ccc0_row4_col4, #T_6ccc0_row4_col5, #T_6ccc0_row4_col6, #T_6ccc0_row4_col7, #T_6ccc0_row4_col8 {
# ...

# %%
pixel_vis_func(pixel_count__s1__division__website_plusHR__tmp1__df, tmp_1_website_years, title="S1 tmp1 Website Pixels per Year")
# Out:
# <style type="text/css">
# #T_67a29 th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_67a29 th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_67a29 caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# #T_67a29_row0_col0, #T_67a29_row0_col1, #T_67a29_row0_col2, #T_67a29_row0_col3, #T_67a29_row0_col4, #T_67a29_row0_col5, #T_67a29_row0_col6, #T_67a29_row0_col7, #T_67a29_row0_col8, #T_67a29_row2_col0, #T_67a29_row2_col1, #T_67a29_row2_col2, #T_67a29_row2_col3, #T_67a29_row2_col4, #T_67a29_row2_col5, #T_67a29_row2_col6, #T_67a29_row2_col7, #T_67a29_row2_col8, #T_67a29_row4_col0, #T_67a29_row4_col1, #T_67a29_row4_col2, #T_67a29_row4_col3, #T_67a29_row4_col4, #T_67a29_row4_col5, #T_67a29_row4_col6, #T_67a29_row4_col7, #T_67a29_row4_col8 {
# ...

# %% [markdown]
# End of the Notebook
