# %% [markdown]
# _This notebook provides an estimation of the pixels included in the habitat dataset with the addition of the LGN open water polygons._

# %% [markdown]
# ## Importing Functions

# %%
from functions.gpkg_funcs import (
    import_gpkg_func,
)

from functions.idx_builder_funcs import (
    tmp_1_idx_df_func,
    HT_idx_df_func,
    FC_idx_df_func,
    group_idx_df_func,
)

from functions.idx_pixel_count_funcs import (
    pixel_count_df_func,
    pixel_vis_func,
)

from functions.idx_to_gdf_or_plot_funcs import (
    idx_to_gdf_plot_func,
)
# Out:
# Cannot find header.dxf (GDAL_DATA is not defined)

# %% [markdown]
# ## Setting Directory

# %%
from paths.OG_paths import (
    #######################################
    #            00_common_dfs            #
    #######################################
    # |    n01_habitat_reference_dfs      |
    # +===================================+ 
    habitat_reference__WD__df_path,
    habitat_reference__s__df_path,

    #######################################
    #     01_pre_processing_hab_kart      #
    #######################################
    # |  n01_T0_habitat_gpkg_processing   |
    # +===================================+ 
    # --- Habitat kart Processed GPKG --- #
    habitat_kart__processed__gelderland__RD__gpkg_path,

    #######################################
    #  02_hab_kart_selection_and_division #
    #######################################
     # |      n01_first_data_division      |
    # +===================================+ 
    idx__WD__division__gelderland__tmp1__df_path,

    # +===================================+  
    # |    n03_add_LGN_OW_to_hab_kart     |
    # +===================================+
    # --- hab kart plusOw merged GPKG --- #
    habitat_kart_plusOW__merged__gelderland__RD__gpkg_path,
    habitat_kart_plusOW__merged__gelderland_minHR__RD__gpkg_path,
    habitat_kart_plusOW__merged__website__RD__gpkg_path,
    habitat_kart_plusOW__merged__website_plusHR__RD__gpkg_path,

    # +=====================================+
    # | n04_visualizing_plusOW_pixel_counts |
    # +=====================================+
    # AO plusOW
    idx__AO_plusOW__division__gelderland__tmp1__df_path,
    idx__AO_plusOW__division__gelderland_minHR__tmp1__df_path,
    idx__AO_plusOW__division__website__tmp1__df_path,
    idx__AO_plusOW__division__website_plusHR__tmp1__df_path,
    # WD plusOW
    idx__WD_plusOW__division__gelderland__tmp1__df_path,
    idx__WD_plusOW__division__gelderland_minHR__tmp1__df_path,
    idx__WD_plusOW__division__website__tmp1__df_path,
    idx__WD_plusOW__division__website_plusHR__tmp1__df_path,
    # s1 plusOW
    idx__s1_plusOW__division__gelderland__tmp1__df_path,
    idx__s1_plusOW__division__gelderland_minHR__tmp1__df_path,
    idx__s1_plusOW__division__website__tmp1__df_path,
    idx__s1_plusOW__division__website_plusHR__tmp1__df_path,
)

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Importing files

# %%
# --- Gelderland processed GPKG ---
habitat_kart__processed__gelderland__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__gelderland__RD__gpkg_path, 
    layer='habitat_kart__processed__gelderland__RD__layer', 
    index_col='index'
)

# --- Gelderland processed idx df ---
idx__WD__division__gelderland__tmp1__df = pd.read_pickle(idx__WD__division__gelderland__tmp1__df_path)
# Out:
# c:\Users\NL1G3K\Desktop\Vegetation_quality_monitoring\.pixi\envs\default\Lib\site-packages\pyogrio\core.py:34: RuntimeWarning: Could not detect GDAL data files. Set GDAL_DATA environment variable to the correct path.
#   _init_gdal_data()

# %%
# --- Habitat kart plusOW GPKGs ---
habitat_kart_plusOW_cols_to_keep = ['years', 'habitatType1', 'habitatnaam_1_disp', 'bedekkingsOppervlakte1', 'bedekkingsPercentage1', 'geometry']

# Gelderland 
habitat_kart_plusOW__merged__gelderland__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart_plusOW__merged__gelderland__RD__gpkg_path,
    layer='habitat_kart_plusOW__merged__gelderland__RD__layer',
    index_col='index',
    cols_to_keep=habitat_kart_plusOW_cols_to_keep,
)

# Gelderland minHR
habitat_kart_plusOW__merged__gelderland_minHR__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart_plusOW__merged__gelderland_minHR__RD__gpkg_path,
    layer='habitat_kart_plusOW__merged__gelderland_minHR__RD__layer',
    index_col='index',
    cols_to_keep=habitat_kart_plusOW_cols_to_keep,
)

# Website 
habitat_kart_plusOW__merged__website__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart_plusOW__merged__website__RD__gpkg_path,
    layer='habitat_kart_plusOW__merged__website__RD__layer',
    index_col='index',
    cols_to_keep=habitat_kart_plusOW_cols_to_keep,
)

# Website plus hr 
habitat_kart_plusOW__merged__website_plusHR__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart_plusOW__merged__website_plusHR__RD__gpkg_path,
    layer='habitat_kart_plusOW__merged__website_plusHR__RD__layer',
    index_col='index',
    cols_to_keep=habitat_kart_plusOW_cols_to_keep,
)

# %%
# --- Selection reference dfs ---
habitat_reference__WD__df = pd.read_pickle(habitat_reference__WD__df_path)
habitat_reference__s__df = pd.read_pickle(habitat_reference__s__df_path)

# %% [markdown]
# ## Build new idx dfs

# %%
# AO tmp1
idx__AO_plusOW__division__gelderland__tmp1__df, idx__AO_plusOW__division__gelderland__tmp1__count = tmp_1_idx_df_func(habitat_kart_plusOW__merged__gelderland__RD__gdf)
idx__AO_plusOW__division__gelderland_minHR__tmp1__df, idx__AO_plusOW__division__gelderland_minHR__tmp1__count = tmp_1_idx_df_func(habitat_kart_plusOW__merged__gelderland_minHR__RD__gdf)
idx__AO_plusOW__division__website__tmp1__df, idx__AO_plusOW__division__website__tmp1__count = tmp_1_idx_df_func(habitat_kart_plusOW__merged__website__RD__gdf)
idx__AO_plusOW__division__website_plusHR__tmp1__df, idx__AO_plusOW__division__website_plusHR__tmp1__count = tmp_1_idx_df_func(habitat_kart_plusOW__merged__website_plusHR__RD__gdf)

# %%
# HB tmp1
idx__HB_plusOW__division__gelderland__tmp1__df, idx__HB_plusOW__division__gelderland__tmp1__count = HT_idx_df_func(
    gdf=habitat_kart_plusOW__merged__gelderland__RD__gdf,
    idx_df=idx__AO_plusOW__division__gelderland__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
)

idx__HB_plusOW__division__gelderland_minHR__tmp1__df, idx__HB_plusOW__division__gelderland_minHR__tmp1__count = HT_idx_df_func(
    gdf=habitat_kart_plusOW__merged__gelderland_minHR__RD__gdf,
    idx_df=idx__AO_plusOW__division__gelderland_minHR__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
)

idx__HB_plusOW__division__website__tmp1__df, idx__HB_plusOW__division__website__tmp1__count = HT_idx_df_func(
    gdf=habitat_kart_plusOW__merged__website__RD__gdf,
    idx_df=idx__AO_plusOW__division__website__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
)

idx__HB_plusOW__division__website_plusHR__tmp1__df, idx__HB_plusOW__division__website_plusHR__tmp1__count = HT_idx_df_func(
    gdf=habitat_kart_plusOW__merged__website_plusHR__RD__gdf,
    idx_df=idx__AO_plusOW__division__website_plusHR__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
)

# %%
# FC tmp1
idx__FC_plusOW__division__gelderland__tmp1__df, idx__FC_plusOW__division__gelderland__tmp1__count = FC_idx_df_func(
    gdf=habitat_kart_plusOW__merged__gelderland__RD__gdf,
    idx_df=idx__HB_plusOW__division__gelderland__tmp1__df,
)

idx__FC_plusOW__division__gelderland_minHR__tmp1__df, idx__FC_plusOW__division__gelderland_minHR__tmp1__count = FC_idx_df_func(
    gdf=habitat_kart_plusOW__merged__gelderland_minHR__RD__gdf,
    idx_df=idx__HB_plusOW__division__gelderland_minHR__tmp1__df,
)

idx__FC_plusOW__division__website__tmp1__df, idx__FC_plusOW__division__website__tmp1__count = FC_idx_df_func(
    gdf=habitat_kart_plusOW__merged__website__RD__gdf,
    idx_df=idx__HB_plusOW__division__website__tmp1__df,
)

idx__FC_plusOW__division__website_plusHR__tmp1__df, idx__FC_plusOW__division__website_plusHR__tmp1__count = FC_idx_df_func(
    gdf=habitat_kart_plusOW__merged__website_plusHR__RD__gdf,
    idx_df=idx__HB_plusOW__division__website_plusHR__tmp1__df,
)

# %%
# WD tmp1
idx__WD_plusOW__division__gelderland__tmp1__df, idx__WD_plusOW__division__gelderland__tmp1__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__merged__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW__division__gelderland__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD_division',
)

idx__WD_plusOW__division__gelderland_minHR__tmp1__df, idx__WD_plusOW__division__gelderland_minHR__tmp1__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__merged__gelderland_minHR__RD__gdf,
    idx_df=idx__FC_plusOW__division__gelderland_minHR__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD_division',
)

idx__WD_plusOW__division__website__tmp1__df, idx__WD_plusOW__division__website__tmp1__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__merged__website__RD__gdf,
    idx_df=idx__FC_plusOW__division__website__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD_division',
)

idx__WD_plusOW__division__website_plusHR__tmp1__df, idx__WD_plusOW__division__website_plusHR__tmp1__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__merged__website_plusHR__RD__gdf,
    idx_df=idx__FC_plusOW__division__website_plusHR__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD_division',
)

# %%
# s1 tmp1 
idx__s1_plusOW__division__gelderland__tmp1__df, idx__s1_plusOW__division__gelderland__tmp1__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__merged__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW__division__gelderland__tmp1__df,
    habitat_types_df=habitat_reference__s__df,
    habitat_col='habitatType1',
    group_col='s1_division',
)

idx__s1_plusOW__division__gelderland_minHR__tmp1__df, idx__s1_plusOW__division__gelderland_minHR__tmp1__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__merged__gelderland_minHR__RD__gdf,
    idx_df=idx__FC_plusOW__division__gelderland_minHR__tmp1__df,
    habitat_types_df=habitat_reference__s__df,
    habitat_col='habitatType1',
    group_col='s1_division',
)

idx__s1_plusOW__division__website__tmp1__df, idx__s1_plusOW__division__website__tmp1__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__merged__website__RD__gdf,
    idx_df=idx__FC_plusOW__division__website__tmp1__df,
    habitat_types_df=habitat_reference__s__df,
    habitat_col='habitatType1',
    group_col='s1_division',
)

idx__s1_plusOW__division__website_plusHR__tmp1__df, idx__s1_plusOW__division__website_plusHR__tmp1__count = group_idx_df_func(
    gdf=habitat_kart_plusOW__merged__website_plusHR__RD__gdf,
    idx_df=idx__FC_plusOW__division__website_plusHR__tmp1__df,
    habitat_types_df=habitat_reference__s__df,
    habitat_col='habitatType1',
    group_col='s1_division',
)

# %% [markdown]
# ## Saving the idx dfs

# %%
idx__AO_plusOW__division__gelderland__tmp1__df.to_pickle(idx__AO_plusOW__division__gelderland__tmp1__df_path)
idx__AO_plusOW__division__gelderland_minHR__tmp1__df.to_pickle(idx__AO_plusOW__division__gelderland_minHR__tmp1__df_path)
idx__AO_plusOW__division__website__tmp1__df.to_pickle(idx__AO_plusOW__division__website__tmp1__df_path)
idx__AO_plusOW__division__website_plusHR__tmp1__df.to_pickle(idx__AO_plusOW__division__website_plusHR__tmp1__df_path)

idx__WD_plusOW__division__gelderland__tmp1__df.to_pickle(idx__WD_plusOW__division__gelderland__tmp1__df_path)
idx__WD_plusOW__division__gelderland_minHR__tmp1__df.to_pickle(idx__WD_plusOW__division__gelderland_minHR__tmp1__df_path)
idx__WD_plusOW__division__website__tmp1__df.to_pickle(idx__WD_plusOW__division__website__tmp1__df_path)
idx__WD_plusOW__division__website_plusHR__tmp1__df.to_pickle(idx__WD_plusOW__division__website_plusHR__tmp1__df_path)

idx__s1_plusOW__division__gelderland__tmp1__df.to_pickle(idx__s1_plusOW__division__gelderland__tmp1__df_path)
idx__s1_plusOW__division__gelderland_minHR__tmp1__df.to_pickle(idx__s1_plusOW__division__gelderland_minHR__tmp1__df_path)
idx__s1_plusOW__division__website__tmp1__df.to_pickle(idx__s1_plusOW__division__website__tmp1__df_path)
idx__s1_plusOW__division__website_plusHR__tmp1__df.to_pickle(idx__s1_plusOW__division__website_plusHR__tmp1__df_path)

# %% [markdown]
# ## Checking the pixel count

# %%
tmp_1_year = ['2010-2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
pixel_count__WD_plusOW__division__gelderland__tmp1__df, pixel_count__WD__division__gelderland__tmp1__count = pixel_count_df_func(
    gdf=habitat_kart_plusOW__merged__gelderland__RD__gdf,
    idx_df=idx__WD_plusOW__division__gelderland__tmp1__df,
    area_col="bedekkingsOppervlakte1",
)

# %%
pixel_vis_func(pixel_count__WD_plusOW__division__gelderland__tmp1__df, tmp_1_year, title="WD plusOW gelderland")
# Out:
# <style type="text/css">
# #T_e6043 th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_e6043 th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_e6043 caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# #T_e6043_row0_col0, #T_e6043_row0_col1, #T_e6043_row0_col2, #T_e6043_row0_col3, #T_e6043_row0_col4, #T_e6043_row0_col5, #T_e6043_row0_col6, #T_e6043_row0_col7, #T_e6043_row0_col8, #T_e6043_row2_col0, #T_e6043_row2_col1, #T_e6043_row2_col2, #T_e6043_row2_col3, #T_e6043_row2_col4, #T_e6043_row2_col5, #T_e6043_row2_col6, #T_e6043_row2_col7, #T_e6043_row2_col8, #T_e6043_row4_col0, #T_e6043_row4_col1, #T_e6043_row4_col2, #T_e6043_row4_col3, #T_e6043_row4_col4, #T_e6043_row4_col5, #T_e6043_row4_col6, #T_e6043_row4_col7, #T_e6043_row4_col8 {
# ...

# %%
pixel_count__WD_plusOW__division__website_plusHR__tmp1__df, pixel_count__WD__division__website_plusHR__tmp1__count = pixel_count_df_func(
    gdf=habitat_kart_plusOW__merged__website_plusHR__RD__gdf,
    idx_df=idx__WD_plusOW__division__website_plusHR__tmp1__df,
    area_col="bedekkingsOppervlakte1",
)

# %%
pixel_vis_func(pixel_count__WD_plusOW__division__website_plusHR__tmp1__df, tmp_1_year, title="WD plusOW website_plusHR")
# Out:
# <style type="text/css">
# #T_02603 th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_02603 th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_02603 caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# #T_02603_row0_col0, #T_02603_row0_col1, #T_02603_row0_col2, #T_02603_row0_col3, #T_02603_row0_col4, #T_02603_row0_col5, #T_02603_row0_col6, #T_02603_row0_col7, #T_02603_row0_col8, #T_02603_row2_col0, #T_02603_row2_col1, #T_02603_row2_col2, #T_02603_row2_col3, #T_02603_row2_col4, #T_02603_row2_col5, #T_02603_row2_col6, #T_02603_row2_col7, #T_02603_row2_col8, #T_02603_row4_col0, #T_02603_row4_col1, #T_02603_row4_col2, #T_02603_row4_col3, #T_02603_row4_col4, #T_02603_row4_col5, #T_02603_row4_col6, #T_02603_row4_col7, #T_02603_row4_col8 {
# ...

# %%
pixel_count__s1_plusOW__division__gelderland__tmp1__df, pixel_count__s1__division__gelderland__tmp1__count = pixel_count_df_func(
    gdf=habitat_kart_plusOW__merged__gelderland__RD__gdf,
    idx_df=idx__s1_plusOW__division__gelderland__tmp1__df,
    area_col="bedekkingsOppervlakte1",
)

# %%
pixel_vis_func(pixel_count__s1_plusOW__division__gelderland__tmp1__df, tmp_1_year, title="s1 plusOW gelderland")
# Out:
# <style type="text/css">
# #T_bfc0f th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_bfc0f th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_bfc0f caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# ...

# %%
pixel_count__s1_plusOW__division__website_plusHR__tmp1__df, pixel_count__s1__division__website_plusHR__tmp1__count = pixel_count_df_func(
    gdf=habitat_kart_plusOW__merged__website_plusHR__RD__gdf,
    idx_df=idx__s1_plusOW__division__website_plusHR__tmp1__df,
    area_col="bedekkingsOppervlakte1",
)

# %%
pixel_vis_func(pixel_count__s1_plusOW__division__website_plusHR__tmp1__df, tmp_1_year, title="s1 plusOW website_plusHR")
# Out:
# <style type="text/css">
# #T_e73c9 th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_e73c9 th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_e73c9 caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# ...

# %% [markdown]
# ## Plotting the difference with and without plusOW

# %%
fig, ax, plot_gdf = idx_to_gdf_plot_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    idx_df=idx__WD__division__gelderland__tmp1__df,      
    year_cols=tmp_1_year,
    lut_df=habitat_reference__WD__df,
    typology_col="habitatnaam_1_disp",
    lut_set_col="WD_division",
    lut_color_col="WD_color",
    plot_unselected=True,
)
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
fig, ax, plot_gdf = idx_to_gdf_plot_func(
    gdf=habitat_kart_plusOW__merged__gelderland__RD__gdf,
    idx_df=idx__WD_plusOW__division__gelderland__tmp1__df,      
    year_cols=tmp_1_year,
    lut_df=habitat_reference__WD__df,
    typology_col="habitatnaam_1_disp",
    lut_set_col="WD_division",
    lut_color_col="WD_color",
    plot_unselected=True,
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 5
#       1 fig, ax, plot_gdf = idx_to_gdf_plot_func(
#       2     gdf=habitat_kart_plusOW__merged__gelderland__RD__gdf,
#       3     idx_df=idx__WD_plusOW__division__gelderland__tmp1__df,
#       4     year_cols=tmp_1_year,
# ----> 5     lut_df=habitat_reference__HB__df,
#       6     typology_col="habitatnaam_1_disp",
#       7     lut_set_col="WD_division",
#       8     lut_color_col="WD_color",
#       9     plot_unselected=True,
#      10 )
#      11 plt.show()
#
# NameError: name 'habitat_reference__HB__df' is not defined

# %% [markdown]
# End of the Notebook
