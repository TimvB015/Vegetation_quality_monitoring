# %% [markdown]
# _This Notebook adds the LGN open water polygons to the habitat dataset._

# %% [markdown]
# ## Importing Functions

# %%
from functions.raster_io_funcs import (
    raster_bordering_pixels_to_polygon,
)

from functions.gpkg_funcs import (
    import_gpkg_func,
    prefix_index,
)

from functions.io_funcs import (
    batch_func
)

from notebooks_dir._02_hab_kart_selection_and_division._support._n03_funcs import (
    remove_habitat_overlap_from_lgn,
    tidy_lgn_output,
    overlap_all_years_geoms,
    add_lgn_to_habitat_kart_and_save,
)
# Out:
# Cannot find header.dxf (GDAL_DATA is not defined)

# %% [markdown]
# ## Setting Directory

# %%
# years definition
tmp_1_year = ['2010-2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']
years_2018_2024 = [2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
from paths.OG_paths import (
    #######################################
    #          GENERAL POLYGONS           #
    #######################################
    # |         Veluwe polygons           |
    # +===================================+ 
    veluwe_polygon__n2000__RD__gpkg_path,
    veluwe_polygon__ruim__RD__gpkg_path,
    veluwe_polygon__aoi__RD__gpkg_path,


    #######################################
    #            00_common_dfs            #
    #######################################
    # |    n01_habitat_reference_dfs      |
    # +===================================+ 
    habitat_reference__WD__df_path,
    habitat_reference__s__df_path,
    

    #######################################
    #     01_pre_processing_hab_kart      #
    #######################################
    # |  n01_T0_habitat_gpkg_processing   |
    # +===================================+ 
    # --- Habitat kart Processed GPKG --- #
    habitat_kart__processed__gelderland__RD__gpkg_path,
    habitat_kart__processed__gelderland_minHR__RD__gpkg_path,
    habitat_kart__processed__website__RD__gpkg_path,
    habitat_kart__processed__website_plusHR__RD__gpkg_path,

    # +===================================+ 
    # |      n03_extract_OW_from_LGN      |
    # +===================================+ 
    # --- LGN_OW n2000 clip rstr --- #
    # DIR
    lgn_plusOW__n2000__clip__rstr_dir,
    # RD
    lgn2018_plusOW__n2000__clip__RD__rstr_path,
    lgn2019_plusOW__n2000__clip__RD__rstr_path,
    lgn2020_plusOW__n2000__clip__RD__rstr_path,
    lgn2021_plusOW__n2000__clip__RD__rstr_path,
    lgn2022_plusOW__n2000__clip__RD__rstr_path,
    lgn2023_plusOW__n2000__clip__RD__rstr_path,
    lgn2024_plusOW__n2000__clip__RD__rstr_path,    


    #######################################
    #  02_hab_kart_selection_and_division #
    #######################################
    # |    n03_add_LGN_OW_to_hab_kart     |
    # +===================================+
    # --- lgn OW RD gpkg --- #
    lgn2018_plusOW__n2000__clip__RD__gpkg_path,
    lgn2019_plusOW__n2000__clip__RD__gpkg_path,
    lgn2020_plusOW__n2000__clip__RD__gpkg_path,
    lgn2021_plusOW__n2000__clip__RD__gpkg_path,
    lgn2022_plusOW__n2000__clip__RD__gpkg_path,
    lgn2023_plusOW__n2000__clip__RD__gpkg_path,
    lgn2024_plusOW__n2000__clip__RD__gpkg_path,

    # --- lgn OW processed RD gpkgs --- #
    # Gelderland
    lgn2018_plusOW__n2000__processed__gelderland__RD__gpkg_path,
    lgn2019_plusOW__n2000__processed__gelderland__RD__gpkg_path,
    lgn2020_plusOW__n2000__processed__gelderland__RD__gpkg_path,
    lgn2021_plusOW__n2000__processed__gelderland__RD__gpkg_path,
    lgn2022_plusOW__n2000__processed__gelderland__RD__gpkg_path,
    lgn2023_plusOW__n2000__processed__gelderland__RD__gpkg_path,
    lgn2024_plusOW__n2000__processed__gelderland__RD__gpkg_path,
    # Gelderland minHR
    lgn2018_plusOW__n2000__processed__gelderland_minHR__RD__gpkg_path,
    lgn2019_plusOW__n2000__processed__gelderland_minHR__RD__gpkg_path,
    lgn2020_plusOW__n2000__processed__gelderland_minHR__RD__gpkg_path,
    lgn2021_plusOW__n2000__processed__gelderland_minHR__RD__gpkg_path,
    lgn2022_plusOW__n2000__processed__gelderland_minHR__RD__gpkg_path,
    lgn2023_plusOW__n2000__processed__gelderland_minHR__RD__gpkg_path,
    lgn2024_plusOW__n2000__processed__gelderland_minHR__RD__gpkg_path,
    # website
    lgn2018_plusOW__n2000__processed__website__RD__gpkg_path,
    lgn2019_plusOW__n2000__processed__website__RD__gpkg_path,
    lgn2020_plusOW__n2000__processed__website__RD__gpkg_path,
    lgn2021_plusOW__n2000__processed__website__RD__gpkg_path,
    lgn2022_plusOW__n2000__processed__website__RD__gpkg_path,
    lgn2023_plusOW__n2000__processed__website__RD__gpkg_path,
    lgn2024_plusOW__n2000__processed__website__RD__gpkg_path,
    # website plusHR
    lgn2018_plusOW__n2000__processed__website_plusHR__RD__gpkg_path,
    lgn2019_plusOW__n2000__processed__website_plusHR__RD__gpkg_path,
    lgn2020_plusOW__n2000__processed__website_plusHR__RD__gpkg_path,
    lgn2021_plusOW__n2000__processed__website_plusHR__RD__gpkg_path,
    lgn2022_plusOW__n2000__processed__website_plusHR__RD__gpkg_path,
    lgn2023_plusOW__n2000__processed__website_plusHR__RD__gpkg_path,
    lgn2024_plusOW__n2000__processed__website_plusHR__RD__gpkg_path,

    # --- lgn OW stacked GPKG --- #
    lgn_plusOW__n2000__stacked__gelderland__RD__gpkg_path,
    lgn_plusOW__n2000__stacked__gelderland_minHR__RD__gpkg_path,
    lgn_plusOW__n2000__stacked__website__RD__gpkg_path,
    lgn_plusOW__n2000__stacked__website_plusHR__RD__gpkg_path,

    # --- hab kart plusOw merged GPKG --- #
    # DIRs
    habitat_kart__processed__gelderland__gpkg_dir,
    habitat_kart__processed__gelderland_minHR__gpkg_dir,
    habitat_kart__processed__website__gpkg_dir,
    habitat_kart__processed__website_plusHR__gpkg_dir,
    # GPKGs RD
    habitat_kart_plusOW__merged__gelderland__RD__gpkg_path,
    habitat_kart_plusOW__merged__gelderland_minHR__RD__gpkg_path,
    habitat_kart_plusOW__merged__website__RD__gpkg_path,
    habitat_kart_plusOW__merged__website_plusHR__RD__gpkg_path,
)

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd
import geopandas as gpd
# from matplotlib import pyplot as plt

# %% [markdown]
# ## Importing files

# %%
# --- Habitat kart Processed GPKGs ---
habitat_kart_cols_to_keep = ['years', 'habitatType1', 'habitatnaam_1_disp', 'bedekkingsPercentage1', 'bedekkingsOppervlakte1', 'geometry']

# Gelderland 
habitat_kart__processed__gelderland__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__gelderland__RD__gpkg_path,
    layer='habitat_kart__processed__gelderland__RD__layer',
    index_col='index',
    cols_to_keep=habitat_kart_cols_to_keep,
)

# Gelderland min hr 
habitat_kart__processed__gelderland_minHR__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__gelderland_minHR__RD__gpkg_path,
    layer='habitat_kart__processed__gelderland_minHR__RD__layer',
    index_col='index',
    cols_to_keep=habitat_kart_cols_to_keep,
)

# Website 
habitat_kart__processed__website__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__website__RD__gpkg_path,
    layer='habitat_kart__processed__website__RD__layer',
    index_col='index',
    cols_to_keep=habitat_kart_cols_to_keep,
)

# Website plus hr 
habitat_kart__processed__website_plusHR__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__website_plusHR__RD__gpkg_path,
    layer='habitat_kart__processed__website_plusHR__RD__layer',
    index_col='index',
    cols_to_keep=habitat_kart_cols_to_keep,
)
# Out:
# c:\Users\NL1G3K\Desktop\Vegetation_quality_monitoring\.pixi\envs\default\Lib\site-packages\pyogrio\core.py:34: RuntimeWarning: Could not detect GDAL data files. Set GDAL_DATA environment variable to the correct path.
#   _init_gdal_data()

# %%
# --- Veluwe Polygons ---
veluwe_polygon__n2000__RD__gdf = import_gpkg_func(
    gdf_path=veluwe_polygon__n2000__RD__gpkg_path,
    layer='natura2000',
)

veluwe_polygon__ruim__RD__gdf = import_gpkg_func(
    gdf_path=veluwe_polygon__ruim__RD__gpkg_path,
    layer='ruime_veluwe_cut_RD',
)

veluwe_polygon__aoi__RD__gdf = import_gpkg_func(
    gdf_path=veluwe_polygon__aoi__RD__gpkg_path,
    layer='vennen_interesse_RD',
    cols_to_keep=['Naam', 'geometry'],
)

# %%
# --- Selection reference dfs ---
habitat_reference__WD__df = pd.read_pickle(habitat_reference__WD__df_path)
habitat_reference__s__df = pd.read_pickle(habitat_reference__s__df_path)

# %% [markdown]
# ## Saving the Open Water raster as a geopackage

# %%
lgn_plusOW__n2000__clip__RD__gdf_template = """
lgn{year}_plusOW__n2000__clip__RD__gdf = raster_bordering_pixels_to_polygon(
    raster_path=lgn{year}_plusOW__n2000__clip__RD__rstr_path,
    drop_nodata=True,
)

lgn{year}_plusOW__n2000__clip__RD__gdf.to_file(
    lgn{year}_plusOW__n2000__clip__RD__gpkg_path,
    layer="lgn{year}_plusOW__n2000__clip__RD__layer",
    driver='GPKG'
)
"""

batch_func(years=years_2018_2024, template=lgn_plusOW__n2000__clip__RD__gdf_template, globals_dict=globals())
# Out:
# c:\Users\NL1G3K\Desktop\Vegetation_quality_monitoring\.pixi\envs\default\Lib\site-packages\rasterio\features.py:129: RuntimeWarning: DeprecationWarning: 'Memory' driver is deprecated since GDAL 3.11. Use 'MEM' onwards. Further messages of this type will be suppressed.
#   yield from _shapes(source, mask, connectivity, transform)

# %% [markdown]
# ## Removing overlap between LGN Open Water polygon and Habitatmap Open Water areas

# %%
# Removing Gelderland overlap
lgn_plusOW__n2000__processed__gelderland__RD__gdf_template = """
lgn{year}_plusOW__n2000__processed__gelderland__RD__gpkg_path = lgn{year}_plusOW__n2000__processed__gelderland__RD__gpkg_path

# removing overlap
lgn{year}_plusOW__n2000__step1__gelderland__RD__gdf = remove_habitat_overlap_from_lgn(
    habitat_gdf=habitat_kart__processed__gelderland__RD__gdf,
    lgn_gdf=lgn{year}_plusOW__n2000__clip__RD__gdf,
    year={year},
)

# adding index, habitaType1, bedekkingsOppervlakte and bedekkingsPercentage
lgn{year}_plusOW__n2000__processed__gelderland__RD__gdf = tidy_lgn_output(
    gdf=lgn{year}_plusOW__n2000__step1__gelderland__RD__gdf,
    years={year},
    code_prefix="lgn_plusOW_{year}",
    habitatType1_value="LGN_OW",
    habitatnaam_value="Open water",
    habitatnaam_disp_col="habitatnaam_1_disp",
)

# Saving to gpkg
lgn{year}_plusOW__n2000__processed__gelderland__RD__gdf.to_file(
    lgn{year}_plusOW__n2000__processed__gelderland__RD__gpkg_path,
    layer="lgn{year}_plusOW__n2000__processed__gelderland__RD__layer",
    driver='GPKG',
)
"""

batch_func(years=years_2018_2024, template=lgn_plusOW__n2000__processed__gelderland__RD__gdf_template, globals_dict=globals())

# %%
# Removing Gelderland_minHR overlap
lgn_plusOW__n2000__processed__gelderland_minHR__RD__gdf_template = """
lgn{year}_plusOW__n2000__processed__gelderland_minHR__RD__gpkg_path = lgn{year}_plusOW__n2000__processed__gelderland_minHR__RD__gpkg_path

# removing overlap
lgn{year}_plusOW__n2000__step1__gelderland_minHR__RD__gdf = remove_habitat_overlap_from_lgn(
    habitat_gdf=habitat_kart__processed__gelderland_minHR__RD__gdf,
    lgn_gdf=lgn{year}_plusOW__n2000__clip__RD__gdf,
    year={year},
)

# adding index, habitaType1, bedekkingsOppervlakte and bedekkingsPercentage
lgn{year}_plusOW__n2000__processed__gelderland_minHR__RD__gdf = tidy_lgn_output(
    gdf=lgn{year}_plusOW__n2000__step1__gelderland_minHR__RD__gdf,
    years={year},
    code_prefix="lgn_plusOW_{year}",
    habitatType1_value="LGN_OW",
    habitatnaam_value="Open water",
    habitatnaam_disp_col="habitatnaam_1_disp",
)

# Saving to gpkg
lgn{year}_plusOW__n2000__processed__gelderland_minHR__RD__gdf.to_file(
    lgn{year}_plusOW__n2000__processed__gelderland_minHR__RD__gpkg_path,
    layer="lgn{year}_plusOW__n2000__processed__gelderland_minHR__RD__layer",
    driver='GPKG',
)
"""

batch_func(years=years_2018_2024, template=lgn_plusOW__n2000__processed__gelderland_minHR__RD__gdf_template, globals_dict=globals())
# Out:
# <string>:5: UserWarning: No habitat features matched year=2023 in column 'years'. Returning LGN unchanged for this year.

# %%
# Removing website overlap
lgn_plusOW__n2000__processed__website__RD__gdf_template = """
lgn{year}_plusOW__n2000__processed__website__RD__gpkg_path = lgn{year}_plusOW__n2000__processed__website__RD__gpkg_path

# removing overlap
lgn{year}_plusOW__n2000__step1__website__RD__gdf = remove_habitat_overlap_from_lgn(
    habitat_gdf=habitat_kart__processed__website__RD__gdf,
    lgn_gdf=lgn{year}_plusOW__n2000__clip__RD__gdf,
    year={year},
)

# adding index, habitaType1, bedekkingsOppervlakte and bedekkingsPercentage
lgn{year}_plusOW__n2000__processed__website__RD__gdf = tidy_lgn_output(
    gdf=lgn{year}_plusOW__n2000__step1__website__RD__gdf,
    years={year},
    code_prefix="lgn_plusOW_{year}",
    habitatType1_value="LGN_OW",
    habitatnaam_value="Open water",
    habitatnaam_disp_col="habitatnaam_1_disp",
)

lgn{year}_plusOW__n2000__processed__website__RD__gdf.to_file(
    lgn{year}_plusOW__n2000__processed__website__RD__gpkg_path,
    layer="lgn{year}_plusOW__n2000__processed__website__RD__layer",
    driver='GPKG',
)
"""

batch_func(years=years_2018_2024, template=lgn_plusOW__n2000__processed__website__RD__gdf_template, globals_dict=globals())

# %%
# Removing website_plusHR overlap
lgn_plusOW__n2000__processed__website_plusHR__RD__gdf_template = """
lgn{year}_plusOW__n2000__processed__website_plusHR__RD__gpkg_path = lgn{year}_plusOW__n2000__processed__website_plusHR__RD__gpkg_path

# removing overlap
lgn{year}_plusOW__n2000__step1__website_plusHR__RD__gdf = remove_habitat_overlap_from_lgn(
    habitat_gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    lgn_gdf=lgn{year}_plusOW__n2000__clip__RD__gdf,
    year={year},
)

# adding index, habitaType1, bedekkingsOppervlakte and bedekkingsPercentage
lgn{year}_plusOW__n2000__processed__website_plusHR__RD__gdf = tidy_lgn_output(
    gdf=lgn{year}_plusOW__n2000__step1__website_plusHR__RD__gdf,
    years={year},
    code_prefix="lgn_plusOW_{year}",
    habitatType1_value="LGN_OW",
    habitatnaam_value="Open water",
    habitatnaam_disp_col="habitatnaam_1_disp",
)

lgn{year}_plusOW__n2000__processed__website_plusHR__RD__gdf.to_file(
    lgn{year}_plusOW__n2000__processed__website_plusHR__RD__gpkg_path,
    layer="lgn{year}_plusOW__n2000__processed__website_plusHR__RD__layer",
    driver='GPKG',
)
"""

batch_func(years=years_2018_2024, template=lgn_plusOW__n2000__processed__website_plusHR__RD__gdf_template, globals_dict=globals())

# %% [markdown]
# ## Add the Open Water polygon to the Habitat kart gpkg and save

# %%
# First make one big lgn gdf
lgn_plusOW__n2000__stacked__gelderland__RD__gdf_collection = [
    lgn2018_plusOW__n2000__processed__gelderland__RD__gdf,
    lgn2019_plusOW__n2000__processed__gelderland__RD__gdf,
    lgn2020_plusOW__n2000__processed__gelderland__RD__gdf,
    lgn2021_plusOW__n2000__processed__gelderland__RD__gdf,
    lgn2022_plusOW__n2000__processed__gelderland__RD__gdf,
    lgn2023_plusOW__n2000__processed__gelderland__RD__gdf,
    lgn2024_plusOW__n2000__processed__gelderland__RD__gdf,
]

lgn_plusOW__n2000__stacked__gelderland_minHR__RD__gdf_collection = [
    lgn2018_plusOW__n2000__processed__gelderland_minHR__RD__gdf,
    lgn2019_plusOW__n2000__processed__gelderland_minHR__RD__gdf,
    lgn2020_plusOW__n2000__processed__gelderland_minHR__RD__gdf,
    lgn2021_plusOW__n2000__processed__gelderland_minHR__RD__gdf,
    lgn2022_plusOW__n2000__processed__gelderland_minHR__RD__gdf,
    lgn2023_plusOW__n2000__processed__gelderland_minHR__RD__gdf,
    lgn2024_plusOW__n2000__processed__gelderland_minHR__RD__gdf,
]

lgn_plusOW__n2000__stacked__website__RD__gdf_collection = [
    lgn2018_plusOW__n2000__processed__website__RD__gdf,
    lgn2019_plusOW__n2000__processed__website__RD__gdf,
    lgn2020_plusOW__n2000__processed__website__RD__gdf,
    lgn2021_plusOW__n2000__processed__website__RD__gdf,
    lgn2022_plusOW__n2000__processed__website__RD__gdf,
    lgn2023_plusOW__n2000__processed__website__RD__gdf,
    lgn2024_plusOW__n2000__processed__website__RD__gdf,
]

lgn_plusOW__n2000__stacked__website_plusHR__RD__gdf_collection = [
    lgn2018_plusOW__n2000__processed__website_plusHR__RD__gdf,
    lgn2019_plusOW__n2000__processed__website_plusHR__RD__gdf,
    lgn2020_plusOW__n2000__processed__website_plusHR__RD__gdf,
    lgn2021_plusOW__n2000__processed__website_plusHR__RD__gdf,
    lgn2022_plusOW__n2000__processed__website_plusHR__RD__gdf,
    lgn2023_plusOW__n2000__processed__website_plusHR__RD__gdf,
    lgn2024_plusOW__n2000__processed__website_plusHR__RD__gdf,
]

# %%
# Gelderland
lgn_plusOW__n2000__stacked__gelderland__RD__gdf = overlap_all_years_geoms(
    lgn_plusOW__n2000__stacked__gelderland__RD__gdf_collection,
    years_col="years",
    out_years_col="years_combined",
)

lgn_plusOW__n2000__stacked__gelderland__RD__gdf = tidy_lgn_output(
    gdf=lgn_plusOW__n2000__stacked__gelderland__RD__gdf,
    years=lgn_plusOW__n2000__stacked__gelderland__RD__gdf["years_combined"].iloc[0],
    code_prefix="lgn_plusOW",
    habitatType1_value="LGN_OW",
    habitatnaam_value="Open water",
    habitatnaam_disp_col="habitatnaam_1_disp",
    apply_min_area=True,
    min_area_m2=100,
)

# %%
# Gelderland_minHR
lgn_plusOW__n2000__stacked__gelderland_minHR__RD__gdf = overlap_all_years_geoms(
    lgn_plusOW__n2000__stacked__gelderland_minHR__RD__gdf_collection,
    years_col="years",
    out_years_col="years_combined",
)

lgn_plusOW__n2000__stacked__gelderland_minHR__RD__gdf = tidy_lgn_output(
    gdf=lgn_plusOW__n2000__stacked__gelderland_minHR__RD__gdf,
    years=lgn_plusOW__n2000__stacked__gelderland_minHR__RD__gdf["years_combined"].iloc[0],
    code_prefix="lgn_plusOW",
    habitatType1_value="LGN_OW",
    habitatnaam_value="Open water",
    habitatnaam_disp_col="habitatnaam_1_disp",
    apply_min_area=True,
    min_area_m2=100,
)

# %%
# Website
lgn_plusOW__n2000__stacked__website__RD__gdf = overlap_all_years_geoms(
    lgn_plusOW__n2000__stacked__website__RD__gdf_collection,
    years_col="years",
    out_years_col="years_combined",
)

lgn_plusOW__n2000__stacked__website__RD__gdf = tidy_lgn_output(
    gdf=lgn_plusOW__n2000__stacked__website__RD__gdf,
    years=lgn_plusOW__n2000__stacked__website__RD__gdf["years_combined"].iloc[0],
    code_prefix="lgn_plusOW",
    habitatType1_value="LGN_OW",
    habitatnaam_value="Open water",
    habitatnaam_disp_col="habitatnaam_1_disp",
    apply_min_area=True,
    min_area_m2=100,
)

# %%
# Website_plusHR
lgn_plusOW__n2000__stacked__website_plusHR__RD__gdf = overlap_all_years_geoms(
    lgn_plusOW__n2000__stacked__website_plusHR__RD__gdf_collection,
    years_col="years",
    out_years_col="years_combined",
)

lgn_plusOW__n2000__stacked__website_plusHR__RD__gdf = tidy_lgn_output(
    gdf=lgn_plusOW__n2000__stacked__website_plusHR__RD__gdf,
    years=lgn_plusOW__n2000__stacked__website_plusHR__RD__gdf["years_combined"].iloc[0],
    code_prefix="lgn_plusOW",
    habitatType1_value="LGN_OW",
    habitatnaam_value="Open water",
    habitatnaam_disp_col="habitatnaam_1_disp",
    apply_min_area=True,
    min_area_m2=100,
)

# %%
# Save the all years LGN gdfs
lgn_plusOW__n2000__stacked__gelderland__RD__gdf.to_file(
    lgn_plusOW__n2000__stacked__gelderland__RD__gpkg_path, 
    layer="lgn_plusOW__n2000__stacked__gelderland__RD__layer", 
    driver='GPKG',
)

lgn_plusOW__n2000__stacked__gelderland_minHR__RD__gdf.to_file(
    lgn_plusOW__n2000__stacked__gelderland_minHR__RD__gpkg_path,
    layer="lgn_plusOW__n2000__stacked__gelderland_minHR__RD__layer",
    driver="GPKG",
)

lgn_plusOW__n2000__stacked__website__RD__gdf.to_file(
    lgn_plusOW__n2000__stacked__website__RD__gpkg_path,
    layer="lgn_plusOW__n2000__stacked__website__RD__layer",
    driver="GPKG",
)

lgn_plusOW__n2000__stacked__website_plusHR__RD__gdf.to_file(
    lgn_plusOW__n2000__stacked__website_plusHR__RD__gpkg_path,
    layer="lgn_plusOW__n2000__stacked__website_plusHR__RD__layer",
    driver="GPKG",
)

# %%
# Merge the Habitat kart gdf with the LGN gdf and save
habitat_kart_plusOW__merged__gelderland__RD__gdf = add_lgn_to_habitat_kart_and_save(
    habitat_kart_gdf=habitat_kart__processed__gelderland__RD__gdf,
    lgn_gdf=lgn_plusOW__n2000__stacked__gelderland__RD__gdf,
    out_dir=habitat_kart__processed__gelderland__gpkg_dir,
    out_name="habitat_kart_plusOW__merged__gelderland__RD__gpkg.gpkg",
    driver='GPKG',
    layer="habitat_kart_plusOW__merged__gelderland__RD__layer"
)

habitat_kart_plusOW__merged__gelderland_minHR__RD__gdf = add_lgn_to_habitat_kart_and_save(
    habitat_kart_gdf=habitat_kart__processed__gelderland_minHR__RD__gdf,
    lgn_gdf=lgn_plusOW__n2000__stacked__gelderland_minHR__RD__gdf,
    out_dir=habitat_kart__processed__gelderland_minHR__gpkg_dir,
    out_name="habitat_kart_plusOW__merged__gelderland_minHR__RD__gpkg.gpkg",
    driver="GPKG",
    layer="habitat_kart_plusOW__merged__gelderland_minHR__RD__layer",
)

habitat_kart_plusOW__merged__website__RD__gdf = add_lgn_to_habitat_kart_and_save(
    habitat_kart_gdf=habitat_kart__processed__website__RD__gdf,
    lgn_gdf=lgn_plusOW__n2000__stacked__website__RD__gdf,
    out_dir=habitat_kart__processed__website__gpkg_dir,
    out_name="habitat_kart_plusOW__merged__website__RD__gpkg.gpkg",
    driver="GPKG",
    layer="habitat_kart_plusOW__merged__website__RD__layer",
)

habitat_kart_plusOW__merged__website_plusHR__RD__gdf = add_lgn_to_habitat_kart_and_save(
    habitat_kart_gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    lgn_gdf=lgn_plusOW__n2000__stacked__website_plusHR__RD__gdf,
    out_dir=habitat_kart__processed__website_plusHR__gpkg_dir,
    out_name="habitat_kart_plusOW__merged__website_plusHR__RD__gpkg.gpkg",
    driver="GPKG",
    layer="habitat_kart_plusOW__merged__website_plusHR__RD__layer",
)

# %% [markdown]
# End of the Notebook
