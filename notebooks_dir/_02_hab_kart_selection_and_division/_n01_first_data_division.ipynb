# %% [markdown]
# _This Notebook builds dfs that keep track of the index (of each habitat polygon) based on each division. Note that the idx division build in this Notebook does NOT include the plusOW pixels. This was a first attempt, the dfs that track the pixels, go to "n01 build selected pixels idx dfs"_

# %% [markdown]
# ## Importing Functions

# %%
from functions.gpkg_funcs import (
    check_gpkg_layers_func,
    import_gpkg_func,
)

from functions.custom_common_nb_funcs import (
    check_processing,
)

from functions.idx_builder_funcs import (
    tmp_0_idx_df_func,
    tmp_1_idx_df_func,
    tmp2_idx_df_func,
    HT_idx_df_func,
    FC_idx_df_func,
    group_idx_df_func,
)

# %% [markdown]
# ## Setting directory

# %%
from paths.OG_paths import (
    #######################################
    #     01_pre_processing_hab_kart      #
    #######################################
    # |  n01_T0_habitat_gpkg_processing   |
    # +===================================+ 
    # --- Habitat kart Processed GPKG --- #
    habitat_kart__processed__gelderland__RD__gpkg_path,
    habitat_kart__processed__gelderland_minHR__RD__gpkg_path,
    habitat_kart__processed__website__RD__gpkg_path,
    habitat_kart__processed__website_plusHR__RD__gpkg_path,


    #######################################
    #            00_common_dfs            #
    #######################################
    # |    n01_habitat_reference_dfs      |
    # +===================================+ 
    habitat_reference__WD__df_path,
    habitat_reference__s__df_path,

    # +===================================+
    # |       n02_explanation_dfs         |
    # +===================================+ 
    explanation__hab_group_codes__df_path,
    explanation__tmp_codes__df_path,

    
    #######################################
    #  02_hab_kart_selection_and_division #
    #######################################
    # |      n01_first_data_division      |
    # +===================================+ 
    # AO tmp0
    idx__AO__division__gelderland__tmp0__df_path,
    idx__AO__division__gelderland_minHR__tmp0__df_path,
    idx__AO__division__website__tmp0__df_path,
    idx__AO__division__website_plusHR__tmp0__df_path,
    # AO tmp1
    idx__AO__division__gelderland__tmp1__df_path,
    idx__AO__division__gelderland_minHR__tmp1__df_path,
    idx__AO__division__website__tmp1__df_path,
    idx__AO__division__website_plusHR__tmp1__df_path,
    # HB tmp1
    idx__HB__division__gelderland__tmp1__df_path,
    idx__HB__division__gelderland_minHR__tmp1__df_path,
    idx__HB__division__website__tmp1__df_path,
    idx__HB__division__website_plusHR__tmp1__df_path,
    # FC tmp1
    idx__FC__division__gelderland__tmp1__df_path,
    idx__FC__division__gelderland_minHR__tmp1__df_path,
    idx__FC__division__website__tmp1__df_path,
    idx__FC__division__website_plusHR__tmp1__df_path,
    # WD tmp1
    idx__WD__division__gelderland__tmp1__df_path,
    idx__WD__division__gelderland_minHR__tmp1__df_path,
    idx__WD__division__website__tmp1__df_path,
    idx__WD__division__website_plusHR__tmp1__df_path,
    # s1 tmp1
    idx__s1__division__gelderland__tmp1__df_path,
    idx__s1__division__gelderland_minHR__tmp1__df_path,
    idx__s1__division__website__tmp1__df_path,
    idx__s1__division__website_plusHR__tmp1__df_path,
    # AO tmp2
    idx__AO__division__gelderland__tmp2__df_path,
    idx__AO__division__website_plusHR__tmp2__df_path,
    # HB tmp2
    idx__HB__division__gelderland__tmp2__df_path,
    idx__HB__division__website_plusHR__tmp2__df_path,
    # FC_p80 tmp2
    idx__FC_p80__division__gelderland__tmp2__df_path,
    idx__FC_p80__division__website_plusHR__tmp2__df_path,
)

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd

# pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Import Files

# %%
check_gpkg_layers_func(habitat_kart__processed__website_plusHR__RD__gpkg_path)
# Out:
# ['habitat_kart__processed__website_plusHR__RD__layer']

# %%
# --- Habitat kart Processed GPKGs ---
# Gelderland 
habitat_kart__processed__gelderland__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__gelderland__RD__gpkg_path, 
    layer='habitat_kart__processed__gelderland__RD__layer', 
    index_col='index'
)

# Gelderland min hr 
habitat_kart__processed__gelderland_minHR__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__gelderland_minHR__RD__gpkg_path, 
    layer='habitat_kart__processed__gelderland_minHR__RD__layer', 
    index_col='index'
)

# Website 
habitat_kart__processed__website__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__website__RD__gpkg_path,
    layer='habitat_kart__processed__website__RD__layer',
    index_col='index'
)

# Website plus hr 
habitat_kart__processed__website_plusHR__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart__processed__website_plusHR__RD__gpkg_path,
    layer='habitat_kart__processed__website_plusHR__RD__layer',
    index_col='index'
)
# Out:
# c:\Users\NL1G3K\Desktop\Vegetation_quality_monitoring\.pixi\envs\default\Lib\site-packages\pyogrio\geopandas.py:49: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   res = pd.to_datetime(ser, **datetime_kwargs)
# c:\Users\NL1G3K\Desktop\Vegetation_quality_monitoring\.pixi\envs\default\Lib\site-packages\pyogrio\geopandas.py:49: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   res = pd.to_datetime(ser, **datetime_kwargs)
# c:\Users\NL1G3K\Desktop\Vegetation_quality_monitoring\.pixi\envs\default\Lib\site-packages\pyogrio\geopandas.py:49: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   res = pd.to_datetime(ser, **datetime_kwargs)
# ...

# %%
# --- Selection reference dfs ---
habitat_reference__WD__df = pd.read_pickle(habitat_reference__WD__df_path)
habitat_reference__s__df = pd.read_pickle(habitat_reference__s__df_path)

# --- Explanation dfs ---
explanation__hab_group_codes__df = pd.read_pickle(explanation__hab_group_codes__df_path)
explanation__tmp_codes__df = pd.read_pickle(explanation__tmp_codes__df_path)

# %%
# Checking the import
values = [habitat_kart__processed__gelderland__RD__gdf.shape[0], habitat_kart__processed__gelderland_minHR__RD__gdf.shape[0],
          habitat_kart__processed__website__RD__gdf.shape[0], habitat_kart__processed__website_plusHR__RD__gdf.shape[0]]
entities = ["gelderland", "gelderland_min_hr", "website", "website_plus_hr"]

check_processing(values, entities, typ="AO", tmp="tmp0")
# Out:
# ['The number of habitat surveys is correct']

# %% [markdown]
# ## Information <br>
#
# Explanation on the the coding used in this notebook for filtering

# %%
habitat_reference__WD__df.head()
# Out:
#                              habitatnaam_disp habitat_color WD_division  \
# habitatType
# H0000                        Geen habitattype       #999999  No-Habitat
# H2310           Stuifzandheiden met struikhei       #fff7b2  Dry Nature
# H2320        Binnenlandse kraaheibegroeiingen       #8c564b  Dry Nature
# H2330                       Zandverstuivingen       #e8d6c3  Dry Nature
# H3130                   Zwakgebufferde vennen       #9ed6f8  Wet Nature
#
#             WD_color WD1_division WD1_color WD2_division WD2_color  \
# habitatType
# H0000        #aaaaaa    Remaining   #f54949    Remaining   #f54949
# H2310        #ffff99    Remaining   #f54949    Remaining   #f54949
# H2320        #ffff99    Remaining   #f54949    Remaining   #f54949
# H2330        #ffff99    Remaining   #f54949    Remaining   #f54949
# H3130        #0c82d1   Wet Nature   #0c82d1   Wet Nature   #0c82d1
#
#             WD3_division WD3_color WD4_division WD4_color WD5_division  \
# habitatType
# ...

# %%
habitat_reference__s__df.head()
# Out:
#                              habitatnaam_disp habitat_color  \
# habitatType
# H0000                        Geen habitattype       #999999
# H2310           Stuifzandheiden met struikhei       #fff7b2
# H2320        Binnenlandse kraaheibegroeiingen       #8c564b
# H2330                       Zandverstuivingen       #e8d6c3
# H3130                   Zwakgebufferde vennen       #9ed6f8
#
#                        s1_division s2_division
# habitatType
# H0000                          NaN         NaN
# H2310                    Remaining   Remaining
# H2320                    Remaining   Remaining
# H2330                    Remaining   Remaining
# H3130        Zwakgebufferde vennen         Ven

# %%
explanation__hab_group_codes__df
# Out:
#          Abbreviation                                        Explanation  \
# AO        All Objects         Contains all objects from the input .gpkgs
# HB            Habitat            Selected all objects with an H.... code
# FC         Full Cover        All objects with an H.... code + 100% cover
# WD  Wet-Dry selection  All habitat types divided into abiotic water c...
# S1        Selection 1  Only trainingdata with Vennen, Vochtige Heide,...
# S2        Selection 2                                  Yet to be defined
#
#    Only H.... codes Cover = 100%
# AO            False        False
# HB             True        False
# FC             True         True
# WD             True         True
# S1             True         True
# S2          unknown      unknown

# %%
explanation__tmp_codes__df
# Out:
#                                             Explanation
# tmp0      All years separate: .... | 2000 | 2001 | ....
# tmp1  Clustering of years 2010-2016. Then each year ...
# tmp2  Only observations for the years | 2017 | 2018 ...

# %% [markdown]
# ## Making IDX tables for AO [tmp0 & tmp1 & tmp2]

# %% [markdown]
# ### IDX AO tmp0

# %%
# AO tmp0 IDX table
idx__AO__division__gelderland__tmp0__df, idx__AO__division__gelderland__tmp0__count = tmp_0_idx_df_func(habitat_kart__processed__gelderland__RD__gdf)
idx__AO__division__gelderland_minHR__tmp0__df, idx__AO__division__gelderland_minHR__tmp0__count = tmp_0_idx_df_func(habitat_kart__processed__gelderland_minHR__RD__gdf)
idx__AO__division__website__tmp0__df, idx__AO__division__website__tmp0__count = tmp_0_idx_df_func(habitat_kart__processed__website__RD__gdf)
idx__AO__division__website_plusHR__tmp0__df, idx__AO__division__website_plusHR__tmp0__count = tmp_0_idx_df_func(habitat_kart__processed__website_plusHR__RD__gdf)

# %%
# Check AO tmp0 processing
values = [idx__AO__division__gelderland__tmp0__count, idx__AO__division__gelderland_minHR__tmp0__count,
          idx__AO__division__website__tmp0__count, idx__AO__division__website_plusHR__tmp0__count]
entities = ["gelderland", "gelderland_min_hr", "website", "website_plus_hr"]

check_processing(values, entities, typ="AO", tmp="tmp0")
# Out:
# ['The number of habitat surveys is correct']

# %%
# Save
idx__AO__division__gelderland__tmp0__df.to_pickle(idx__AO__division__gelderland__tmp0__df_path)
idx__AO__division__gelderland_minHR__tmp0__df.to_pickle(idx__AO__division__gelderland_minHR__tmp0__df_path)
idx__AO__division__website__tmp0__df.to_pickle(idx__AO__division__website__tmp0__df_path)
idx__AO__division__website_plusHR__tmp0__df.to_pickle(idx__AO__division__website_plusHR__tmp0__df_path)

# %% [markdown]
# ### IDX AO tmp1

# %%
# AO tmp1 IDX table
idx__AO__division__gelderland__tmp1__df, idx__AO__division__gelderland__tmp1__count = tmp_1_idx_df_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    group_col='habitatnaam_1_disp',
    year_col='years'
)
idx__AO__division__gelderland_minHR__tmp1__df, idx__AO__division__gelderland_minHR__tmp1__count = tmp_1_idx_df_func(
    gdf=habitat_kart__processed__gelderland_minHR__RD__gdf,
    group_col='habitatnaam_1_disp',
    year_col='years'
)
idx__AO__division__website__tmp1__df, idx__AO__division__website__tmp1__count = tmp_1_idx_df_func(
    gdf=habitat_kart__processed__website__RD__gdf,
    group_col='habitatnaam_1_disp',
    year_col='years'
)
idx__AO__division__website_plusHR__tmp1__df, idx__AO__division__website_plusHR__tmp1__count = tmp_1_idx_df_func(
    gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    group_col='habitatnaam_1_disp',
    year_col='years'
)

# %%
# Check AO tmp1 processing
values = [idx__AO__division__gelderland__tmp1__count, idx__AO__division__gelderland_minHR__tmp1__count,
          idx__AO__division__website__tmp1__count, idx__AO__division__website_plusHR__tmp1__count]
entities = ["gelderland", "gelderland_min_hr", "website", "website_plus_hr"]

check_processing(values, entities, typ="AO", tmp="tmp1")
# Out:
# ['The number of habitat surveys is correct']

# %%
# Save
idx__AO__division__gelderland__tmp1__df.to_pickle(idx__AO__division__gelderland__tmp1__df_path)
idx__AO__division__gelderland_minHR__tmp1__df.to_pickle(idx__AO__division__gelderland_minHR__tmp1__df_path)
idx__AO__division__website__tmp1__df.to_pickle(idx__AO__division__website__tmp1__df_path)
idx__AO__division__website_plusHR__tmp1__df.to_pickle(idx__AO__division__website_plusHR__tmp1__df_path)

# %% [markdown]
# ### IDX AO tmp2

# %%
# AO tmp2 idx df (tmp2 = 2017-> 2024 ONLY)
idx__AO__division__gelderland__tmp2__df, idx__AO__division__gelderland__tmp2__count = tmp2_idx_df_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    group_col='habitatnaam_1_disp',
    year_col='years',
)
idx__AO__division__website_plusHR__tmp2__df, idx__AO__division__website_plusHR__tmp2__count = tmp2_idx_df_func(
    gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    group_col='habitatnaam_1_disp',
    year_col='years',
)

# %%
# Save
idx__AO__division__gelderland__tmp2__df.to_pickle(idx__AO__division__gelderland__tmp2__df_path)
idx__AO__division__website_plusHR__tmp2__df.to_pickle(idx__AO__division__website_plusHR__tmp2__df_path)

# %% [markdown]
# ## Making IDX tables for HB

# %% [markdown]
# ### IDX HB tmp1

# %%
# HB tmp1 idx df
idx__HB__division__gelderland__tmp1__df, idx__HB__division__gelderland__tmp1__count = HT_idx_df_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    idx_df=idx__AO__division__gelderland__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1'
)

idx__HB__division__gelderland_minHR__tmp1__df, idx__HB__division__gelderland_minHR__tmp1__count = HT_idx_df_func(
    gdf=habitat_kart__processed__gelderland_minHR__RD__gdf,
    idx_df=idx__AO__division__gelderland_minHR__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1'
)

idx__HB__division__website__tmp1__df, idx__HB__division__website__tmp1_count = HT_idx_df_func(
    gdf=habitat_kart__processed__website__RD__gdf,
    idx_df=idx__AO__division__website__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1'
)

idx__HB__division__website_plusHR__tmp1__df, idx__HB__division__website_plusHR__tmp1__count = HT_idx_df_func(
    gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    idx_df=idx__AO__division__website_plusHR__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1'
)

# %%
# Check HB tmp1 processing
values = [idx__HB__division__gelderland__tmp1__count, idx__HB__division__gelderland_minHR__tmp1__count,
          idx__HB__division__website__tmp1_count, idx__HB__division__website_plusHR__tmp1__count]
entities = ["gelderland", "gelderland_min_hr", "website", "website_plus_hr"]

check_processing(values, entities, typ="HB", tmp="tmp1")
# Out:
# ['The number of habitat surveys is correct']

# %%
idx__HB__division__gelderland__tmp1__df.head()
# Out:
# _year_str                                                                  2010-2016  \
# index
# Actieve hoogvenen (heideveentjes)  [GI_44980, GI_4504, GI_4517, GI_4520, GI_4522,...
# Beken & rivieren met waterplanten  [GI_11591, GI_11113, GI_45974, GI_45985, GI_45...
# Beuken-eikenbossen                 [GI_2798, GI_2812, GI_3711, GI_3728, GI_5048, ...
# Binnenlandse kraaheibegroeiingen   [GI_25398, GI_25509, GI_25677, GI_25679, GI_25...
# Blauwgraslanden                                                                   []
#
# _year_str                                          2017  \
# index
# Actieve hoogvenen (heideveentjes)                    []
# Beken & rivieren met waterplanten  [GI_45639, GI_45710]
# Beuken-eikenbossen                 [GI_41687, GI_45356]
# Binnenlandse kraaheibegroeiingen                     []
# Blauwgraslanden                              [GI_41965]
#
# _year_str                                                                       2018  \
# index
# ...

# %%
# Save
idx__HB__division__gelderland__tmp1__df.to_pickle(idx__HB__division__gelderland__tmp1__df_path)
idx__HB__division__gelderland_minHR__tmp1__df.to_pickle(idx__HB__division__gelderland_minHR__tmp1__df_path)
idx__HB__division__website__tmp1__df.to_pickle(idx__HB__division__website__tmp1__df_path)
idx__HB__division__website_plusHR__tmp1__df.to_pickle(idx__HB__division__website_plusHR__tmp1__df_path)

# %% [markdown]
# ### IDX HB tmp2

# %%
# HB tmp2 idx df
idx__HB__division__gelderland__tmp2__df, idx__HB__division__gelderland__tmp2__count = HT_idx_df_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    idx_df=idx__AO__division__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1'
)

idx__HB__division__website_plusHR__tmp2__df, idx__HB__division__website_plusHR__tmp2__count = HT_idx_df_func(
    gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    idx_df=idx__AO__division__website_plusHR__tmp2__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1'
)

# %%
# save
idx__HB__division__gelderland__tmp2__df.to_pickle(idx__HB__division__gelderland__tmp2__df_path)
idx__HB__division__website_plusHR__tmp2__df.to_pickle(idx__HB__division__website_plusHR__tmp2__df_path)

# %% [markdown]
# ## Making IDX tables for FC (p80)

# %% [markdown]
# ### IDX FC tmp1

# %%
# FC tmp1 IDX table
idx__FC__division__gelderland__tmp1__df, idx__FC__division__gelderland__tmp1__count = FC_idx_df_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    idx_df=idx__HB__division__gelderland__tmp1__df,
    min_percentage=100,
)

idx__FC__division__gelderland_minHR__tmp1__df, idx__FC__division__gelderland_minHR__tmp1__count = FC_idx_df_func(
    gdf=habitat_kart__processed__gelderland_minHR__RD__gdf,
    idx_df=idx__HB__division__gelderland_minHR__tmp1__df,
    min_percentage=100,
)

idx__FC__division__website__tmp1__df, idx__FC__division__website__tmp1_count = FC_idx_df_func(
    gdf=habitat_kart__processed__website__RD__gdf,
    idx_df=idx__HB__division__website__tmp1__df,
    min_percentage=100,
)

idx__FC__division__website_plusHR__tmp1__df, idx__FC__division__website_plusHR__tmp1__count = FC_idx_df_func(
    gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    idx_df=idx__HB__division__website_plusHR__tmp1__df,
    min_percentage=100,
)

# %%
# Check FC tmp1 processing
values = [idx__FC__division__gelderland__tmp1__count, idx__FC__division__gelderland_minHR__tmp1__count,
          idx__FC__division__website__tmp1_count, idx__FC__division__website_plusHR__tmp1__count]
entities = ["gelderland", "gelderland_min_hr", "website", "website_plus_hr"]

check_processing(values, entities, typ="FC", tmp="tmp1")
# Out:
# ['The number of habitat surveys is correct']

# %%
# Save
idx__FC__division__gelderland__tmp1__df.to_pickle(idx__FC__division__gelderland__tmp1__df_path)
idx__FC__division__gelderland_minHR__tmp1__df.to_pickle(idx__FC__division__gelderland_minHR__tmp1__df_path)
idx__FC__division__website__tmp1__df.to_pickle(idx__FC__division__website__tmp1__df_path)
idx__FC__division__website_plusHR__tmp1__df.to_pickle(idx__FC__division__website_plusHR__tmp1__df_path)

# %% [markdown]
# ### IDX FC p80 tmp2

# %%
# FC tmp2 idx df
idx__FC_p80__division__gelderland__tmp2__df, idx__FC_p80__division__gelderland__tmp2__count = FC_idx_df_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    idx_df=idx__HB__division__gelderland__tmp2__df,
    min_percentage=80,
)

idx__FC_p80__division__website_plusHR__tmp2__df, idx__FC_p80__division__website_plusHR__tmp2__count = FC_idx_df_func(
    gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    idx_df=idx__HB__division__website_plusHR__tmp2__df,
    min_percentage=80,
)

# %%
# Save
idx__FC_p80__division__gelderland__tmp2__df.to_pickle(idx__FC_p80__division__gelderland__tmp2__df_path)
idx__FC_p80__division__website_plusHR__tmp2__df.to_pickle(idx__FC_p80__division__website_plusHR__tmp2__df_path)

# %% [markdown]
# ## Making IDX tables for WD

# %% [markdown]
# ### IDX WD tmp1

# %%
# WD tmp1 idx df
idx__WD__division__gelderland__tmp1__df, idx__WD__division__gelderland__tmp1__count = group_idx_df_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    idx_df=idx__FC__division__gelderland__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD_division'
)

idx__WD__division__gelderland_minHR__tmp1__df, idx__WD__division__gelderland_minHR__tmp1__count = group_idx_df_func(
    gdf=habitat_kart__processed__gelderland_minHR__RD__gdf,
    idx_df=idx__FC__division__gelderland_minHR__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD_division'
)

idx__WD__division__website__tmp1__df, idx__WD__division__website__tmp1_count = group_idx_df_func(
    gdf=habitat_kart__processed__website__RD__gdf,
    idx_df=idx__FC__division__website__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD_division'
)

idx__WD__division__website_plusHR__tmp1__df, idx__WD__division__website_plusHR__tmp1__count = group_idx_df_func(
    gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    idx_df=idx__FC__division__website_plusHR__tmp1__df,
    habitat_types_df=habitat_reference__WD__df,
    habitat_col='habitatType1',
    group_col='WD_division'
)

# %%
# Check WD tmp1 processing
values = [idx__WD__division__gelderland__tmp1__count, idx__WD__division__gelderland_minHR__tmp1__count,
          idx__WD__division__website__tmp1_count, idx__WD__division__website_plusHR__tmp1__count]
entities = ["gelderland", "gelderland_min_hr", "website", "website_plus_hr"]

check_processing(values, entities, typ="WD", tmp="tmp1")
# Out:
# ['The number of habitat surveys is correct']

# %%
# WD tmp1 IDX
idx__WD__division__gelderland__tmp1__df.to_pickle(idx__WD__division__gelderland__tmp1__df_path)
idx__WD__division__gelderland_minHR__tmp1__df.to_pickle(idx__WD__division__gelderland_minHR__tmp1__df_path)
idx__WD__division__website__tmp1__df.to_pickle(idx__WD__division__website__tmp1__df_path)
idx__WD__division__website_plusHR__tmp1__df.to_pickle(idx__WD__division__website_plusHR__tmp1__df_path)

# %% [markdown]
# ## Making IDX tables for S1

# %% [markdown]
# ### IDX S1 tmp1

# %%
# S1 tmp1 IDX table
idx__s1__division__gelderland__tmp1__df, idx__s1__division__gelderland__tmp1__count = group_idx_df_func(
    gdf=habitat_kart__processed__gelderland__RD__gdf,
    idx_df=idx__FC__division__gelderland__tmp1__df,
    habitat_types_df=habitat_reference__s__df,
    habitat_col='habitatType1',
    group_col='s1_division',
)

idx__s1__division__gelderland_minHR__tmp1__df, idx__s1__division__gelderland_minHR__tmp1__count = group_idx_df_func(
    gdf=habitat_kart__processed__gelderland_minHR__RD__gdf,
    idx_df=idx__FC__division__gelderland_minHR__tmp1__df,
    habitat_types_df=habitat_reference__s__df,
    habitat_col='habitatType1',
    group_col='s1_division',
)

idx__s1__division__website__tmp1__df, idx__s1__division__website__tmp1_count = group_idx_df_func(
    gdf=habitat_kart__processed__website__RD__gdf,
    idx_df=idx__FC__division__website__tmp1__df,
    habitat_types_df=habitat_reference__s__df,
    habitat_col='habitatType1',
    group_col='s1_division',
)

idx__s1__division__website_plusHR__tmp1__df, idx__s1__division__website_plusHR__tmp1__count = group_idx_df_func(
    gdf=habitat_kart__processed__website_plusHR__RD__gdf,
    idx_df=idx__FC__division__website_plusHR__tmp1__df,
    habitat_types_df=habitat_reference__s__df,
    habitat_col='habitatType1',
    group_col='s1_division',
)

# %%
# Check S1 tmp1 processing
values = [idx__s1__division__gelderland__tmp1__count, idx__s1__division__gelderland_minHR__tmp1__count,
          idx__s1__division__website__tmp1_count, idx__s1__division__website_plusHR__tmp1__count]
entities = ["gelderland", "gelderland_min_hr", "website", "website_plus_hr"]

check_processing(values, entities, typ="S1", tmp="tmp1")
# Out:
# ['The number of habitat surveys is correct']

# %%
# s1 tmp1 IDX
idx__s1__division__gelderland__tmp1__df.to_pickle(idx__s1__division__gelderland__tmp1__df_path)
idx__s1__division__gelderland_minHR__tmp1__df.to_pickle(idx__s1__division__gelderland_minHR__tmp1__df_path)
idx__s1__division__website__tmp1__df.to_pickle(idx__s1__division__website__tmp1__df_path)
idx__s1__division__website_plusHR__tmp1__df.to_pickle(idx__s1__division__website_plusHR__tmp1__df_path)

# %%
idx__s1__division__gelderland__tmp1__df.head()
# Out:
# _year_str                                                                  2010-2016  \
# Remaining                          [GI_1, GI_10, GI_10001, GI_10004, GI_10012, GI...
# Vochtige heiden                    [GI_10557, GI_10585, GI_10604, GI_10747, GI_10...
# Zwakgebufferde vennen              [GI_12829, GI_13961, GI_21272, GI_25818, GI_26...
# Zure vennen                        [GI_12818, GI_12849, GI_12852, GI_12853, GI_12...
# Actieve hoogvenen (heideveentjes)  [GI_12854, GI_4517, GI_4525, GI_6037, GI_6164,...
#
# _year_str                                                                       2017  \
# Remaining                          [GI_11616, GI_11633, GI_11635, GI_12300, GI_14...
# Vochtige heiden                    [GI_41299, GI_41301, GI_41302, GI_41303, GI_41...
# Zwakgebufferde vennen                                                             []
# Zure vennen                                                               [GI_41726]
# ...

# %% [markdown]
# End of the notebook
