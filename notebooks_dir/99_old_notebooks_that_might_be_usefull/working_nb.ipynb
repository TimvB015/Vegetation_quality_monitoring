# %%
from paths.OG_paths import (
    idx__WD1_plusOW_p80_tmp2_training_at1__gelderland__df_path,
    idx__WD1_plusOW_p80_tmp2_validation_at1__gelderland__df_path,
    training_polys__WD1_plusOW_p80_tmp2_at1__gelderland__RD__gpkg_path,
    validation_pixels__WD1_plusOW_p80_tmp2_at1__gelderland__RD__gpkg_path,
)

# %%
import pandas as pd
import geopandas as gpd

# %%
idx__WD1_plusOW_p80_tmp2_training_at1__gelderland__df = pd.read_pickle(idx__WD1_plusOW_p80_tmp2_training_at1__gelderland__df_path)

# %%
idx__WD1_plusOW_p80_tmp2_training_at1__gelderland__df
# Out:
#                                                          2017  \
# Remaining   [GI_14631_2, GI_14631_3, GI_14732_1, GI_14732_...
# Wet Nature  [GI_41299_1, GI_41299_2, GI_41299_3, GI_41299_...
# Open water                                                 []
#
#                                                          2018  \
# Remaining   [GI_18627_1, GI_18627_2, GI_18627_3, GI_18888_...
# Wet Nature  [GI_18984_11, GI_18984_12, GI_18984_13, GI_189...
# Open water                                                 []
#
#                                                          2019  \
# Remaining   [GI_10075_1, GI_10075_10, GI_10075_11, GI_1007...
# Wet Nature                                                 []
# Open water                                                 []
#
#                                                          2020  \
# Remaining   [GI_10141_1, GI_10141_10, GI_10141_2, GI_10141...
# Wet Nature  [GI_12951_1, GI_12951_2, GI_12951_3, GI_12951_...
# ...

# %%
gpd.read_file(training_polys__WD1_plusOW_p80_tmp2_at1__gelderland__RD__gpkg_path)
# Out:
#     polygon_id        Type years  \
# 0     GI_14631   Remaining  2017
# 1     GI_14732   Remaining  2017
# 2     GI_14750   Remaining  2017
# 3     GI_14756   Remaining  2017
# 4     GI_14843   Remaining  2017
# ..         ...         ...   ...
# 152      OW_21  Open water  2023
# 153       OW_1  Open water  2024
# 154      OW_10  Open water  2024
# 155      OW_12  Open water  2024
# 156       OW_9  Open water  2024
#
#                                               geometry
# 0    MULTIPOLYGON (((182439.305 464463.083, 182439....
# 1    MULTIPOLYGON (((182359.317 464673.053, 182359....
# 2    MULTIPOLYGON (((182139.348 464523.075, 182129....
# 3    MULTIPOLYGON (((183729.122 464743.043, 183719....
# 4    MULTIPOLYGON (((181929.378 464973.011, 181929....
# ..                                                 ...
# 152  MULTIPOLYGON (((185488.873 459093.845, 185488....
# 153  MULTIPOLYGON (((200276.781 497598.412, 200276....
# 154  MULTIPOLYGON (((177659.983 451274.968, 177659....
# ...

# %%
idx__WD1_plusOW_p80_tmp2_validation_at1__gelderland__df = pd.read_pickle(idx__WD1_plusOW_p80_tmp2_validation_at1__gelderland__df_path)

# %%
idx__WD1_plusOW_p80_tmp2_validation_at1__gelderland__df
# Out:
#                                                          2017  \
# Remaining   [GI_14622_12, GI_14622_13, GI_14622_14, GI_146...
# Wet Nature  [GI_45319_1, GI_45319_2, GI_45319_3, GI_45319_...
# Open water                                                 []
#
#                                                          2018  \
# Remaining   [GI_19553_1, GI_19553_10, GI_19553_101, GI_195...
# Wet Nature  [GI_18556_11, GI_18556_12, GI_18556_13, GI_185...
# Open water  [OW_6_1, OW_6_10, OW_6_11, OW_6_12, OW_6_13, O...
#
#                                                          2019  \
# Remaining   [GI_26354_28, GI_26354_29, GI_26354_30, GI_263...
# Wet Nature                                                 []
# Open water  [OW_2_1, OW_2_10, OW_2_11, OW_2_12, OW_2_13, O...
#
#                                                          2020  \
# Remaining   [GI_169_11, GI_169_12, GI_169_13, GI_169_14, G...
# Wet Nature   [GI_41773_1, GI_45861_1, GI_45861_2, GI_45861_3]
# ...

# %%
gpd.read_file(validation_pixels__WD1_plusOW_p80_tmp2_at1__gelderland__RD__gpkg_path)
# Out:
#             index                                              years  \
# 0      GI_15018_1                                               2017
# 1     GI_15018_10                                               2017
# 2     GI_15018_11                                               2017
# 3     GI_15018_12                                               2017
# 4     GI_15018_13                                               2017
# ...           ...                                                ...
# 1205     OW_19_48  2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024...
# 1206     OW_19_49  2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024...
# 1207     OW_19_50  2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024...
# 1208     OW_19_51  2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024...
# 1209     OW_19_52  2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024...
#
#             type idx_layer                                           geometry
# ...
