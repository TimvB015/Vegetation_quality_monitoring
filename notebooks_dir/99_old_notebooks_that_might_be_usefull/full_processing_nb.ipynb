# %% [markdown]
# ## Importing functions

# %%
from pathlib import Path
import sys

sys.path.insert(0, str(Path.cwd().resolve()))
from functions._00_common_funcs import (
    batch_func,
    check_directories_func,
    path_func,
    check_gpkg_layers_func,
    import_gpkg_func,
    import_xlsx_func,
    print_raster_info,
    import_raster_func,
    quick_rstr_plot_func,
    check_processing,
    show_nameconvention_func,
)

from functions._02_building_idx_df_funcs import (
    tmp_0_idx_df_func,
    HT_idx_df_func,
    FC_idx_df_func,
    WD_idx_df_func,
)

from functions._03_visualizing_pixel_count_funcs import (
    pixel_count_df_func,
    pixel_vis_func
)

from functions.training_validation_split_funcs import (
    cut_gdf_to_raster_pixels,
    build_gpkg_from_idx_df_func,
)

from functions._07_full_processing_nb_funcs import (
    tmp2_idx_df_func,
    clean_and_update_inspected_GPKG,
    idx_per_row_area_func,
    training_validation_split_func,
    idx_to_training_validation_gdf_func,
)

# %% [markdown]
# ## Setting Notebook directory

# %%
notebook_dir = Path.cwd()

check_directories_func(notebook_dir)
# Out:
# 'Functions, Dependencies, and Output directories found'

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd

# %% [markdown]
# ## Import reference DFs

# %%
from paths._00_file_paths import (
    # --- Selection reference dfs ---
    habitat_reference__HB__df_path,
    habitat_reference__s1__df_path,
)

# %%
# --- Selection reference dfs ---
habitat_reference__HB__df = pd.read_pickle(habitat_reference__HB__df_path)
habitat_reference__s1__df = pd.read_pickle(habitat_reference__s1__df_path)

# %%
habitat_reference__HB__df
# Out:
#                                    habitatnaam_disp habitat_color  \
# habitatType
# H0000                              Geen habitattype       #999999
# H2310                 Stuifzandheiden met struikhei       #fff7b2
# H2320              Binnenlandse kraaheibegroeiingen       #8c564b
# H2330                             Zandverstuivingen       #e8d6c3
# H3130                         Zwakgebufferde vennen       #9ed6f8
# H3150          Meren krabbenscheer & fonteinkruiden       #00375f
# H3160                                   Zure vennen       #2e86c1
# H3260A            Beken & rivieren met waterplanten       #0c5a92
# H3260B            Beken & rivieren met waterplanten       #0c5a92
# H3270                         slikkige rivieroevers       #9b4f12
# H4010A                              Vochtige heiden       #a1d99b
# H4030                                  Droge heiden       #6ba368
# H5130                           Jeneverbesstruwelen       #9467bd
# ...

# %% [markdown]
# ## Clip the processed GDF to the sentinel raster and save

# %% [markdown]
# _If you already have a pixeled version of the GPKG, then skip this step_

# %% [markdown]
# #### Setting dir

# %%
# # Setting dir
# from functions._00_file_paths import (
#     # --- Habitat kart Processed GPKGs ---
#     OW_all_years__selected__lgn__RD__gpkg_path,

#     # --- sentinel 2 basisraster ---
#     s2_basisraster__10m__RD__rstr_path,
#     s2_basisraster__20m__RD__rstr_path,

#     # --- pixeled gdfs --- 
#     OW_all_years__selected_pixeled__lgn__RD__gpkg_path,
# )

# %%
# # --- Habitat kart Processed GPKGs ---
# # Gelderland 
# habitat_kart__processed__gelderland__RD__gdf = import_gpkg_func(
#     gdf_path=habitat_kart__processed__gelderland__RD__gpkg_path, 
#     layer='habitat_kart__processed__gelderland__RD__layer', 
#     index_col='index'
# )

# # Website plus hr 
# habitat_kart__processed__website_plusHR__RD__gdf = import_gpkg_func(
#     gdf_path=habitat_kart__processed__website_plusHR__RD__gpkg_path,
#     layer='habitat_kart__processed__website_plusHR__RD__layer',
#     index_col='index'
# )
# 
# # All years OW
# OW_all_years__selected__lgn__RD__gdf = import_gpkg_func(
#     gdf_path=OW_all_years__selected__lgn__RD__gpkg_path, 
#     layer='OW_all_years__selected__lgn__RD__layer', 
#     index_col='index'
# )

# %%
# # Clip to raster -> very time consuming!
# OW_all_years__selected_pixeled__lgn__RD__gdf = cut_gdf_to_raster_pixels(
#     gdf=OW_all_years__selected__lgn__RD__gdf,
#     raster_path=s2_basisraster__10m__RD__rstr_path,
#     all_touched=True,
#     make_geoms_valid=True,
#     progress=True,
# )

# %%
# # Save directly to file
# OW_all_years__selected_pixeled__lgn__RD__gdf.to_file(
#     filename=OW_all_years__selected_pixeled__lgn__RD__gpkg_path,
#     layer="OW_all_years__selected_pixeled__lgn__RD__layer",
#     driver="GPKG"
# )

# %% [markdown]
# ## Building (pixeled) IDX table for new selection

# %% [markdown]
# #### _Setting dir_

# %%
# Setting dir
from functions._00_file_paths import (
    # --- (pixeled) gdfs --- 
    habitat_kart__processed__gelderland__RD__gpkg_path,
    habitat_kart__processed__website_plusHR__RD__gpkg_path,
    habitat_kart__pixeled__gelderland__RD__gpkg_path,
    habitat_kart__pixeled__website_plusHR__RD__gpkg_path,

    # --- Create new pixeled idx dfs ---
    # HB tmp2
    idx__HB__division__gelderland__tmp2__df_path,
    idx__HB__division__website_plusHR__tmp2__df_path,
    idx__HB__pixeled__gelderland__tmp2__df_path,
    idx__HB__pixeled__website_plusHR__tmp2__df_path,
    # FC_p80 tmp2
    idx__FC_p80__division__gelderland__tmp2__df_path,
    idx__FC_p80__division__website_plusHR__tmp2__df_path,
    idx__FC_p80__pixeled__gelderland__tmp2__df_path,
    idx__FC_p80__pixeled__website_plusHR__tmp2__df_path,
    # WD_p80 tmp2
    idx__WD1_p80__division__gelderland__tmp2__df_path,
    idx__WD1_p80__division__website_plusHR__tmp2__df_path,
    idx__WD2_p80__division__gelderland__tmp2__df_path,
    idx__WD2_p80__division__website_plusHR__tmp2__df_path,
    
    idx__WD1_p80__pixeled__gelderland__tmp2__df_path,
    idx__WD1_p80__pixeled__website_plusHR__tmp2__df_path,
    idx__WD2_p80__pixeled__gelderland__tmp2__df_path,
    idx__WD2_p80__pixeled__website_plusHR__tmp2__df_path,
)

# %% [markdown]
# #### _Loading the GDFs_

# %%
# # Loading the processed GDF
# # Gelderland 
# habitat_kart__processed__gelderland__RD__gdf = import_gpkg_func(
#     gdf_path=habitat_kart__processed__gelderland__RD__gpkg_path, 
#     layer='habitat_kart__processed__gelderland__RD__layer', 
#     index_col='index'
# )

# # Website plus hr 
# habitat_kart__processed__website_plusHR__RD__gdf = import_gpkg_func(
#     gdf_path=habitat_kart__processed__website_plusHR__RD__gpkg_path,
#     layer='habitat_kart__processed__website_plusHR__RD__layer',
#     index_col='index'
# )

# %%
# # Loading the pixeled GDF
# # Gelderland 
# habitat_kart__pixeled__gelderland__RD__gdf = import_gpkg_func(
#     gdf_path=habitat_kart__pixeled__gelderland__RD__gpkg_path, 
#     layer='habitat_kart__pixeled__gelderland__RD__layer', 
#     index_col='new_index'
# )

# # Website plus hr 
# habitat_kart__pixeled__website_plusHR__RD__gdf = import_gpkg_func(
#     gdf_path=habitat_kart__pixeled__website_plusHR__RD__gpkg_path,
#     layer='habitat_kart__pixeled__website_plusHR__RD__layer',
#     index_col='new_index'
# )

# %%
# habitat_kart__pixeled__website_plusHR__RD__gdf.head()

# %% [markdown]
# #### _Loading the IDX dfs (if available)_

# %%
# idx__HB__division__gelderland__tmp2__df = pd.read_pickle(idx__HB__division__gelderland__tmp2__df_path)
# idx__HB__division__website_plusHR__tmp2__df = pd.read_pickle(idx__HB__division__website_plusHR__tmp2__df_path)
# idx__HB__pixeled__gelderland__tmp2__df = pd.read_pickle(idx__HB__pixeled__gelderland__tmp2__df_path)
# idx__HB__pixeled__website_plusHR__tmp2__df = pd.read_pickle(idx__HB__pixeled__website_plusHR__tmp2__df_path)

# %% [markdown]
# #### _Using AO tmp0, any new combination can be made_

# %%
# # AO tmp2 idx df (tmp2 = 2017-> 2024 ONLY)
# idx__AO__pixeled__gelderland__tmp2__df, idx__AO__pixeled__gelderland__tmp2__count = tmp2_idx_df_func(
#     gdf=habitat_kart__pixeled__gelderland__RD__gdf,
#     group_col='habitatnaam_1_disp',
#     year_col='years',
# )
# idx__AO__pixeled__website_plusHR__tmp2__df, idx__AO__pixeled__website_plusHR__tmp2__count = tmp2_idx_df_func(
#     gdf=habitat_kart__pixeled__website_plusHR__RD__gdf,
#     group_col='habitatnaam_1_disp',
#     year_col='years',
# )

# %%
# idx__AO__pixeled__gelderland__tmp2__df.head()

# %%
# # save
# idx__AO__pixeled__gelderland__tmp2__df.to_pickle(idx__AO__pixeled__gelderland__tmp2__df_path)
# idx__AO__pixeled__website_plusHR__tmp2__df.to_pickle(idx__AO__pixeled__website_plusHR__tmp2__df_path)

# %% [markdown]
# #### _Using HT func only the rows with a true Habitat type are selected_

# %%
# # HB tmp2 idx df
# idx__HB__pixeled__gelderland__tmp2__df, idx__HB__pixeled__gelderland__tmp2__count = HT_idx_df_func(
#     gdf=habitat_kart__pixeled__gelderland__RD__gdf,
#     idx_df=idx__AO__pixeled__gelderland__tmp2__df,
#     habitat_types_df=habitat_reference__HB__df,
#     habitat_col='habitatType1'
# )

# idx__HB__pixeled__website_plusHR__tmp2__df, idx__HB__pixeled__website_plusHR__tmp2__count = HT_idx_df_func(
#     gdf=habitat_kart__pixeled__website_plusHR__RD__gdf,
#     idx_df=idx__AO__pixeled__website_plusHR__tmp2__df,
#     habitat_types_df=habitat_reference__HB__df,
#     habitat_col='habitatType1'
# )

# %%
# # save
# idx__HB__pixeled__gelderland__tmp2__df.to_pickle(idx__HB__pixeled__gelderland__tmp2__df_path)
# idx__HB__pixeled__website_plusHR__tmp2__df.to_pickle(idx__HB__pixeled__website_plusHR__tmp2__df_path)

# %% [markdown]
# #### _Using FC func only the habitat covers above a percentage are selected_

# %%
# # FC tmp2 idx df
# idx__FC_p80__division__gelderland__tmp2__df, idx__FC_p80__division__gelderland__tmp2__count = FC_idx_df_func(
#     gdf=habitat_kart__processed__gelderland__RD__gdf,
#     idx_df=idx__HB__division__gelderland__tmp2__df,
#     min_percentage=80,
# )

# idx__FC_p80__division__website_plusHR__tmp2__df, idx__FC_p80__division__website_plusHR__tmp2__count = FC_idx_df_func(
#     gdf=habitat_kart__processed__website_plusHR__RD__gdf,
#     idx_df=idx__HB__division__website_plusHR__tmp2__df,
#     min_percentage=80,
# )

# %%
# # # Save
# idx__FC_p80__division__gelderland__tmp2__df.to_pickle(idx__FC_p80__division__gelderland__tmp2__df_path)
# idx__FC_p80__division__website_plusHR__tmp2__df.to_pickle(idx__FC_p80__division__website_plusHR__tmp2__df_path)

# %%
# # FC tmp2 idx df
# idx__FC_p80__pixeled__gelderland__tmp2__df, idx__FC_p80__pixeled__gelderland__tmp2__count = FC_idx_df_func(
#     gdf=habitat_kart__pixeled__gelderland__RD__gdf,
#     idx_df=idx__HB__pixeled__gelderland__tmp2__df,
#     min_percentage=80,
# )

# idx__FC_p80__pixeled__website_plusHR__tmp2__df, idx__FC__pixeled__website_plusHR__tmp2__count = FC_idx_df_func(
#     gdf=habitat_kart__pixeled__website_plusHR__RD__gdf,
#     idx_df=idx__HB__pixeled__website_plusHR__tmp2__df,
#     min_percentage=80,
# )

# %%
# # # Save
# idx__FC_p80__pixeled__gelderland__tmp2__df.to_pickle(idx__FC_p80__pixeled__gelderland__tmp2__df_path)
# idx__FC_p80__pixeled__website_plusHR__tmp2__df.to_pickle(idx__FC_p80__pixeled__website_plusHR__tmp2__df_path)

# %% [markdown]
# #### _Using WD func only habitats are grouped based on WD_

# %%
# # WD tmp2 idx df
# idx__WD1_p80__pixeled__gelderland__tmp2__df, idx__WD1_p80__pixeled__gelderland__tmp2__count = WD_idx_df_func(
#     gdf=habitat_kart__pixeled__gelderland__RD__gdf,
#     idx_df=idx__FC_p80__pixeled__gelderland__tmp2__df,
#     habitat_types_df=habitat_reference__HB__df,
#     habitat_col='habitatType1',
#     wd_col='WD1_division'
# )

# idx__WD1_p80__pixeled__website_plusHR__tmp2__df, idx__WD1_p80__pixeled__website_plusHR__tmp2__count = WD_idx_df_func(
#     gdf=habitat_kart__pixeled__website_plusHR__RD__gdf,
#     idx_df=idx__FC_p80__pixeled__website_plusHR__tmp2__df,
#     habitat_types_df=habitat_reference__HB__df,
#     habitat_col='habitatType1',
#     wd_col='WD1_division'
# )

# # WD tmp2 idx df
# idx__WD2_p80__pixeled__gelderland__tmp2__df, idx__WD2_p80__pixeled__gelderland__tmp2__count = WD_idx_df_func(
#     gdf=habitat_kart__pixeled__gelderland__RD__gdf,
#     idx_df=idx__FC_p80__pixeled__gelderland__tmp2__df,
#     habitat_types_df=habitat_reference__HB__df,
#     habitat_col='habitatType1',
#     wd_col='WD2_division'
# )

# idx__WD2_p80__pixeled__website_plusHR__tmp2__df, idx__WD2_p80__pixeled__website_plusHR__tmp2__count = WD_idx_df_func(
#     gdf=habitat_kart__pixeled__website_plusHR__RD__gdf,
#     idx_df=idx__FC_p80__pixeled__website_plusHR__tmp2__df,
#     habitat_types_df=habitat_reference__HB__df,
#     habitat_col='habitatType1',
#     wd_col='WD2_division'
# )

# %%
# # save
# idx__WD1_p80__pixeled__gelderland__tmp2__df.to_pickle(idx__WD1_p80__pixeled__gelderland__tmp2__df_path)
# idx__WD1_p80__pixeled__website_plusHR__tmp2__df.to_pickle(idx__WD1_p80__pixeled__website_plusHR__tmp2__df_path)
# idx__WD2_p80__pixeled__gelderland__tmp2__df.to_pickle(idx__WD2_p80__pixeled__gelderland__tmp2__df_path)
# idx__WD2_p80__pixeled__website_plusHR__tmp2__df.to_pickle(idx__WD2_p80__pixeled__website_plusHR__tmp2__df_path)

# %%
# # WD tmp2 idx df
# idx__WD1_p80__division__gelderland__tmp2__df, idx__WD1_p80__division__gelderland__tmp2__count = WD_idx_df_func(
#     gdf=habitat_kart__processed__gelderland__RD__gdf,
#     idx_df=idx__FC_p80__division__gelderland__tmp2__df,
#     habitat_types_df=habitat_reference__HB__df,
#     habitat_col='habitatType1',
#     wd_col='WD1_division'
# )

# idx__WD1_p80__division__website_plusHR__tmp2__df, idx__WD1_p80__division__website_plusHR__tmp2__count = WD_idx_df_func(
#     gdf=habitat_kart__processed__website_plusHR__RD__gdf,
#     idx_df=idx__FC_p80__division__website_plusHR__tmp2__df,
#     habitat_types_df=habitat_reference__HB__df,
#     habitat_col='habitatType1',
#     wd_col='WD1_division'
# )

# # WD tmp2 idx df
# idx__WD2_p80__division__gelderland__tmp2__df, idx__WD2_p80__division__gelderland__tmp2__count = WD_idx_df_func(
#     gdf=habitat_kart__processed__gelderland__RD__gdf,
#     idx_df=idx__FC_p80__division__gelderland__tmp2__df,
#     habitat_types_df=habitat_reference__HB__df,
#     habitat_col='habitatType1',
#     wd_col='WD2_division'
# )

# idx__WD2_p80__division__website_plusHR__tmp2__df, idx__WD2_p80__division__website_plusHR__tmp2__count = WD_idx_df_func(
#     gdf=habitat_kart__processed__website_plusHR__RD__gdf,
#     idx_df=idx__FC_p80__division__website_plusHR__tmp2__df,
#     habitat_types_df=habitat_reference__HB__df,
#     habitat_col='habitatType1',
#     wd_col='WD2_division'
# )

# %%
# # save
# idx__WD1_p80__division__gelderland__tmp2__df.to_pickle(idx__WD1_p80__division__gelderland__tmp2__df_path)
# idx__WD1_p80__division__website_plusHR__tmp2__df.to_pickle(idx__WD1_p80__division__website_plusHR__tmp2__df_path)
# idx__WD2_p80__division__gelderland__tmp2__df.to_pickle(idx__WD2_p80__division__gelderland__tmp2__df_path)
# idx__WD2_p80__division__website_plusHR__tmp2__df.to_pickle(idx__WD2_p80__division__website_plusHR__tmp2__df_path)

# %% [markdown]
# #### _s1 selection func_

# %%
# # S1 tmp1 idx dfs
# idx__s1__pixeled__gelderland__tmp2__df, idx__s1__pixeled__gelderland__tmp2__count = HT_idx_df_func(
#     gdf=habitat_kart__pixeled__gelderland__RD__gdf,
#     idx_df=idx__FC__pixeled__gelderland__tmp2__df,
#     habitat_types_df=habitat_reference__s1__df,
#     habitat_col='habitatType1'
# )

# idx__s1__pixeled__website_plusHR__tmp2__df, idx__s1__pixeled__website_plusHR__tmp2__count = HT_idx_df_func(
#     gdf=habitat_kart__pixeled__website_plusHR__RD__gdf,
#     idx_df=idx__FC__pixeled__website_plusHR__tmp2__df,
#     habitat_types_df=habitat_reference__s1__df,
#     habitat_col='habitatType1'
# )

# %%
# # save
# idx__s1__pixeled__gelderland__tmp2__df.to_pickle(idx__s1__pixeled__gelderland__tmp2__df_path)
# idx__s1__pixeled__website_plusHR__tmp2__df.to_pickle(idx__s1__pixeled__website_plusHR__tmp2__df_path)

# %% [markdown]
# ## Visualizing pixel count (before inspection)

# %%
# ## rounding the areacover column off 
# # Gelderland
# habitat_kart__pixeled__gelderland__RD__gdf["bedekkingsOppervlakte1"] = (
#     habitat_kart__pixeled__gelderland__RD__gdf["bedekkingsOppervlakte1"].round().astype("Int64")
# )

# # Website plusHR
# habitat_kart__pixeled__website_plusHR__RD__gdf["bedekkingsOppervlakte1"] = (
#     habitat_kart__pixeled__website_plusHR__RD__gdf["bedekkingsOppervlakte1"].round().astype("Int64")
# )

# %%
# # Estimating the pixel count
# # WD
# pixel_count__WD__pixeled__gelderland__tmp2__df, pixel_count__WD__pixeled__gelderland__tmp2__check = pixel_count_df_func(
#     gdf=habitat_kart__pixeled__gelderland__RD__gdf,
#     idx_df=idx__WD__pixeled__gelderland__tmp2__df,
# )

# pixel_count__WD__pixeled__website_plusHR__tmp2__df, pixel_count__WD__pixeled__website_plusHR__tmp2__check = pixel_count_df_func(
#     gdf=habitat_kart__pixeled__website_plusHR__RD__gdf,
#     idx_df=idx__WD__pixeled__website_plusHR__tmp2__df,
# )

# # s1
# pixel_count__s1__pixeled__gelderland__tmp2__df, pixel_count__s1__pixeled__gelderland__tmp2__check = pixel_count_df_func(
#     gdf=habitat_kart__pixeled__gelderland__RD__gdf,
#     idx_df=idx__s1__pixeled__gelderland__tmp2__df,
# )

# pixel_count__s1__pixeled__website_plusHR__tmp2__df, pixel_count__s1__pixeled__website_plusHR__tmp2__check = pixel_count_df_func(
#     gdf=habitat_kart__pixeled__website_plusHR__RD__gdf,
#     idx_df=idx__s1__pixeled__website_plusHR__tmp2__df,
# )

# %%
# # making the year cols for visualization
# tmp_2_gelderland_years = pixel_count__WD__pixeled__gelderland__tmp2__df.columns.tolist()
# tmp_2_website_plusHR_years = pixel_count__WD__pixeled__website_plusHR__tmp2__df.columns.tolist()

# %%
# pixel_vis_func(
#     df=pixel_count__WD__pixeled__gelderland__tmp2__df, 
#     years=tmp_2_gelderland_years, 
#     title="WD tmp2 Gelderland Pixels per Year"
# )

# %%
# pixel_vis_func(
#     df=pixel_count__WD__pixeled__website_plusHR__tmp2__df, 
#     years=tmp_2_website_plusHR_years, 
#     title="WD tmp2 Website_plusHR Pixels per Year"
# )

# %%
# pixel_vis_func(
#     df=pixel_count__s1__pixeled__gelderland__tmp2__df, 
#     years=tmp_2_gelderland_years, 
#     title="s1 tmp2 Gelderland Pixels per Year"
# )

# %%
# pixel_vis_func(
#     df=pixel_count__s1__pixeled__website_plusHR__tmp2__df, 
#     years=tmp_2_website_plusHR_years, 
#     title="s1 tmp2 Website_plusHR Pixels per Year"
# )

# %% [markdown]
# ## QGIS inspection export

# %% [markdown]
# #### Setting dir

# %%
# Setting dir
from functions._00_file_paths import (
    # --- (pixeled) gdfs --- 
    habitat_kart__processed__gelderland__RD__gpkg_path,
    habitat_kart__processed__website_plusHR__RD__gpkg_path,
    habitat_kart__pixeled__gelderland__RD__gpkg_path,
    habitat_kart__pixeled__website_plusHR__RD__gpkg_path,


    # --- (pixeled) idx dfs ---
    # FC_p80 tmp2
    idx__FC_p80__division__gelderland__tmp2__df_path,
    idx__FC_p80__division__website_plusHR__tmp2__df_path,
    idx__FC_p80__pixeled__gelderland__tmp2__df_path,
    idx__FC_p80__pixeled__website_plusHR__tmp2__df_path,
    # WD_p80 tmp2
    idx__WD1_p80__division__gelderland__tmp2__df_path,
    idx__WD1_p80__division__website_plusHR__tmp2__df_path,
    idx__WD2_p80__division__gelderland__tmp2__df_path,
    idx__WD2_p80__division__website_plusHR__tmp2__df_path,
    
    idx__WD1_p80__pixeled__gelderland__tmp2__df_path,
    idx__WD1_p80__pixeled__website_plusHR__tmp2__df_path,
    idx__WD2_p80__pixeled__gelderland__tmp2__df_path,
    idx__WD2_p80__pixeled__website_plusHR__tmp2__df_path,


    # --- Habitat kart idx-picked pixels GPKGs (for inspection) ---
    habitat_kart__FC_p80_tmp2_polys__gelderland__RD__gpkg_path,
    habitat_kart__FC_p80_tmp2_polys__website_plusHR__RD__gpkg_path,
    habitat_kart__FC_p80_tmp2_inspection__gelderland__RD__gpkg_path,
    habitat_kart__FC_p80_tmp2_inspection__website_plusHR__RD__gpkg_path,

    habitat_kart__WD1_p80_tmp2_polys__gelderland__RD__gpkg_path,
    habitat_kart__WD1_p80_tmp2_polys__website_plusHR__RD__gpkg_path,
    habitat_kart__WD2_p80_tmp2_polys__gelderland__RD__gpkg_path,
    habitat_kart__WD2_p80_tmp2_polys__website_plusHR__RD__gpkg_path,
    
    habitat_kart__WD1_p80_tmp2_inspection__gelderland__RD__gpkg_path,
    habitat_kart__WD1_p80_tmp2_inspection__website_plusHR__RD__gpkg_path,
    habitat_kart__WD2_p80_tmp2_inspection__gelderland__RD__gpkg_path,
    habitat_kart__WD2_p80_tmp2_inspection__website_plusHR__RD__gpkg_path,
)

# %% [markdown]
# #### Loading the GDFs

# %%
# # Loading the processed GDF
# # Gelderland 
# habitat_kart__processed__gelderland__RD__gdf = import_gpkg_func(
#     gdf_path=habitat_kart__processed__gelderland__RD__gpkg_path, 
#     layer='habitat_kart__processed__gelderland__RD__layer', 
#     index_col='index'
# )

# # Website plus hr 
# habitat_kart__processed__website_plusHR__RD__gdf = import_gpkg_func(
#     gdf_path=habitat_kart__processed__website_plusHR__RD__gpkg_path,
#     layer='habitat_kart__processed__website_plusHR__RD__layer',
#     index_col='index'
# )

# %%
# # Loading the pixeled GDF
# # Gelderland 
# habitat_kart__pixeled__gelderland__RD__gdf = import_gpkg_func(
#     gdf_path=habitat_kart__pixeled__gelderland__RD__gpkg_path, 
#     layer='habitat_kart__pixeled__gelderland__RD__layer', 
#     index_col='new_index'
# )

# # Website plus hr 
# habitat_kart__pixeled__website_plusHR__RD__gdf = import_gpkg_func(
#     gdf_path=habitat_kart__pixeled__website_plusHR__RD__gpkg_path,
#     layer='habitat_kart__pixeled__website_plusHR__RD__layer',
#     index_col='new_index'
# )

# %% [markdown]
# #### _Loading the idx dfs_

# %%
# idx__HB__division__gelderland__tmp2__df = pd.read_pickle(idx__HB__division__gelderland__tmp2__df_path)
# idx__HB__division__website_plusHR__tmp2__df = pd.read_pickle(idx__HB__division__website_plusHR__tmp2__df_path)
# idx__FC__division__gelderland__tmp2__df = pd.read_pickle(idx__FC__division__gelderland__tmp2__df_path)
# idx__FC__division__website_plusHR__tmp2__df = pd.read_pickle(idx__FC__division__website_plusHR__tmp2__df_path)

# %% [markdown]
# #### _Building the selection GPKG_

# %%
# # FC Gelderland
# habitat_kart__FC_p80_tmp2_polys__gelderland__RD__gdf = build_gpkg_from_idx_df_func(
#     idx_df=idx__FC_p80__division__gelderland__tmp2__df,
#     source_gdf=habitat_kart__processed__gelderland__RD__gdf,
#     out_gpkg=habitat_kart__FC_p80_tmp2_polys__gelderland__RD__gpkg_path,
#     single_layer=True,
#     single_layer_name="habitat_kart__FC_p80_tmp2_polys__gelderland__RD__layer",
# )

# # FC Website_plusHR
# habitat_kart__FC_p80_tmp2_polys__website_plusHR__RD__gdf = build_gpkg_from_idx_df_func(
#     idx_df=idx__FC_p80__division__website_plusHR__tmp2__df,
#     source_gdf=habitat_kart__processed__website_plusHR__RD__gdf,
#     out_gpkg=habitat_kart__FC_p80_tmp2_polys__website_plusHR__RD__gpkg_path,
#     single_layer=True,
#     single_layer_name="habitat_kart__FC_p80_tmp2_polys__website_plusHR__RD__layer",
# )

# %%
# # WD Gelderland
# habitat_kart__FC_p80_tmp2_inspection__gelderland__RD__gdf = build_gpkg_from_idx_df_func(
#     idx_df=idx__FC_p80__pixeled__gelderland__tmp2__df,
#     source_gdf=habitat_kart__pixeled__gelderland__RD__gdf,
#     out_gpkg=habitat_kart__FC_p80_tmp2_inspection__gelderland__RD__gpkg_path,
#     single_layer=True,
#     single_layer_name="habitat_kart__FC_p80_tmp2_inspection__gelderland__RD__layer",
# )

# # WD Website_plusHR
# habitat_kart__FC_p80_tmp2_inspection__website_plusHR__RD__gdf = build_gpkg_from_idx_df_func(
#     idx_df=idx__FC_p80__pixeled__website_plusHR__tmp2__df,
#     source_gdf=habitat_kart__pixeled__website_plusHR__RD__gdf,
#     out_gpkg=habitat_kart__FC_p80_tmp2_inspection__website_plusHR__RD__gpkg_path,
#     single_layer=True,
#     single_layer_name="habitat_kart__FC_p80_tmp2_inspection__website_plusHR__RD__layer",
# )

# %% [markdown]
# ## Import and check selected GPKGs

# %% [markdown]
# #### Setting dir

# %%
# Setting dir
from functions._00_file_paths import (
    # --- Selected/Inspected training validation pixels ---
    habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gpkg_path,


    # --- IDX selected dfs ---
    idx__FC_plusOW_p80__selected__gelderland__tmp2__df_path,
    idx__WD_plusOW__selected__gelderland__tmp2__df_path,
    idx__WD1_plusOW__selected__gelderland__tmp2__df_path,
    idx__WD2_plusOW__selected__gelderland__tmp2__df_path,
    idx__WD3_plusOW__selected__gelderland__tmp2__df_path,
    idx__WD4_plusOW__selected__gelderland__tmp2__df_path,
)

# %% [markdown]
# #### Load the selected GPKGs

# %%
# Loading the Selected/Inspected gdfs
# Gelderland 
habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf = import_gpkg_func(
    gdf_path=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gpkg_path, 
    layer='habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__layer', 
    index_col='index',
)

# %% [markdown]
# #### Load the available idx dfs

# %%
# idx__FC_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__FC_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# #### Update the GDF (recalculate area & cleaning)

# %%
# habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf = clean_and_update_inspected_GPKG(
#     habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf
# )

# %%
# # Save the updated GPKG
# habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf.to_file(
#     filename=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gpkg_path,
#     layer="habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__layer",
#     driver="GPKG"
# )

# %%
idx__FC_plusOW_p80__selected__gelderland__tmp2__df, idx__FC_plusOW_p80__selected__gelderland__tmp2__count = tmp_0_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
)

# %%
# Remove the LGN2025 column from FC_p80 idx
idx__FC_plusOW_p80__selected__gelderland__tmp2__df = idx__FC_plusOW_p80__selected__gelderland__tmp2__df.drop(columns='2025')

# %%
idx__FC_plusOW_p80__selected__gelderland__tmp2__df.to_pickle(idx__FC_plusOW_p80__selected__gelderland__tmp2__df_path)

# %% [markdown]
# #### Building new IDX dfs

# %%
# WD
idx__WD_plusOW__selected__gelderland__tmp2__df, idx__WD_plusOW__selected__gelderland__tmp2__count = WD_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__HB__df,
    habitat_col='habitatType1',
    wd_col='WD_division'
)

# %%
idx__WD_plusOW__selected__gelderland__tmp2__df.to_pickle(idx__WD_plusOW__selected__gelderland__tmp2__df_path)#

# %%
# WD
idx__WD1_plusOW__selected__gelderland__tmp2__df, idx__WD1_plusOW__selected__gelderland__tmp2__count = WD_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__HB__df,
    habitat_col='habitatType1',
    wd_col='WD1_division'
)

# %%
idx__WD1_plusOW__selected__gelderland__tmp2__df.to_pickle(idx__WD1_plusOW__selected__gelderland__tmp2__df_path)

# %%
# WD
idx__WD2_plusOW__selected__gelderland__tmp2__df, idx__WD2_plusOW__selected__gelderland__tmp2__count = WD_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__HB__df,
    habitat_col='habitatType1',
    wd_col='WD2_division'
)

# %%
idx__WD2_plusOW__selected__gelderland__tmp2__df.to_pickle(idx__WD2_plusOW__selected__gelderland__tmp2__df_path)

# %%
# WD
idx__WD3_plusOW__selected__gelderland__tmp2__df, idx__WD3_plusOW__selected__gelderland__tmp2__count = WD_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__HB__df,
    habitat_col='habitatType1',
    wd_col='WD3_division'
)

idx__WD3_plusOW__selected__gelderland__tmp2__df = idx__WD3_plusOW__selected__gelderland__tmp2__df.drop(index="No-Habitat")

# %%
idx__WD3_plusOW__selected__gelderland__tmp2__df.to_pickle(idx__WD3_plusOW__selected__gelderland__tmp2__df_path)

# %%
# WD
idx__WD4_plusOW__selected__gelderland__tmp2__df, idx__WD4_plusOW__selected__gelderland__tmp2__count = WD_idx_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__FC_plusOW_p80__selected__gelderland__tmp2__df,
    habitat_types_df=habitat_reference__HB__df,
    habitat_col='habitatType1',
    wd_col='WD4_division'
)

idx__WD4_plusOW__selected__gelderland__tmp2__df = idx__WD4_plusOW__selected__gelderland__tmp2__df.drop(index="No-Habitat")

# %%
idx__WD4_plusOW__selected__gelderland__tmp2__df.to_pickle(idx__WD4_plusOW__selected__gelderland__tmp2__df_path)

# %% [markdown]
# #### Visualizing pixel count

# %%
years_2017_2025 = ['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
# Load the IDX dfs
idx__FC_plusOW_p80__selected__gelderland__tmp2__df = pd.read_pickle(idx__FC_plusOW_p80__selected__gelderland__tmp2__df_path)
idx__WD_plusOW__selected__gelderland__tmp2__df = pd.read_pickle(idx__WD_plusOW__selected__gelderland__tmp2__df_path)
idx__WD1_plusOW__selected__gelderland__tmp2__df = pd.read_pickle(idx__WD1_plusOW__selected__gelderland__tmp2__df_path)
idx__WD2_plusOW__selected__gelderland__tmp2__df = pd.read_pickle(idx__WD2_plusOW__selected__gelderland__tmp2__df_path)
idx__WD3_plusOW__selected__gelderland__tmp2__df = pd.read_pickle(idx__WD3_plusOW__selected__gelderland__tmp2__df_path)
idx__WD4_plusOW__selected__gelderland__tmp2__df = pd.read_pickle(idx__WD4_plusOW__selected__gelderland__tmp2__df_path)

# %%
idx__WD_plusOW__selected__gelderland__tmp2__area_df, idx__WD_plusOW__selected__gelderland__tmp2__count = pixel_count_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD_plusOW__selected__gelderland__tmp2__df,
    area_col="bedekkingsOppervlakte1",
)

pixel_vis_func(
    df=idx__WD_plusOW__selected__gelderland__tmp2__area_df, 
    years=years_2017_2025, 
    title="WD tmp2 Gelderland Pixels per Year"
)
# Out:
# <style type="text/css">
# #T_0a74a th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_0a74a th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_0a74a caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# #T_0a74a_row0_col0, #T_0a74a_row0_col1, #T_0a74a_row0_col2, #T_0a74a_row0_col3, #T_0a74a_row0_col4, #T_0a74a_row0_col5, #T_0a74a_row0_col6, #T_0a74a_row0_col7, #T_0a74a_row2_col0, #T_0a74a_row2_col1, #T_0a74a_row2_col2, #T_0a74a_row2_col3, #T_0a74a_row2_col4, #T_0a74a_row2_col5, #T_0a74a_row2_col6, #T_0a74a_row2_col7, #T_0a74a_row4_col0, #T_0a74a_row4_col1, #T_0a74a_row4_col2, #T_0a74a_row4_col3, #T_0a74a_row4_col4, #T_0a74a_row4_col5, #T_0a74a_row4_col6, #T_0a74a_row4_col7 {
#   background-color: #ffffff;
#   color: black;
#   text-align: center;
# ...

# %%
idx__WD1_plusOW__selected__gelderland__tmp2__area_df, idx__WD1_plusOW__selected__gelderland__tmp2__count = pixel_count_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD1_plusOW__selected__gelderland__tmp2__df,
    area_col="bedekkingsOppervlakte1",
)

pixel_vis_func(
    df=idx__WD1_plusOW__selected__gelderland__tmp2__area_df, 
    years=years_2017_2025, 
    title="WD1 tmp2 Gelderland Pixels per Year"
)
# Out:
# <style type="text/css">
# #T_457e0 th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_457e0 th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_457e0 caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# #T_457e0_row0_col0, #T_457e0_row0_col1, #T_457e0_row0_col2, #T_457e0_row0_col3, #T_457e0_row0_col4, #T_457e0_row0_col5, #T_457e0_row0_col6, #T_457e0_row0_col7, #T_457e0_row2_col0, #T_457e0_row2_col1, #T_457e0_row2_col2, #T_457e0_row2_col3, #T_457e0_row2_col4, #T_457e0_row2_col5, #T_457e0_row2_col6, #T_457e0_row2_col7 {
#   background-color: #ffffff;
#   color: black;
#   text-align: center;
#   font-family: Arial;
#   font-size: 13px;
# }
# #T_457e0_row0_col8, #T_457e0_row2_col8 {
#   background-color: #ffffff;
#   background-color: #5cb85c;
#   color: black;
# ...

# %%
idx__WD2_plusOW__selected__gelderland__tmp2__area_df, idx__WD2_plusOW__selected__gelderland__tmp2__count = pixel_count_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD2_plusOW__selected__gelderland__tmp2__df,
    area_col="bedekkingsOppervlakte1",
)

pixel_vis_func(
    df=idx__WD2_plusOW__selected__gelderland__tmp2__area_df, 
    years=years_2017_2025, 
    title="WD2 tmp2 Gelderland Pixels per Year"
)
# Out:
# <style type="text/css">
# #T_95b39 th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_95b39 th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_95b39 caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# #T_95b39_row0_col0, #T_95b39_row0_col1, #T_95b39_row0_col2, #T_95b39_row0_col3, #T_95b39_row0_col4, #T_95b39_row0_col5, #T_95b39_row0_col6, #T_95b39_row0_col7, #T_95b39_row2_col0, #T_95b39_row2_col1, #T_95b39_row2_col2, #T_95b39_row2_col3, #T_95b39_row2_col4, #T_95b39_row2_col5, #T_95b39_row2_col6, #T_95b39_row2_col7 {
#   background-color: #ffffff;
#   color: black;
#   text-align: center;
#   font-family: Arial;
#   font-size: 13px;
# }
# #T_95b39_row0_col8, #T_95b39_row2_col8 {
#   background-color: #ffffff;
#   background-color: #5cb85c;
#   color: black;
# ...

# %%
idx__WD3_plusOW__selected__gelderland__tmp2__area_df, idx__WD3_plusOW__selected__gelderland__tmp2__count = pixel_count_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD3_plusOW__selected__gelderland__tmp2__df,
    area_col="bedekkingsOppervlakte1",
)

pixel_vis_func(
    df=idx__WD3_plusOW__selected__gelderland__tmp2__area_df, 
    years=years_2017_2025, 
    title="WD3 tmp2 Gelderland Pixels per Year"
)
# Out:
# <style type="text/css">
# #T_56597 th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_56597 th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_56597 caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# #T_56597_row0_col0, #T_56597_row0_col1, #T_56597_row0_col2, #T_56597_row0_col3, #T_56597_row0_col4, #T_56597_row0_col5, #T_56597_row0_col6, #T_56597_row0_col7, #T_56597_row2_col0, #T_56597_row2_col1, #T_56597_row2_col2, #T_56597_row2_col3, #T_56597_row2_col4, #T_56597_row2_col5, #T_56597_row2_col6, #T_56597_row2_col7 {
#   background-color: #ffffff;
#   color: black;
#   text-align: center;
#   font-family: Arial;
#   font-size: 13px;
# }
# #T_56597_row0_col8, #T_56597_row2_col8 {
#   background-color: #ffffff;
#   background-color: #5cb85c;
#   color: black;
# ...

# %%
idx__WD4_plusOW__selected__gelderland__tmp2__area_df, idx__WD4_plusOW__selected__gelderland__tmp2__count = pixel_count_df_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD4_plusOW__selected__gelderland__tmp2__df,
    area_col="bedekkingsOppervlakte1",
)

pixel_vis_func(
    df=idx__WD4_plusOW__selected__gelderland__tmp2__area_df, 
    years=years_2017_2025, 
    title="WD4 tmp2 Gelderland Pixels per Year"
)
# Out:
# <style type="text/css">
# #T_02ac6 th {
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_02ac6 th.row_heading {
#   font-style: italic;
#   font-weight: bold;
#   background-color: #aaaaaa;
#   color: black;
# }
# #T_02ac6 caption {
#   caption-side: top;
#   font-size: 24px;
#   font-weight: bold;
#   color: black;
#   background-color: #aaaaaa;
#   text-align: center;
#   padding: 0px;
# }
# #T_02ac6_row0_col0, #T_02ac6_row0_col1, #T_02ac6_row0_col2, #T_02ac6_row0_col3, #T_02ac6_row0_col4, #T_02ac6_row0_col5, #T_02ac6_row0_col6, #T_02ac6_row0_col7, #T_02ac6_row2_col0, #T_02ac6_row2_col1, #T_02ac6_row2_col2, #T_02ac6_row2_col3, #T_02ac6_row2_col4, #T_02ac6_row2_col5, #T_02ac6_row2_col6, #T_02ac6_row2_col7 {
#   background-color: #ffffff;
#   color: black;
#   text-align: center;
#   font-family: Arial;
#   font-size: 13px;
# }
# #T_02ac6_row0_col8, #T_02ac6_row2_col8 {
#   background-color: #ffffff;
#   background-color: #5cb85c;
#   color: black;
# ...

# %% [markdown]
# ## Training validation split

# %% [markdown]
# #### Determining the area that will go into training / validating

# %%
WD_area_text = idx_per_row_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD_plusOW__selected__gelderland__tmp2__df,
    area_col="bedekkingsOppervlakte1",
    as_text=True,
    divide_by=100
)

print("WD areas per row:\n" + WD_area_text)
# Out:
# WD areas per row:
# Dry Nature: 128967.81 pixels
# Wet Nature: 270.87 pixels
# No-Habitat: 182564.00 pixels
# Semi-Wet Nature: 1967.96 pixels
# Open water: 1186.64 pixels

# %%
WD_dict = {
    "Dry Nature": 1250,
    "Wet Nature": 250,
    "No-Habitat": 1250,
    "Semi-Wet Nature": 500,
    "Open water": 250,
}

# %%
WD1_area_text = idx_per_row_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD1_plusOW__selected__gelderland__tmp2__df,
    area_col="bedekkingsOppervlakte1",
    as_text=True,
)

print("WD1 areas per row:\n" + WD1_area_text)
# Out:
# WD1 areas per row:
# Remaining: 304963.81 pixels
# Wet Nature: 1559.83 pixels
# Open water: 1186.64 pixels

# %%
WD1_dict = {
    "Remaining": 3000,
    "Wet Nature": 1400,
    "Open water": 300,
}

# %%
WD2_area_text = idx_per_row_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD2_plusOW__selected__gelderland__tmp2__df,
    area_col="bedekkingsOppervlakte1",
    as_text=True,
)

print("WD3 areas per row:\n" + WD2_area_text)
# Out:
# WD3 areas per row:
# Remaining: 304963.81 pixels
# Semi-Wet Nature: 1296.96 pixels
# Wet Nature: 262.87 pixels
# Open water: 1186.64 pixels

# %%
WD2_dict = {
    "Remaining": 1250,
    "Wet Nature": 250,
    "Semi-Wet Nature": 500,
    "Open water": 250,
}

# %%
WD3_area_text = idx_per_row_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD3_plusOW__selected__gelderland__tmp2__df,
    area_col="bedekkingsOppervlakte1",
    as_text=True,
)

print("WD3 areas per row:\n" + WD3_area_text)
# Out:
# WD3 areas per row:
# Remaining: 122399.81 pixels
# Wet Nature: 1559.83 pixels
# Open water: 1186.64 pixels

# %%
WD3_dict = {
    "Remaining": 2500,
    "Wet Nature": 1300,
    "Open water": 300,
}

# %%
WD4_area_text = idx_per_row_area_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD4_plusOW__selected__gelderland__tmp2__df,
    area_col="bedekkingsOppervlakte1",
    as_text=True,
)

print("WD4 areas per row:\n" + WD4_area_text)
# Out:
# WD4 areas per row:
# Remaining: 122399.81 pixels
# Semi-Wet Nature: 1296.96 pixels
# Wet Nature: 262.87 pixels
# Open water: 1186.64 pixels

# %%
WD4_dict = {
    "Remaining": 1250,
    "Semi-Wet Nature": 500,
    "Wet Nature": 250,
    "Open water": 300,
}

# %% [markdown]
# #### Splitting the data

# %%
# Setting dir
from functions._00_file_paths import (
    # --- IDX training/validation dfs ---
    idx__WD_plusOW_p80_tmp2_training__gelderland__df_path,
    idx__WD_plusOW_p80_tmp2_validation__gelderland__df_path,
    idx__WD1_plusOW_p80_tmp2_training__gelderland__df_path,
    idx__WD1_plusOW_p80_tmp2_validation__gelderland__df_path,
    idx__WD2_plusOW_p80_tmp2_training__gelderland__df_path,
    idx__WD2_plusOW_p80_tmp2_validation__gelderland__df_path,
    idx__WD3_plusOW_p80_tmp2_training__gelderland__df_path,
    idx__WD3_plusOW_p80_tmp2_validation__gelderland__df_path,
    idx__WD4_plusOW_p80_tmp2_training__gelderland__df_path,
    idx__WD4_plusOW_p80_tmp2_validation__gelderland__df_path,
)

# %%
idx__WD_plusOW_p80_tmp2_training__gelderland__df, idx__WD_plusOW_p80_tmp2_validation__gelderland__df, idx__WD_plusOW_p80_tmp2_test__gelderland__df, leftover_df, idx__WD_plusOW_p80_tmp2_summary__gelderland__df = training_validation_split_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD_plusOW__selected__gelderland__tmp2__df,
    year_cols=idx__WD_plusOW__selected__gelderland__tmp2__df.columns,
    cap_pixels_by_class=WD_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    seed=42,
    area_col="bedekkingsOppervlakte1",
    pixel_area_m2=100.0,
)

# %%
idx__WD_plusOW_p80_tmp2_summary__gelderland__df
# Out:
#                  target_train_m2  got_train_m2  target_val_m2  got_val_m2  \
# class_name
# Dry Nature               87500.0       88440.0        37500.0     39600.0
# Wet Nature               17500.0       15900.0         7500.0      5287.0
# No-Habitat               87500.0       88700.0        37500.0     39300.0
# Semi-Wet Nature          35000.0       38400.0        15000.0     15100.0
# Open water               17500.0       19096.0         7500.0      7618.0
#
#                  target_test_m2  got_test_m2  n_train_ids  n_val_ids  \
# class_name
# Dry Nature                  0.0          0.0          888        396
# Wet Nature                  0.0          0.0          155         45
# No-Habitat                  0.0          0.0          887        393
# Semi-Wet Nature             0.0          0.0          386        151
# Open water                  0.0          0.0          234         93
#
#                  n_test_ids  n_leftover_ids  n_unavailable_ids_ignored  \
# ...

# %%
idx__WD_plusOW_p80_tmp2_training__gelderland__df.to_pickle(idx__WD_plusOW_p80_tmp2_training__gelderland__df_path)
idx__WD_plusOW_p80_tmp2_validation__gelderland__df.to_pickle(idx__WD_plusOW_p80_tmp2_validation__gelderland__df_path)

# %%
idx__WD1_plusOW_p80_tmp2_training__gelderland__df, idx__WD1_plusOW_p80_tmp2_validation__gelderland__df, idx__WD1_plusOW_p80_tmp2_test__gelderland__df, leftover_df, idx__WD1_plusOW_p80_tmp2_summary__gelderland__df = training_validation_split_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD1_plusOW__selected__gelderland__tmp2__df,
    year_cols=idx__WD1_plusOW__selected__gelderland__tmp2__df.columns,
    cap_pixels_by_class=WD1_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    seed=42,
    area_col="bedekkingsOppervlakte1",
    pixel_area_m2=100.0,
)

# %%
idx__WD1_plusOW_p80_tmp2_summary__gelderland__df
# Out:
#             target_train_m2  got_train_m2  target_val_m2  got_val_m2  \
# class_name
# Remaining          210000.0      211936.0        90000.0     90160.0
# Wet Nature          98000.0       72032.0        42000.0     14051.0
# Open water          21000.0       22697.0         9000.0     10153.0
#
#             target_test_m2  got_test_m2  n_train_ids  n_val_ids  n_test_ids  \
# class_name
# Remaining              0.0          0.0         2127        903           0
# Wet Nature             0.0          0.0          710        141           0
# Open water             0.0          0.0          250        147           0
#
#             n_leftover_ids  n_unavailable_ids_ignored  n_invalid_ids_ignored  \
# class_name
# Remaining           292260                          0                      0
# Wet Nature               0                          0                      0
# Open water            2121                          0                      0
#
# ...

# %%
idx__WD1_plusOW_p80_tmp2_training__gelderland__df.to_pickle(idx__WD1_plusOW_p80_tmp2_training__gelderland__df_path)
idx__WD1_plusOW_p80_tmp2_validation__gelderland__df.to_pickle(idx__WD1_plusOW_p80_tmp2_validation__gelderland__df_path)

# %%
idx__WD2_plusOW_p80_tmp2_training__gelderland__df, idx__WD2_plusOW_p80_tmp2_validation__gelderland__df, idx__WD2_plusOW_p80_tmp2_test__gelderland__df, leftover_df, idx__WD2_plusOW_p80_tmp2_summary__gelderland__df = training_validation_split_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD2_plusOW__selected__gelderland__tmp2__df,
    year_cols=idx__WD2_plusOW__selected__gelderland__tmp2__df.columns,
    cap_pixels_by_class=WD2_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    seed=42,
    area_col="bedekkingsOppervlakte1",
    pixel_area_m2=100.0,
)

# %%
idx__WD2_plusOW_p80_tmp2_summary__gelderland__df
# Out:
#                  target_train_m2  got_train_m2  target_val_m2  got_val_m2  \
# class_name
# Remaining                87500.0       88996.0        37500.0     38900.0
# Semi-Wet Nature          35000.0       35096.0        15000.0     16600.0
# Wet Nature               17500.0       16287.0         7500.0      4100.0
# Open water               17500.0       17516.0         7500.0      9197.0
#
#                  target_test_m2  got_test_m2  n_train_ids  n_val_ids  \
# class_name
# Remaining                   0.0          0.0          894        389
# Semi-Wet Nature             0.0          0.0          353        166
# Wet Nature                  0.0          0.0          151         41
# Open water                  0.0          0.0          214        124
#
#                  n_test_ids  n_leftover_ids  n_unavailable_ids_ignored  \
# class_name
# Remaining                 0          298089                          0
# ...

# %%
idx__WD2_plusOW_p80_tmp2_training__gelderland__df.to_pickle(idx__WD2_plusOW_p80_tmp2_training__gelderland__df_path)
idx__WD2_plusOW_p80_tmp2_validation__gelderland__df.to_pickle(idx__WD2_plusOW_p80_tmp2_validation__gelderland__df_path)

# %%
idx__WD3_plusOW_p80_tmp2_training__gelderland__df, idx__WD3_plusOW_p80_tmp2_validation__gelderland__df, idx__WD3_plusOW_p80_tmp2_test__gelderland__df, leftover_df, idx__WD3_plusOW_p80_tmp2_summary__gelderland__df = training_validation_split_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD3_plusOW__selected__gelderland__tmp2__df,
    year_cols=idx__WD3_plusOW__selected__gelderland__tmp2__df.columns,
    cap_pixels_by_class=WD3_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    seed=42,
    area_col="bedekkingsOppervlakte1",
    pixel_area_m2=100.0,
)

# %%
idx__WD3_plusOW_p80_tmp2_summary__gelderland__df
# Out:
#             target_train_m2  got_train_m2  target_val_m2  got_val_m2  \
# class_name
# Remaining          175000.0      178300.0        75000.0     75900.0
# Wet Nature          91000.0       69583.0        39000.0     19500.0
# Open water          21000.0       21972.0         9000.0     10493.0
#
#             target_test_m2  got_test_m2  n_train_ids  n_val_ids  n_test_ids  \
# class_name
# Remaining              0.0          0.0         1789        759           0
# Wet Nature             0.0          0.0          686        195           0
# Open water             0.0          0.0          277        131           0
#
#             n_leftover_ids  n_unavailable_ids_ignored  n_invalid_ids_ignored  \
# class_name
# Remaining           115917                          0                      0
# Wet Nature               0                          0                      0
# Open water            3041                          0                      0
#
# ...

# %%
idx__WD3_plusOW_p80_tmp2_training__gelderland__df.to_pickle(idx__WD3_plusOW_p80_tmp2_training__gelderland__df_path)
idx__WD3_plusOW_p80_tmp2_validation__gelderland__df.to_pickle(idx__WD3_plusOW_p80_tmp2_validation__gelderland__df_path)

# %%
idx__WD4_plusOW_p80_tmp2_training__gelderland__df, idx__WD4_plusOW_p80_tmp2_validation__gelderland__df, idx__WD4_plusOW_p80_tmp2_test__gelderland__df, leftover_df, idx__WD4_plusOW_p80_tmp2_summary__gelderland__df = training_validation_split_func(
    gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
    idx_df=idx__WD4_plusOW__selected__gelderland__tmp2__df,
    year_cols=idx__WD4_plusOW__selected__gelderland__tmp2__df.columns,
    cap_pixels_by_class=WD4_dict,
    train_pct=0.7,
    val_pct=0.3,
    test_pct=0.0,
    seed=42,
    area_col="bedekkingsOppervlakte1",
    pixel_area_m2=100.0,
)

# %%
idx__WD4_plusOW_p80_tmp2_summary__gelderland__df
# Out:
#                  target_train_m2  got_train_m2  target_val_m2  got_val_m2  \
# class_name
# Remaining                87500.0       90040.0        37500.0     39960.0
# Semi-Wet Nature          35000.0       35396.0        15000.0     18000.0
# Wet Nature               17500.0       15125.0         7500.0      5262.0
# Open water               21000.0       21015.0         9000.0      9302.0
#
#                  target_test_m2  got_test_m2  n_train_ids  n_val_ids  \
# class_name
# Remaining                   0.0          0.0          904        402
# Semi-Wet Nature             0.0          0.0          356        180
# Wet Nature                  0.0          0.0          142         50
# Open water                  0.0          0.0          258        102
#
#                  n_test_ids  n_leftover_ids  n_unavailable_ids_ignored  \
# class_name
# Remaining                 0          119350                          0
# ...

# %%
idx__WD4_plusOW_p80_tmp2_training__gelderland__df.to_pickle(idx__WD4_plusOW_p80_tmp2_training__gelderland__df_path)
idx__WD4_plusOW_p80_tmp2_validation__gelderland__df.to_pickle(idx__WD4_plusOW_p80_tmp2_validation__gelderland__df_path)

# %% [markdown]
# #### saving the training/validation gpkgs

# %%
# Setting dir
from functions._00_file_paths import (
    # --- IDX training/validation dfs ---
    habitat_kart__WD_plusOW_p80_tmp2__training__gelderland__gpkg_path,
    habitat_kart__WD_plusOW_p80_tmp2__validation__gelderland__gpkg_path,
    habitat_kart__WD1_plusOW_p80_tmp2__training__gelderland__gpkg_path,
    habitat_kart__WD1_plusOW_p80_tmp2__validation__gelderland__gpkg_path,
    habitat_kart__WD2_plusOW_p80_tmp2__training__gelderland__gpkg_path,
    habitat_kart__WD2_plusOW_p80_tmp2__validation__gelderland__gpkg_path,
    habitat_kart__WD3_plusOW_p80_tmp2__training__gelderland__gpkg_path,
    habitat_kart__WD3_plusOW_p80_tmp2__validation__gelderland__gpkg_path,
    habitat_kart__WD4_plusOW_p80_tmp2__training__gelderland__gpkg_path,
    habitat_kart__WD4_plusOW_p80_tmp2__validation__gelderland__gpkg_path,
)

# %%
# WD Training
habitat_kart__WD_plusOW_p80_tmp2__training__gelderland__gdf = idx_to_training_validation_gdf_func(
    idx_df=idx__WD_plusOW_p80_tmp2_training__gelderland__df, 
    source_gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
)

habitat_kart__WD_plusOW_p80_tmp2__training__gelderland__gdf.to_file(
    filename=habitat_kart__WD_plusOW_p80_tmp2__training__gelderland__gpkg_path,
    driver="GPKG"
)

# WD Validation
habitat_kart__WD_plusOW_p80_tmp2__validation__gelderland__gdf = idx_to_training_validation_gdf_func(
    idx_df=idx__WD_plusOW_p80_tmp2_validation__gelderland__df, 
    source_gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
)

habitat_kart__WD_plusOW_p80_tmp2__validation__gelderland__gdf.to_file(
    filename=habitat_kart__WD_plusOW_p80_tmp2__validation__gelderland__gpkg_path,
    driver="GPKG"
)

# %%
# WD1 Training
habitat_kart__WD1_plusOW_p80_tmp2__training__gelderland__gdf = idx_to_training_validation_gdf_func(
    idx_df=idx__WD1_plusOW_p80_tmp2_training__gelderland__df, 
    source_gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
)

habitat_kart__WD1_plusOW_p80_tmp2__training__gelderland__gdf.to_file(
    filename=habitat_kart__WD1_plusOW_p80_tmp2__training__gelderland__gpkg_path,
    driver="GPKG"
)

# WD1 Validation
habitat_kart__WD1_plusOW_p80_tmp2__validation__gelderland__gdf = idx_to_training_validation_gdf_func(
    idx_df=idx__WD1_plusOW_p80_tmp2_validation__gelderland__df, 
    source_gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
)

habitat_kart__WD1_plusOW_p80_tmp2__validation__gelderland__gdf.to_file(
    filename=habitat_kart__WD1_plusOW_p80_tmp2__validation__gelderland__gpkg_path,
    driver="GPKG"
)

# %%
# WD2 Training
habitat_kart__WD2_plusOW_p80_tmp2__training__gelderland__gdf = idx_to_training_validation_gdf_func(
    idx_df=idx__WD2_plusOW_p80_tmp2_training__gelderland__df, 
    source_gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
)

habitat_kart__WD2_plusOW_p80_tmp2__training__gelderland__gdf.to_file(
    filename=habitat_kart__WD2_plusOW_p80_tmp2__training__gelderland__gpkg_path,
    driver="GPKG"
)

# WD2 Validation
habitat_kart__WD2_plusOW_p80_tmp2__validation__gelderland__gdf = idx_to_training_validation_gdf_func(
    idx_df=idx__WD2_plusOW_p80_tmp2_validation__gelderland__df, 
    source_gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
)

habitat_kart__WD2_plusOW_p80_tmp2__validation__gelderland__gdf.to_file(
    filename=habitat_kart__WD2_plusOW_p80_tmp2__validation__gelderland__gpkg_path,
    driver="GPKG"
)

# %%
# WD3 Training
habitat_kart__WD3_plusOW_p80_tmp2__training__gelderland__gdf = idx_to_training_validation_gdf_func(
    idx_df=idx__WD3_plusOW_p80_tmp2_training__gelderland__df, 
    source_gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
)

habitat_kart__WD3_plusOW_p80_tmp2__training__gelderland__gdf.to_file(
    filename=habitat_kart__WD3_plusOW_p80_tmp2__training__gelderland__gpkg_path,
    driver="GPKG"
)

# WD3 Validation
habitat_kart__WD3_plusOW_p80_tmp2__validation__gelderland__gdf = idx_to_training_validation_gdf_func(
    idx_df=idx__WD3_plusOW_p80_tmp2_validation__gelderland__df, 
    source_gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
)

habitat_kart__WD3_plusOW_p80_tmp2__validation__gelderland__gdf.to_file(
    filename=habitat_kart__WD3_plusOW_p80_tmp2__validation__gelderland__gpkg_path,
    driver="GPKG"
)

# %%
# WD Training
habitat_kart__WD4_plusOW_p80_tmp2__training__gelderland__gdf = idx_to_training_validation_gdf_func(
    idx_df=idx__WD4_plusOW_p80_tmp2_training__gelderland__df, 
    source_gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
)

habitat_kart__WD4_plusOW_p80_tmp2__training__gelderland__gdf.to_file(
    filename=habitat_kart__WD4_plusOW_p80_tmp2__training__gelderland__gpkg_path,
    driver="GPKG"
)

# WD Validation
habitat_kart__WD4_plusOW_p80_tmp2__validation__gelderland__gdf = idx_to_training_validation_gdf_func(
    idx_df=idx__WD4_plusOW_p80_tmp2_validation__gelderland__df, 
    source_gdf=habitat_kart_plusOW__FC_p80_tmp2_selected__gelderland__RD__gdf,
)

habitat_kart__WD4_plusOW_p80_tmp2__validation__gelderland__gdf.to_file(
    filename=habitat_kart__WD4_plusOW_p80_tmp2__validation__gelderland__gpkg_path,
    driver="GPKG"
)
