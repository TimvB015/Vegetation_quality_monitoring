# %% [markdown]
# _This Notebook provides an overview on the classes present in the "Landgebruik Nederland" dataset._

# %% [markdown]
# ## Importing Functions

# %%
from notebooks_dir._00_common_dfs._support._n03_funcs import (
    rgba_to_hex_func,
)

# %% [markdown]
# ## Setting directory

# %%
from paths.OG_paths import (
    #######################################
    #            00_common_dfs            #
    #######################################
    # |        n03_LGN_legend_dfs         |
    # +===================================+ 
    lgn2018_reference__df_path,
    lgn2019_reference__df_path,
    lgn2020_reference__df_path,
    lgn2021_reference__df_path,
    lgn2022_reference__df_path,
    lgn2023_reference__df_path,
    lgn2024_reference__df_path,
)

# %% [markdown]
# ## Importing packagages

# %%
import pandas as pd

# %% [markdown]
# ## LGN2018 definitions

# %%
lgn2018_reference__data = [
    {"value": 1, "rgba": (115/255, 223/255, 31/255, 1.0), "class": "agrarisch gras"},
    {"value": 2, "rgba": (232/255, 153/255, 25/255, 1.0), "class": "maïs"},
    {"value": 3, "rgba": (178/255, 102/255, 0/255,  1.0), "class": "aardappelen"},
    {"value": 4, "rgba": (229/255, 31/255,  127/255,1.0), "class": "bieten"},
    {"value": 5, "rgba": (255/255, 255/255, 0/255,  1.0), "class": "granen"},
    {"value": 6, "rgba": (255/255, 0/255,   197/255,1.0), "class": "overige landbouwgewassen"},
    {"value": 8, "rgba": (70/255,  255/255, 207/255,1.0), "class": "glastuinbouw"},
    {"value": 9, "rgba": (60/255,  239/255, 69/255, 1.0), "class": "boomgaarden"},
    {"value": 10,"rgba": (172/255, 129/255, 168/255,1.0), "class": "bloembollen"},
    {"value": 11,"rgba": (51/255,  200/255, 0/255,  1.0), "class": "loofbos"},
    {"value": 12,"rgba": (0/255,   153/255, 0/255,  1.0), "class": "naaldbos"},
    {"value": 16,"rgba": (36/255,  115/255, 255/255,1.0), "class": "zoet water"},
    {"value": 17,"rgba": (0/255,   0/255,   153/255,1.0), "class": "zout water"},
    {"value": 18,"rgba": (255/255, 0/255,   0/255,  1.0), "class": "bebouwing in primair bebouwd gebied"},
    {"value": 19,"rgba": (115/255, 0/255,   0/255,  1.0), "class": "bebouwing in secundair bebouwd gebied"},
    {"value": 20,"rgba": (147/255, 214/255, 0/255,  1.0), "class": "bos in primair bebouwd gebied"},
    {"value": 22,"rgba": (147/255, 170/255, 0/255,  1.0), "class": "bos in secundair bebouwd gebied"},
    {"value": 23,"rgba": (147/255, 255/255, 0/255,  1.0), "class": "gras in primair bebouwd gebied"},
    {"value": 24,"rgba": (255/255, 255/255, 102/255,1.0), "class": "kale grond in bebouwd gebied"},
    {"value": 25,"rgba": (204/255, 42/255,  42/255, 1.0), "class": "wegen en spoorwegen"},
    {"value": 26,"rgba": (118/255, 24/255,  24/255, 1.0), "class": "bebouwing in buitengebied"},
    {"value": 27,"rgba": (255/255, 100/255, 90/255, 1.0), "class": "overig grondgebruik in buitengebied"},
    {"value": 28,"rgba": (168/255, 239/255, 68/255, 1.0), "class": "gras in secundair bebouwd gebied"},
    {"value": 30,"rgba": (176/255, 48/255,  96/255, 1.0), "class": "kwelders"},
    {"value": 31,"rgba": (230/255, 251/255, 0/255,  1.0), "class": "open zand in kustgebied"},
    {"value": 32,"rgba": (137/255, 212/255, 43/255, 1.0), "class": "duinen met lage vegetatie"},
    {"value": 33,"rgba": (90/255,  186/255, 64/255, 1.0), "class": "duinen met hoge vegetatie"},
    {"value": 34,"rgba": (117/255, 0/255,   117/255,1.0), "class": "duinheide"},
    {"value": 35,"rgba": (255/255, 255/255, 0/255,  1.0), "class": "open stuifzand en/of rivierzand"},
    {"value": 36,"rgba": (117/255, 0/255,   117/255,1.0), "class": "heide"},
    {"value": 37,"rgba": (164/255, 35/255,  83/255, 1.0), "class": "matig vergraste heide"},
    {"value": 38,"rgba": (173/255, 139/255, 6/255,  1.0), "class": "sterk vergraste heide"},
    {"value": 39,"rgba": (36/255,  153/255, 150/255,1.0), "class": "hoogveen"},
    {"value": 40,"rgba": (6/255,   90/255,  76/255, 1.0), "class": "bos in hoogveengebied"},
    {"value": 41,"rgba": (255/255, 192/255, 203/255,1.0), "class": "overige moeras vegetatie"},
    {"value": 42,"rgba": (255/255, 165/255, 0/255,  1.0), "class": "rietvegetatie"},
    {"value": 43,"rgba": (0/255,   100/255, 0/255,  1.0), "class": "bos in moerasgebied"},
    {"value": 45,"rgba": (182/255, 182/255, 57/255, 1.0), "class": "natuurgraslanden"},
    {"value": 46,"rgba": (245/255, 225/255, 15/255, 1.0), "class": "gras in het kustgebied"},
    {"value": 47,"rgba": (150/255, 150/255, 57/255, 1.0), "class": "overig gras"},
    {"value": 61,"rgba": (255/255, 179/255, 168/255,1.0), "class": "boomkwekerijen"},
    {"value": 62,"rgba": (227/255, 255/255, 112/255,1.0), "class": "fruitkwekerijen"},
    {"value": 321,"rgba": (137/255, 212/255, 43/255,1.0), "class": "struikvegetatie in hoogveengebied (laag)"},
    {"value": 322,"rgba": (137/255, 212/255, 43/255,1.0), "class": "struikvegetatie in moerasgebied (laag)"},
    {"value": 323,"rgba": (137/255, 212/255, 43/255,1.0), "class": "overige struikvegetatie (laag)"},
    {"value": 331,"rgba": (90/255,  186/255, 64/255,1.0), "class": "struikvegetatie in hoogveengebied (hoog)"},
    {"value": 332,"rgba": (90/255,  186/255, 64/255,1.0), "class": "struikvegetatie in moerasgebied (hoog)"},
    {"value": 333,"rgba": (90/255,  186/255, 64/255,1.0), "class": "overige struikvegetatie (hoog)"},
]

# %%
lgn2018_reference__df = pd.DataFrame(lgn2018_reference__data).set_index('value')

# %%
lgn2018_reference__df["hexa"] = lgn2018_reference__df["rgba"].apply(lambda x: rgba_to_hex_func(x, True))

# %% [markdown]
# ## LGN2019 Definitions

# %%
lgn2019_reference__data = [
    {"value": 1,   "rgba": (115/255, 223/255, 31/255,  1.0), "class": "agrarisch gras"},
    {"value": 2,   "rgba": (232/255, 153/255, 25/255,  1.0), "class": "maïs"},
    {"value": 3,   "rgba": (178/255, 102/255, 0/255,   1.0), "class": "aardappelen"},
    {"value": 4,   "rgba": (229/255, 31/255,  127/255, 1.0), "class": "bieten"},
    {"value": 5,   "rgba": (255/255, 255/255, 0/255,   1.0), "class": "granen"},
    {"value": 6,   "rgba": (255/255, 0/255,   197/255, 1.0), "class": "overige landbouwgewassen"},
    {"value": 8,   "rgba": (70/255,  255/255, 207/255, 1.0), "class": "glastuinbouw"},
    {"value": 9,   "rgba": (60/255,  239/255, 69/255,  1.0), "class": "boomgaarden"},
    {"value": 10,  "rgba": (172/255, 129/255, 168/255, 1.0), "class": "bloembollen"},
    {"value": 11,  "rgba": (51/255,  200/255, 0/255,   1.0), "class": "loofbos"},
    {"value": 12,  "rgba": (0/255,   153/255, 0/255,   1.0), "class": "naaldbos"},
    {"value": 16,  "rgba": (36/255,  115/255, 255/255, 1.0), "class": "zoet water"},
    {"value": 17,  "rgba": (0/255,   0/255,   153/255, 1.0), "class": "zout water"},
    {"value": 18,  "rgba": (255/255, 0/255,   0/255,   1.0), "class": "bebouwing in primair bebouwd gebied"},
    {"value": 19,  "rgba": (115/255, 0/255,   0/255,   1.0), "class": "bebouwing in secundair bebouwd gebied"},
    {"value": 20,  "rgba": (147/255, 214/255, 0/255,   1.0), "class": "bos in primair bebouwd gebied"},
    {"value": 22,  "rgba": (147/255, 170/255, 0/255,   1.0), "class": "bos in secundair bebouwd gebied"},
    {"value": 23,  "rgba": (147/255, 255/255, 0/255,   1.0), "class": "gras in primair bebouwd gebied"},
    {"value": 24,  "rgba": (255/255, 255/255, 102/255, 1.0), "class": "kale grond in bebouwd gebied"},
    {"value": 25,  "rgba": (204/255, 42/255,  42/255,  1.0), "class": "wegen en spoorwegen"},
    {"value": 26,  "rgba": (118/255, 24/255,  24/255,  1.0), "class": "bebouwing in buitengebied"},
    {"value": 27,  "rgba": (255/255, 100/255, 90/255,  1.0), "class": "overig grondgebruik in buitengebied"},
    {"value": 28,  "rgba": (168/255, 239/255, 68/255,  1.0), "class": "gras in secundair bebouwd gebied"},
    {"value": 30,  "rgba": (176/255, 48/255,  96/255,  1.0), "class": "kwelders"},
    {"value": 31,  "rgba": (230/255, 251/255, 0/255,   1.0), "class": "open zand in kustgebied"},
    {"value": 32,  "rgba": (137/255, 212/255, 43/255,  1.0), "class": "duinen met lage vegetatie"},
    {"value": 33,  "rgba": (90/255,  186/255, 64/255,  1.0), "class": "duinen met hoge vegetatie"},
    {"value": 34,  "rgba": (117/255, 0/255,   117/255, 1.0), "class": "duinheide"},
    {"value": 35,  "rgba": (255/255, 255/255, 0/255,   1.0), "class": "open stuifzand en/of rivierzand"},
    {"value": 36,  "rgba": (117/255, 0/255,   117/255, 1.0), "class": "heide"},
    {"value": 37,  "rgba": (164/255, 35/255,  83/255,  1.0), "class": "matig vergraste heide"},
    {"value": 38,  "rgba": (173/255, 139/255, 6/255,   1.0), "class": "sterk vergraste heide"},
    {"value": 39,  "rgba": (36/255,  153/255, 150/255, 1.0), "class": "hoogveen"},
    {"value": 40,  "rgba": (6/255,   90/255,  76/255,  1.0), "class": "bos in hoogveengebied"},
    {"value": 41,  "rgba": (255/255, 192/255, 203/255, 1.0), "class": "overige moeras vegetatie"},
    {"value": 42,  "rgba": (255/255, 165/255, 0/255,   1.0), "class": "rietvegetatie"},
    {"value": 43,  "rgba": (0/255,   100/255, 0/255,   1.0), "class": "bos in moerasgebied"},
    {"value": 45,  "rgba": (182/255, 182/255, 57/255,  1.0), "class": "natuurgraslanden"},
    {"value": 46,  "rgba": (245/255, 225/255, 15/255,  1.0), "class": "gras in het kustgebied"},
    {"value": 47,  "rgba": (150/255, 150/255, 57/255,  1.0), "class": "overig gras"},
    {"value": 61,  "rgba": (255/255, 179/255, 168/255, 1.0), "class": "boomkwekerijen"},
    {"value": 62,  "rgba": (227/255, 255/255, 112/255, 1.0), "class": "fruitkwekerijen"},
    {"value": 321, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "struikvegetatie in hoogveengebied (laag)"},
    {"value": 322, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "struikvegetatie in moerasgebied (laag)"},
    {"value": 323, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "overige struikvegetatie (laag)"},
    {"value": 331, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "struikvegetatie in hoogveengebied (hoog)"},
    {"value": 332, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "struikvegetatie in moerasgebied (hoog)"},
    {"value": 333, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "overige struikvegetatie (hoog)"},
]

# %%
lgn2019_reference__df = pd.DataFrame(lgn2019_reference__data).set_index('value')

# %%
lgn2019_reference__df["hexa"] = lgn2019_reference__df["rgba"].apply(lambda x: rgba_to_hex_func(x, True))

# %% [markdown]
# ## LGN2020 Definitions

# %%
lgn2020_reference__data = [
    {"value": 1,   "rgba": (115/255, 223/255, 31/255,  1.0), "class": "agrarisch gras"},
    {"value": 2,   "rgba": (232/255, 153/255, 25/255,  1.0), "class": "maïs"},
    {"value": 3,   "rgba": (178/255, 102/255, 0/255,   1.0), "class": "aardappelen"},
    {"value": 4,   "rgba": (229/255, 31/255,  127/255, 1.0), "class": "bieten"},
    {"value": 5,   "rgba": (255/255, 255/255, 0/255,   1.0), "class": "granen"},
    {"value": 6,   "rgba": (255/255, 0/255,   197/255, 1.0), "class": "overige landbouwgewassen"},
    {"value": 8,   "rgba": (70/255,  255/255, 207/255, 1.0), "class": "glastuinbouw"},
    {"value": 9,   "rgba": (60/255,  239/255, 69/255,  1.0), "class": "boomgaarden"},
    {"value": 10,  "rgba": (172/255, 129/255, 168/255, 1.0), "class": "bloembollen"},
    {"value": 11,  "rgba": (51/255,  200/255, 0/255,   1.0), "class": "loofbos"},
    {"value": 12,  "rgba": (0/255,   153/255, 0/255,   1.0), "class": "naaldbos"},
    {"value": 16,  "rgba": (36/255,  115/255, 255/255, 1.0), "class": "zoet water"},
    {"value": 17,  "rgba": (0/255,   0/255,   153/255, 1.0), "class": "zout water"},
    {"value": 18,  "rgba": (255/255, 0/255,   0/255,   1.0), "class": "bebouwing in primair bebouwd gebied"},
    {"value": 19,  "rgba": (115/255, 0/255,   0/255,   1.0), "class": "bebouwing in secundair bebouwd gebied"},
    {"value": 20,  "rgba": (147/255, 214/255, 0/255,   1.0), "class": "bos in primair bebouwd gebied"},
    {"value": 22,  "rgba": (147/255, 170/255, 0/255,   1.0), "class": "bos in secundair bebouwd gebied"},
    {"value": 23,  "rgba": (147/255, 255/255, 0/255,   1.0), "class": "gras in primair bebouwd gebied"},
    {"value": 24,  "rgba": (255/255, 255/255, 102/255, 1.0), "class": "kale grond in bebouwd gebied"},
    {"value": 25,  "rgba": (204/255, 42/255,  42/255,  1.0), "class": "wegen en spoorwegen"},
    {"value": 26,  "rgba": (118/255, 24/255,  24/255,  1.0), "class": "bebouwing in buitengebied"},
    {"value": 27,  "rgba": (255/255, 100/255, 90/255,  1.0), "class": "overig grondgebruik in buitengebied"},
    {"value": 28,  "rgba": (168/255, 239/255, 68/255,  1.0), "class": "gras in secundair bebouwd gebied"},
    {"value": 30,  "rgba": (176/255, 48/255,  96/255,  1.0), "class": "kwelders"},
    {"value": 31,  "rgba": (230/255, 251/255, 0/255,   1.0), "class": "open zand in kustgebied"},
    {"value": 32,  "rgba": (137/255, 212/255, 43/255,  1.0), "class": "duinen met lage vegetatie"},
    {"value": 33,  "rgba": (90/255,  186/255, 64/255,  1.0), "class": "duinen met hoge vegetatie"},
    {"value": 34,  "rgba": (117/255, 0/255,   117/255, 1.0), "class": "duinheide"},
    {"value": 35,  "rgba": (255/255, 255/255, 0/255,   1.0), "class": "open stuifzand en/of rivierzand"},
    {"value": 36,  "rgba": (117/255, 0/255,   117/255, 1.0), "class": "heide"},
    {"value": 37,  "rgba": (164/255, 35/255,  83/255,  1.0), "class": "matig vergraste heide"},
    {"value": 38,  "rgba": (173/255, 139/255, 6/255,   1.0), "class": "sterk vergraste heide"},
    {"value": 39,  "rgba": (36/255,  153/255, 150/255, 1.0), "class": "hoogveen"},
    {"value": 40,  "rgba": (6/255,   90/255,  76/255,  1.0), "class": "bos in hoogveengebied"},
    {"value": 41,  "rgba": (255/255, 192/255, 203/255, 1.0), "class": "overige moeras vegetatie"},
    {"value": 42,  "rgba": (255/255, 165/255, 0/255,   1.0), "class": "rietvegetatie"},
    {"value": 43,  "rgba": (0/255,   100/255, 0/255,   1.0), "class": "bos in moerasgebied"},
    {"value": 45,  "rgba": (182/255, 182/255, 57/255,  1.0), "class": "natuurgraslanden"},
    {"value": 46,  "rgba": (245/255, 225/255, 15/255,  1.0), "class": "gras in het kustgebied"},
    {"value": 47,  "rgba": (150/255, 150/255, 57/255,  1.0), "class": "overig gras"},
    {"value": 61,  "rgba": (255/255, 179/255, 168/255, 1.0), "class": "boomkwekerijen"},
    {"value": 62,  "rgba": (227/255, 255/255, 112/255, 1.0), "class": "fruitkwekerijen"},
    {"value": 321, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "struikvegetatie in hoogveengebied (laag)"},
    {"value": 322, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "struikvegetatie in moerasgebied (laag)"},
    {"value": 323, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "overige struikvegetatie (laag)"},
    {"value": 331, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "struikvegetatie in hoogveengebied (hoog)"},
    {"value": 332, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "struikvegetatie in moerasgebied (hoog)"},
    {"value": 333, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "overige struikvegetatie (hoog)"},
]

# %%
lgn2020_reference__df = pd.DataFrame(lgn2020_reference__data).set_index('value')

# %%
lgn2020_reference__df["hexa"] = lgn2020_reference__df["rgba"].apply(lambda x: rgba_to_hex_func(x, True))

# %% [markdown]
# ## LGN2021 Definitions

# %%
lgn2021_reference__data = [
    {"value": 1,   "rgba": (115/255, 223/255, 31/255,  1.0), "class": "agrarisch gras"},
    {"value": 2,   "rgba": (232/255, 153/255, 25/255,  1.0), "class": "maïs"},
    {"value": 3,   "rgba": (178/255, 102/255, 0/255,   1.0), "class": "aardappelen"},
    {"value": 4,   "rgba": (229/255, 31/255,  127/255, 1.0), "class": "bieten"},
    {"value": 5,   "rgba": (255/255, 255/255, 0/255,   1.0), "class": "granen"},
    {"value": 6,   "rgba": (255/255, 0/255,   197/255, 1.0), "class": "overige landbouwgewassen"},
    {"value": 8,   "rgba": (70/255,  255/255, 207/255, 1.0), "class": "glastuinbouw"},
    {"value": 9,   "rgba": (60/255,  239/255, 69/255,  1.0), "class": "boomgaarden"},
    {"value": 10,  "rgba": (172/255, 129/255, 168/255, 1.0), "class": "bloembollen"},
    {"value": 11,  "rgba": (51/255,  200/255, 0/255,   1.0), "class": "loofbos"},
    {"value": 12,  "rgba": (0/255,   153/255, 0/255,   1.0), "class": "naaldbos"},
    {"value": 16,  "rgba": (36/255,  115/255, 255/255, 1.0), "class": "zoet water"},
    {"value": 17,  "rgba": (0/255,   0/255,   153/255, 1.0), "class": "zout water"},
    {"value": 18,  "rgba": (255/255, 0/255,   0/255,   1.0), "class": "bebouwing in primair bebouwd gebied"},
    {"value": 19,  "rgba": (115/255, 0/255,   0/255,   1.0), "class": "bebouwing in secundair bebouwd gebied"},
    {"value": 20,  "rgba": (147/255, 214/255, 0/255,   1.0), "class": "bos in primair bebouwd gebied"},
    {"value": 22,  "rgba": (147/255, 170/255, 0/255,   1.0), "class": "bos in secundair bebouwd gebied"},
    {"value": 23,  "rgba": (147/255, 255/255, 0/255,   1.0), "class": "gras in primair bebouwd gebied"},
    {"value": 24,  "rgba": (255/255, 255/255, 102/255, 1.0), "class": "kale grond in bebouwd gebied"},
    {"value": 25,  "rgba": (204/255, 42/255,  42/255,  1.0), "class": "wegen en spoorwegen"},
    {"value": 26,  "rgba": (118/255, 24/255,  24/255,  1.0), "class": "bebouwing in buitengebied"},
    {"value": 27,  "rgba": (255/255, 100/255, 90/255,  1.0), "class": "overig grondgebruik in buitengebied"},
    {"value": 28,  "rgba": (168/255, 239/255, 68/255,  1.0), "class": "gras in secundair bebouwd gebied"},
    {"value": 29,  "rgba": (0/255,   0/255,   0/255,   1.0), "class": "zonneparken"},
    {"value": 30,  "rgba": (176/255, 48/255,  96/255,  1.0), "class": "kwelders"},
    {"value": 31,  "rgba": (230/255, 251/255, 0/255,   1.0), "class": "open zand in kustgebied"},
    {"value": 32,  "rgba": (137/255, 212/255, 43/255,  1.0), "class": "duinen met lage vegetatie"},
    {"value": 33,  "rgba": (90/255,  186/255, 64/255,  1.0), "class": "duinen met hoge vegetatie"},
    {"value": 34,  "rgba": (117/255, 0/255,   117/255, 1.0), "class": "duinheide"},
    {"value": 35,  "rgba": (255/255, 255/255, 0/255,   1.0), "class": "open stuifzand en/of rivierzand"},
    {"value": 36,  "rgba": (117/255, 0/255,   117/255, 1.0), "class": "heide"},
    {"value": 37,  "rgba": (164/255, 35/255,  83/255,  1.0), "class": "matig vergraste heide"},
    {"value": 38,  "rgba": (173/255, 139/255, 6/255,   1.0), "class": "sterk vergraste heide"},
    {"value": 39,  "rgba": (36/255,  153/255, 150/255, 1.0), "class": "hoogveen"},
    {"value": 40,  "rgba": (6/255,   90/255,  76/255,  1.0), "class": "bos in hoogveengebied"},
    {"value": 41,  "rgba": (255/255, 192/255, 203/255, 1.0), "class": "overige moeras vegetatie"},
    {"value": 42,  "rgba": (255/255, 165/255, 0/255,   1.0), "class": "rietvegetatie"},
    {"value": 43,  "rgba": (0/255,   100/255, 0/255,   1.0), "class": "bos in moerasgebied"},
    {"value": 45,  "rgba": (182/255, 182/255, 57/255,  1.0), "class": "natuurlijk beheerde agrarische graslanden"},
    {"value": 46,  "rgba": (245/255, 225/255, 15/255,  1.0), "class": "gras in het kustgebied"},
    {"value": 47,  "rgba": (150/255, 150/255, 57/255,  1.0), "class": "overig gras"},
    {"value": 61,  "rgba": (255/255, 179/255, 168/255, 1.0), "class": "boomkwekerijen"},
    {"value": 62,  "rgba": (227/255, 255/255, 112/255, 1.0), "class": "fruitkwekerijen"},
    {"value": 251, "rgba": (135/255, 27/255,  0/255,   1.0), "class": "hoofdinfrastructuur en spoorbaanlichamen"},
    {"value": 252, "rgba": (176/255, 35/255,  0/255,   1.0), "class": "halfverharde wegen, infrastructuur langzaam verkeer en overige infrastructuur"},
    {"value": 253, "rgba": (168/255, 0/255,   0/255,   1.0), "class": "smalle wegen"},
    {"value": 321, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "struikvegetatie in hoogveengebied (laag)"},
    {"value": 322, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "struikvegetatie in moerasgebied (laag)"},
    {"value": 323, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "overige struikvegetatie (laag)"},
    {"value": 331, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "struikvegetatie in hoogveengebied (hoog)"},
    {"value": 332, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "struikvegetatie in moerasgebied (hoog)"},
    {"value": 333, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "overige struikvegetatie (hoog)"},
]

# %%
lgn2021_reference__df = pd.DataFrame(lgn2021_reference__data).set_index('value')

# %%
lgn2021_reference__df["hexa"] = lgn2021_reference__df["rgba"].apply(lambda x: rgba_to_hex_func(x, True))

# %% [markdown]
# ## LGN2022 Defintions

# %%
lgn2022_reference__data = [
    {"value": 1,   "rgba": (115/255, 223/255, 31/255,  1.0), "class": "agrarisch gras"},
    {"value": 2,   "rgba": (232/255, 153/255, 25/255,  1.0), "class": "mais"},
    {"value": 3,   "rgba": (178/255, 102/255, 0/255,   1.0), "class": "aardappelen"},
    {"value": 4,   "rgba": (229/255, 31/255,  127/255, 1.0), "class": "bieten"},
    {"value": 5,   "rgba": (255/255, 255/255, 0/255,   1.0), "class": "granen"},
    {"value": 6,   "rgba": (255/255, 0/255,   197/255, 1.0), "class": "overige landbouwgewassen"},
    {"value": 8,   "rgba": (70/255,  255/255, 207/255, 1.0), "class": "glastuinbouw"},
    {"value": 9,   "rgba": (60/255,  239/255, 69/255,  1.0), "class": "boomgaarden"},
    {"value": 10,  "rgba": (172/255, 129/255, 168/255, 1.0), "class": "bloembollen"},
    {"value": 11,  "rgba": (51/255,  200/255, 0/255,   1.0), "class": "loofbos"},
    {"value": 12,  "rgba": (0/255,   153/255, 0/255,   1.0), "class": "naaldbos"},
    {"value": 16,  "rgba": (36/255,  115/255, 255/255, 1.0), "class": "zoet water"},
    {"value": 17,  "rgba": (0/255,   0/255,   153/255, 1.0), "class": "zout water"},
    {"value": 18,  "rgba": (255/255, 0/255,   0/255,   1.0), "class": "bebouwing in primair bebouwd gebied"},
    {"value": 19,  "rgba": (115/255, 0/255,   0/255,   1.0), "class": "bebouwing in secundair bebouwd gebied"},
    {"value": 20,  "rgba": (147/255, 214/255, 0/255,   1.0), "class": "bos in primair bebouwd gebied"},
    {"value": 22,  "rgba": (147/255, 170/255, 0/255,   1.0), "class": "bos in secundair bebouwd gebied"},
    {"value": 23,  "rgba": (147/255, 255/255, 0/255,   1.0), "class": "gras in primair bebouwd gebied"},
    {"value": 24,  "rgba": (255/255, 255/255, 102/255, 1.0), "class": "kale grond in bebouwd gebied"},
    {"value": 26,  "rgba": (118/255, 24/255,  24/255,  1.0), "class": "bebouwing in buitengebied"},
    {"value": 27,  "rgba": (255/255, 100/255, 90/255,  1.0), "class": "overig grondgebruik in buitengebied"},
    {"value": 28,  "rgba": (168/255, 239/255, 68/255,  1.0), "class": "gras in secundair bebouwd gebied"},
    {"value": 29,  "rgba": (0/255,   0/255,   0/255,   1.0), "class": "zonneparken"},
    {"value": 30,  "rgba": (176/255, 48/255,  96/255,  1.0), "class": "kwelders"},
    {"value": 31,  "rgba": (230/255, 251/255, 0/255,   1.0), "class": "open zand in kustgebied"},
    {"value": 32,  "rgba": (137/255, 212/255, 43/255,  1.0), "class": "duinen met lage vegetatie"},
    {"value": 33,  "rgba": (90/255,  186/255, 64/255,  1.0), "class": "duinen met hoge vegetatie"},
    {"value": 34,  "rgba": (117/255, 0/255,   117/255, 1.0), "class": "duinheide"},
    {"value": 35,  "rgba": (255/255, 255/255, 0/255,   1.0), "class": "open stuifzand en/of rivierzand"},
    {"value": 36,  "rgba": (117/255, 0/255,   117/255, 1.0), "class": "heide"},
    {"value": 37,  "rgba": (164/255, 35/255,  83/255,  1.0), "class": "matig vergraste heide"},
    {"value": 38,  "rgba": (173/255, 139/255, 6/255,   1.0), "class": "sterk vergraste heide"},
    {"value": 39,  "rgba": (36/255,  153/255, 150/255, 1.0), "class": "hoogveen"},
    {"value": 40,  "rgba": (6/255,   90/255,  76/255,  1.0), "class": "bos in hoogveengebied"},
    {"value": 41,  "rgba": (255/255, 192/255, 203/255, 1.0), "class": "overige moeras vegetatie"},
    {"value": 42,  "rgba": (255/255, 165/255, 0/255,   1.0), "class": "rietvegetatie"},
    {"value": 43,  "rgba": (0/255,   100/255, 0/255,   1.0), "class": "bos in moerasgebied"},
    {"value": 45,  "rgba": (182/255, 182/255, 57/255,  1.0), "class": "natuurlijk beheerde agrarische graslanden"},
    {"value": 46,  "rgba": (245/255, 225/255, 15/255,  1.0), "class": "gras in het kustgebied"},
    {"value": 47,  "rgba": (150/255, 150/255, 57/255,  1.0), "class": "overig gras"},
    {"value": 61,  "rgba": (255/255, 179/255, 168/255, 1.0), "class": "boomkwekerijen"},
    {"value": 62,  "rgba": (227/255, 255/255, 112/255, 1.0), "class": "fruitkwekerijen"},
    {"value": 251, "rgba": (135/255, 27/255,  0/255,   1.0), "class": "hoofdinfrastructuur en spoorbaanlichamen"},
    {"value": 252, "rgba": (176/255, 35/255,  0/255,   1.0), "class": "halfverharde wegen, infrastructuur langzaam verkeer en overige infrastructuur"},
    {"value": 253, "rgba": (168/255, 0/255,   0/255,   1.0), "class": "smalle wegen"},
    {"value": 321, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "struikvegetatie in hoogveengebied (laag)"},
    {"value": 322, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "struikvegetatie in moerasgebied (laag)"},
    {"value": 323, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "overige struikvegetatie (laag)"},
    {"value": 331, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "struikvegetatie in hoogveengebied (hoog)"},
    {"value": 332, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "struikvegetatie in moerasgebied (hoog)"},
    {"value": 333, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "overige struikvegetatie (hoog)"},
]

# %%
lgn2022_reference__df = pd.DataFrame(lgn2022_reference__data).set_index('value')

# %%
lgn2022_reference__df["hexa"] = lgn2022_reference__df["rgba"].apply(lambda x: rgba_to_hex_func(x, True))

# %% [markdown]
# ## LGN2023 Definitions

# %%
lgn2023_reference__data = [
    {"value": 1,   "rgba": (115/255, 223/255, 31/255,  1.0), "class": "agrarisch gras"},
    {"value": 2,   "rgba": (232/255, 153/255, 25/255,  1.0), "class": "mais"},
    {"value": 3,   "rgba": (178/255, 102/255, 0/255,   1.0), "class": "aardappelen"},
    {"value": 4,   "rgba": (229/255, 31/255,  127/255, 1.0), "class": "bieten"},
    {"value": 5,   "rgba": (255/255, 255/255, 0/255,   1.0), "class": "granen"},
    {"value": 6,   "rgba": (255/255, 0/255,   197/255, 1.0), "class": "overige landbouwgewassen"},
    {"value": 8,   "rgba": (70/255,  255/255, 207/255, 1.0), "class": "glastuinbouw"},
    {"value": 9,   "rgba": (60/255,  239/255, 69/255,  1.0), "class": "boomgaarden"},
    {"value": 10,  "rgba": (172/255, 129/255, 168/255, 1.0), "class": "bloembollen"},
    {"value": 11,  "rgba": (51/255,  200/255, 0/255,   1.0), "class": "loofbos"},
    {"value": 12,  "rgba": (0/255,   153/255, 0/255,   1.0), "class": "naaldbos"},
    {"value": 16,  "rgba": (36/255,  115/255, 255/255, 1.0), "class": "zoet water"},
    {"value": 17,  "rgba": (0/255,   0/255,   153/255, 1.0), "class": "zout water"},
    {"value": 18,  "rgba": (255/255, 0/255,   0/255,   1.0), "class": "bebouwing in primair bebouwd gebied"},
    {"value": 19,  "rgba": (115/255, 0/255,   0/255,   1.0), "class": "bebouwing in secundair bebouwd gebied"},
    {"value": 20,  "rgba": (147/255, 214/255, 0/255,   1.0), "class": "bos in primair bebouwd gebied"},
    {"value": 22,  "rgba": (147/255, 170/255, 0/255,   1.0), "class": "bos in secundair bebouwd gebied"},
    {"value": 23,  "rgba": (147/255, 255/255, 0/255,   1.0), "class": "gras in primair bebouwd gebied"},
    {"value": 26,  "rgba": (118/255, 24/255,  24/255,  1.0), "class": "bebouwing in buitengebied"},
    {"value": 27,  "rgba": (255/255, 100/255, 90/255,  1.0), "class": "overig grondgebruik in buitengebied"},
    {"value": 28,  "rgba": (168/255, 239/255, 68/255,  1.0), "class": "gras in secundair bebouwd gebied"},
    {"value": 29,  "rgba": (0/255,   0/255,   0/255,   1.0), "class": "zonneparken"},
    {"value": 30,  "rgba": (176/255, 48/255,  96/255,  1.0), "class": "kwelders"},
    {"value": 31,  "rgba": (230/255, 251/255, 0/255,   1.0), "class": "open zand in kustgebied"},
    {"value": 32,  "rgba": (137/255, 212/255, 43/255,  1.0), "class": "duinen met lage vegetatie"},
    {"value": 33,  "rgba": (90/255,  186/255, 64/255,  1.0), "class": "duinen met hoge vegetatie"},
    {"value": 34,  "rgba": (117/255, 0/255,   117/255, 1.0), "class": "duinheide"},
    {"value": 35,  "rgba": (255/255, 255/255, 0/255,   1.0), "class": "open stuifzand en/of rivierzand"},
    {"value": 36,  "rgba": (117/255, 0/255,   117/255, 1.0), "class": "heide"},
    {"value": 37,  "rgba": (164/255, 35/255,  83/255,  1.0), "class": "matig vergraste heide"},
    {"value": 38,  "rgba": (173/255, 139/255, 6/255,   1.0), "class": "sterk vergraste heide"},
    {"value": 39,  "rgba": (36/255,  153/255, 150/255, 1.0), "class": "hoogveen"},
    {"value": 40,  "rgba": (6/255,   90/255,  76/255,  1.0), "class": "bos in hoogveengebied"},
    {"value": 41,  "rgba": (255/255, 192/255, 203/255, 1.0), "class": "overige moeras vegetatie"},
    {"value": 42,  "rgba": (255/255, 165/255, 0/255,   1.0), "class": "rietvegetatie"},
    {"value": 43,  "rgba": (0/255,   100/255, 0/255,   1.0), "class": "bos in moerasgebied"},
    {"value": 45,  "rgba": (182/255, 182/255, 57/255,  1.0), "class": "natuurlijk beheerde agrarische graslanden"},
    {"value": 46,  "rgba": (245/255, 225/255, 15/255,  1.0), "class": "gras in het kustgebied"},
    {"value": 47,  "rgba": (150/255, 150/255, 57/255,  1.0), "class": "overig gras"},
    {"value": 61,  "rgba": (255/255, 179/255, 168/255, 1.0), "class": "boomkwekerijen"},
    {"value": 62,  "rgba": (227/255, 255/255, 112/255, 1.0), "class": "fruitkwekerijen"},
    {"value": 251, "rgba": (135/255, 27/255,  0/255,   1.0), "class": "hoofdinfrastructuur en spoorbaanlichamen"},
    {"value": 252, "rgba": (176/255, 35/255,  0/255,   1.0), "class": "halfverharde wegen, infrastructuur langzaam verkeer en overige infrastructuur"},
    {"value": 253, "rgba": (168/255, 0/255,   0/255,   1.0), "class": "smalle wegen"},
    {"value": 321, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "struikvegetatie in hoogveengebied (laag)"},
    {"value": 322, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "struikvegetatie in moerasgebied (laag)"},
    {"value": 323, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "overige struikvegetatie (laag)"},
    {"value": 331, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "struikvegetatie in hoogveengebied (hoog)"},
    {"value": 332, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "struikvegetatie in moerasgebied (hoog)"},
    {"value": 333, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "overige struikvegetatie (hoog)"},
]

# %%
lgn2023_reference__df = pd.DataFrame(lgn2023_reference__data).set_index('value')

# %%
lgn2023_reference__df["hexa"] = lgn2023_reference__df["rgba"].apply(lambda x: rgba_to_hex_func(x, True))

# %% [markdown]
# ## LGN2024 Definitions

# %%
lgn2024_reference__data = [
    {"value": 1,   "rgba": (115/255, 223/255, 31/255,  1.0), "class": "agrarisch gras"},
    {"value": 2,   "rgba": (232/255, 153/255, 25/255,  1.0), "class": "mais"},
    {"value": 3,   "rgba": (178/255, 102/255, 0/255,   1.0), "class": "aardappelen"},
    {"value": 4,   "rgba": (229/255, 31/255,  127/255, 1.0), "class": "bieten"},
    {"value": 5,   "rgba": (255/255, 255/255, 0/255,   1.0), "class": "granen"},
    {"value": 6,   "rgba": (255/255, 0/255,   197/255, 1.0), "class": "overige landbouwgewassen"},
    {"value": 8,   "rgba": (70/255,  255/255, 207/255, 1.0), "class": "glastuinbouw"},
    {"value": 9,   "rgba": (60/255,  239/255, 69/255,  1.0), "class": "boomgaarden"},
    {"value": 10,  "rgba": (172/255, 129/255, 168/255, 1.0), "class": "bloembollen"},
    {"value": 11,  "rgba": (51/255,  200/255, 0/255,   1.0), "class": "loofbos"},
    {"value": 12,  "rgba": (0/255,   153/255, 0/255,   1.0), "class": "naaldbos"},
    {"value": 16,  "rgba": (36/255,  115/255, 255/255, 1.0), "class": "zoet water"},
    {"value": 17,  "rgba": (0/255,   0/255,   153/255, 1.0), "class": "zout water"},
    {"value": 18,  "rgba": (255/255, 0/255,   0/255,   1.0), "class": "bebouwing in primair bebouwd gebied"},
    {"value": 19,  "rgba": (115/255, 0/255,   0/255,   1.0), "class": "bebouwing in secundair bebouwd gebied"},
    {"value": 20,  "rgba": (147/255, 214/255, 0/255,   1.0), "class": "bos in primair bebouwd gebied"},
    {"value": 22,  "rgba": (147/255, 170/255, 0/255,   1.0), "class": "bos in secundair bebouwd gebied"},
    {"value": 23,  "rgba": (147/255, 255/255, 0/255,   1.0), "class": "gras in primair bebouwd gebied"},
    {"value": 26,  "rgba": (118/255, 24/255,  24/255,  1.0), "class": "bebouwing in buitengebied"},
    {"value": 27,  "rgba": (255/255, 100/255, 90/255,  1.0), "class": "overig grondgebruik in buitengebied"},
    {"value": 28,  "rgba": (168/255, 239/255, 68/255,  1.0), "class": "gras in secundair bebouwd gebied"},
    {"value": 29,  "rgba": (0/255,   0/255,   0/255,   1.0), "class": "zonneparken"},
    {"value": 30,  "rgba": (176/255, 48/255,  96/255,  1.0), "class": "kwelders"},
    {"value": 31,  "rgba": (230/255, 251/255, 0/255,   1.0), "class": "open zand in kustgebied"},
    {"value": 32,  "rgba": (137/255, 212/255, 43/255,  1.0), "class": "duinen met lage vegetatie"},
    {"value": 33,  "rgba": (90/255,  186/255, 64/255,  1.0), "class": "duinen met hoge vegetatie"},
    {"value": 34,  "rgba": (117/255, 0/255,   117/255, 1.0), "class": "duinheide"},
    {"value": 35,  "rgba": (255/255, 255/255, 0/255,   1.0), "class": "open stuifzand en/of rivierzand"},
    {"value": 36,  "rgba": (117/255, 0/255,   117/255, 1.0), "class": "heide"},
    {"value": 37,  "rgba": (164/255, 35/255,  83/255,  1.0), "class": "matig vergraste heide"},
    {"value": 38,  "rgba": (173/255, 139/255, 6/255,   1.0), "class": "sterk vergraste heide"},
    {"value": 39,  "rgba": (36/255,  153/255, 150/255, 1.0), "class": "hoogveen"},
    {"value": 40,  "rgba": (6/255,   90/255,  76/255,  1.0), "class": "bos in hoogveengebied"},
    {"value": 41,  "rgba": (255/255, 192/255, 203/255, 1.0), "class": "overige moeras vegetatie"},
    {"value": 42,  "rgba": (255/255, 165/255, 0/255,   1.0), "class": "rietvegetatie"},
    {"value": 43,  "rgba": (0/255,   100/255, 0/255,   1.0), "class": "bos in moerasgebied"},
    {"value": 45,  "rgba": (182/255, 182/255, 57/255,  1.0), "class": "natuurlijk beheerde agrarische graslanden"},
    {"value": 46,  "rgba": (245/255, 225/255, 15/255,  1.0), "class": "gras in het kustgebied"},
    {"value": 47,  "rgba": (150/255, 150/255, 57/255,  1.0), "class": "overig gras"},
    {"value": 61,  "rgba": (255/255, 179/255, 168/255, 1.0), "class": "boomkwekerijen"},
    {"value": 62,  "rgba": (227/255, 255/255, 112/255, 1.0), "class": "fruitkwekerijen"},
    {"value": 251, "rgba": (135/255, 27/255,  0/255,   1.0), "class": "hoofdinfrastructuur en spoorbaanlichamen"},
    {"value": 252, "rgba": (176/255, 35/255,  0/255,   1.0), "class": "halfverharde wegen, infrastructuur langzaam verkeer en overige infrastructuur"},
    {"value": 253, "rgba": (168/255, 0/255,   0/255,   1.0), "class": "smalle wegen"},
    {"value": 321, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "struikvegetatie in hoogveengebied (laag)"},
    {"value": 322, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "struikvegetatie in moerasgebied (laag)"},
    {"value": 323, "rgba": (137/255, 212/255, 43/255,  1.0), "class": "overige struikvegetatie (laag)"},
    {"value": 331, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "struikvegetatie in hoogveengebied (hoog)"},
    {"value": 332, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "struikvegetatie in moerasgebied (hoog)"},
    {"value": 333, "rgba": (90/255,  186/255, 64/255,  1.0), "class": "overige struikvegetatie (hoog)"},
]

# %%
lgn2024_reference__df = pd.DataFrame(lgn2024_reference__data).set_index('value')

# %%
lgn2024_reference__df['hexa'] = lgn2024_reference__df["rgba"].apply(lambda x: rgba_to_hex_func(x, True))

# %% [markdown]
# ## Saving dfs

# %%
lgn2018_reference__df.to_pickle(lgn2018_reference__df_path)
lgn2019_reference__df.to_pickle(lgn2019_reference__df_path)
lgn2020_reference__df.to_pickle(lgn2020_reference__df_path)
lgn2021_reference__df.to_pickle(lgn2021_reference__df_path)
lgn2022_reference__df.to_pickle(lgn2022_reference__df_path)
lgn2023_reference__df.to_pickle(lgn2023_reference__df_path)
lgn2024_reference__df.to_pickle(lgn2024_reference__df_path)

# %% [markdown]
# End of the Notebook
